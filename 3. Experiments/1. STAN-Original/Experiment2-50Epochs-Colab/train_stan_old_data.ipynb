# %%
# Mount this colab file correctly in google drive so I can access relative/local files
from google.colab import drive
drive.mount('/content/gdrive')
% cd /content/gdrive/My Drive/Github/"CS 499 - SPRING 2022"/"3. Experiments"/"1. STAN-Original/Experiment2-50Epochs"
! pwd

# Install python packages I will need in the local environment
! pip install epiweeks
! pip install haversine
! pip install dgl-cu111 -f https://data.dgl.ai/wheels/repo.html
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# /content/gdrive/My Drive/Github/CS 499 - SPRING 2022/3. Experiments/1. STAN-Original/Experiment2-50Epochs
# /content/gdrive/My Drive/Github/CS 499 - SPRING 2022/3. Experiments/1. STAN-Original/Experiment2-50Epochs
# Requirement already satisfied: epiweeks in /usr/local/lib/python3.7/dist-packages (2.1.4)
# Requirement already satisfied: haversine in /usr/local/lib/python3.7/dist-packages (2.5.1)
# Looking in links: https://data.dgl.ai/wheels/repo.html
# Requirement already satisfied: dgl-cu111 in /usr/local/lib/python3.7/dist-packages (0.8.1)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.7/dist-packages (from dgl-cu111) (1.21.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from dgl-cu111) (4.64.0)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from dgl-cu111) (1.4.1)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from dgl-cu111) (2.23.0)
# Requirement already satisfied: networkx>=2.1 in /usr/local/lib/python3.7/dist-packages (from dgl-cu111) (2.6.3)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->dgl-cu111) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->dgl-cu111) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->dgl-cu111) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->dgl-cu111) (2.10)

# %%
import time
time_start = time.time()

# %%
import csv
import os

import numpy as np
import pandas as pd
from epiweeks import Week

from data_downloader import GenerateTrainingData
from utils import date_today, gravity_law_commute_dist

os.environ['NUMEXPR_MAX_THREADS'] = '16'
os.environ['NUMEXPR_NUM_THREADS'] = '8'

import pickle
import matplotlib.pyplot as plt
import dgl
import torch
from torch import nn
import torch.nn.functional as F
from model import STAN

import sklearn
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

# %%
# Try to ensure reproducibility
torch.manual_seed(0)

# %%
GenerateTrainingData().download_jhu_data('2020-05-01', '2020-12-01')

# %%
#Merge population data with downloaded data
# raw_data = pickle.load(open('./data/old_state_covid_data.pickle','rb'))
raw_data = pickle.load(open('./data/state_covid_data.pickle','rb'))
pop_data = pd.read_csv('./uszips.csv')
pop_data = pop_data.groupby('state_name').agg({'population':'sum', 'density':'mean', 'lat':'mean', 'lng':'mean'}).reset_index()
raw_data = pd.merge(raw_data, pop_data, how='inner', left_on='state', right_on='state_name')

# %%
# Generate location similarity
loc_list = list(raw_data['state'].unique())
loc_dist_map = {}

for each_loc in loc_list:
    loc_dist_map[each_loc] = {}
    for each_loc2 in loc_list:
        lat1 = raw_data[raw_data['state']==each_loc]['latitude'].unique()[0]
        lng1 = raw_data[raw_data['state']==each_loc]['longitude'].unique()[0]
        pop1 = raw_data[raw_data['state']==each_loc]['population'].unique()[0]
        
        lat2 = raw_data[raw_data['state']==each_loc2]['latitude'].unique()[0]
        lng2 = raw_data[raw_data['state']==each_loc2]['longitude'].unique()[0]
        pop2 = raw_data[raw_data['state']==each_loc2]['population'].unique()[0]
        
        loc_dist_map[each_loc][each_loc2] = gravity_law_commute_dist(lat1, lng1, pop1, lat2, lng2, pop2, r=0.5)

# %%
#Generate Graph
dist_threshold = 18

for each_loc in loc_dist_map:
    loc_dist_map[each_loc] = {k: v for k, v in sorted(loc_dist_map[each_loc].items(), key=lambda item: item[1], reverse=True)}
    
adj_map = {}
for each_loc in loc_dist_map:
    adj_map[each_loc] = []
    for i, each_loc2 in enumerate(loc_dist_map[each_loc]):
        if loc_dist_map[each_loc][each_loc2] > dist_threshold:
            if i <= 3:
                adj_map[each_loc].append(each_loc2)
            else:
                break
        else:
            if i <= 1:
                adj_map[each_loc].append(each_loc2)
            else:
                break

rows = []
cols = []
for each_loc in adj_map:
    for each_loc2 in adj_map[each_loc]:
        rows.append(loc_list.index(each_loc))
        cols.append(loc_list.index(each_loc2))

# %%
g = dgl.graph((rows, cols))

# %%
#Preprocess features

active_cases = []
confirmed_cases = []
new_cases = []
death_cases = []
static_feat = []

for i, each_loc in enumerate(loc_list):
    active_cases.append(raw_data[raw_data['state'] == each_loc]['active'])
    confirmed_cases.append(raw_data[raw_data['state'] == each_loc]['confirmed'])
    new_cases.append(raw_data[raw_data['state'] == each_loc]['new_cases'])
    death_cases.append(raw_data[raw_data['state'] == each_loc]['deaths'])
    static_feat.append(np.array(raw_data[raw_data['state'] == each_loc][['population','density','lng','lat']]))
    
active_cases = np.array(active_cases)
confirmed_cases = np.array(confirmed_cases)
death_cases = np.array(death_cases)
new_cases = np.array(new_cases)
static_feat = np.array(static_feat)[:, 0, :]
recovered_cases = confirmed_cases - active_cases - death_cases
susceptible_cases = np.expand_dims(static_feat[:, 0], -1) - active_cases - recovered_cases

# Batch_feat: new_cases(dI), dR, dS
#dI = np.array(new_cases)
dI = np.concatenate((np.zeros((active_cases.shape[0],1), dtype=np.float32), np.diff(active_cases)), axis=-1)
dR = np.concatenate((np.zeros((recovered_cases.shape[0],1), dtype=np.float32), np.diff(recovered_cases)), axis=-1)
dS = np.concatenate((np.zeros((susceptible_cases.shape[0],1), dtype=np.float32), np.diff(susceptible_cases)), axis=-1)

# %%
#Build normalizer
normalizer = {'S':{}, 'I':{}, 'R':{}, 'dS':{}, 'dI':{}, 'dR':{}}

for i, each_loc in enumerate(loc_list):
    normalizer['S'][each_loc] = (np.mean(susceptible_cases[i]), np.std(susceptible_cases[i]))
    normalizer['I'][each_loc] = (np.mean(active_cases[i]), np.std(active_cases[i]))
    normalizer['R'][each_loc] = (np.mean(recovered_cases[i]), np.std(recovered_cases[i]))
    normalizer['dI'][each_loc] = (np.mean(dI[i]), np.std(dI[i]))
    normalizer['dR'][each_loc] = (np.mean(dR[i]), np.std(dR[i]))
    normalizer['dS'][each_loc] = (np.mean(dS[i]), np.std(dS[i]))

# %%
def prepare_data(data, sum_I, sum_R, history_window=5, pred_window=15, slide_step=5):
    # Data shape n_loc, timestep, n_feat
    # Reshape to n_loc, t, history_window*n_feat
    n_loc = data.shape[0]
    timestep = data.shape[1]
    n_feat = data.shape[2]
    
    x = []
    y_I = []
    y_R = []
    y_active_cases = []
    last_I = []
    last_R = []
    concat_I = []
    concat_R = []
    for i in range(0, timestep, slide_step):
        if i+history_window+pred_window-1 >= timestep or i+history_window >= timestep:
            break
        x.append(data[:, i:i+history_window, :].reshape((n_loc, history_window*n_feat)))
        
        concat_I.append(data[:, i+history_window-1, 0])
        concat_R.append(data[:, i+history_window-1, 1])
        last_I.append(sum_I[:, i+history_window-1])
        last_R.append(sum_R[:, i+history_window-1])

        y_I.append(data[:, i+history_window:i+history_window+pred_window, 0])
        y_R.append(data[:, i+history_window:i+history_window+pred_window, 1])
        y_active_cases.append(sum_I[:, i+history_window:i+history_window+pred_window].reshape((n_loc, pred_window)))

    x = np.array(x, dtype=np.float32).transpose((1, 0, 2))
    last_I = np.array(last_I, dtype=np.float32).transpose((1, 0))
    last_R = np.array(last_R, dtype=np.float32).transpose((1, 0))
    concat_I = np.array(concat_I, dtype=np.float32).transpose((1, 0))
    concat_R = np.array(concat_R, dtype=np.float32).transpose((1, 0))
    y_I = np.array(y_I, dtype=np.float32).transpose((1, 0, 2))
    y_R = np.array(y_R, dtype=np.float32).transpose((1, 0, 2))
    y_active_cases = np.array(y_active_cases, dtype=np.float32).transpose((1, 0, 2))

    return x, last_I, last_R, concat_I, concat_R, y_I, y_R, y_active_cases

# %%
valid_window = 25
test_window = 25

history_window=6
pred_window=15
slide_step=5

dynamic_feat = np.concatenate((np.expand_dims(dI, axis=-1), np.expand_dims(dR, axis=-1), np.expand_dims(dS, axis=-1)), axis=-1)
    
#Normalize
for i, each_loc in enumerate(loc_list):
    dynamic_feat[i, :, 0] = (dynamic_feat[i, :, 0] - normalizer['dI'][each_loc][0]) / normalizer['dI'][each_loc][1]
    dynamic_feat[i, :, 1] = (dynamic_feat[i, :, 1] - normalizer['dR'][each_loc][0]) / normalizer['dR'][each_loc][1]
    dynamic_feat[i, :, 2] = (dynamic_feat[i, :, 2] - normalizer['dS'][each_loc][0]) / normalizer['dS'][each_loc][1]

dI_mean = []
dI_std = []
dR_mean = []
dR_std = []

for i, each_loc in enumerate(loc_list):
    dI_mean.append(normalizer['dI'][each_loc][0])
    dR_mean.append(normalizer['dR'][each_loc][0])
    dI_std.append(normalizer['dI'][each_loc][1])
    dR_std.append(normalizer['dR'][each_loc][1])

dI_mean = np.array(dI_mean)
dI_std = np.array(dI_std)
dR_mean = np.array(dR_mean)
dR_std = np.array(dR_std)

#Split train-test
train_feat = dynamic_feat[:, :-valid_window-test_window, :]
val_feat = dynamic_feat[:, -valid_window-test_window:-test_window, :]
test_feat = dynamic_feat[:, -test_window:, :]

train_x, train_I, train_R, train_cI, train_cR, train_yI, train_yR, _ = prepare_data(train_feat, active_cases[:, :-valid_window-test_window], recovered_cases[:, :-valid_window-test_window], history_window, pred_window, slide_step)
val_x, val_I, val_R, val_cI, val_cR, val_yI, val_yR, _ = prepare_data(val_feat, active_cases[:, -valid_window-test_window:-test_window], recovered_cases[:, -valid_window-test_window:-test_window], history_window, pred_window, slide_step)
test_x, test_I, test_R, test_cI, test_cR, test_yI, test_yR, test_active_cases = prepare_data(test_feat, active_cases[:, -test_window:], recovered_cases[:, -test_window:], history_window, pred_window, slide_step)

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

train_x = torch.tensor(train_x).to(device)
train_I = torch.tensor(train_I).to(device)
train_R = torch.tensor(train_R).to(device)
train_cI = torch.tensor(train_cI).to(device)
train_cR = torch.tensor(train_cR).to(device)
train_yI = torch.tensor(train_yI).to(device)
train_yR = torch.tensor(train_yR).to(device)

val_x = torch.tensor(val_x).to(device)
val_I = torch.tensor(val_I).to(device)
val_R = torch.tensor(val_R).to(device)
val_cI = torch.tensor(val_cI).to(device)
val_cR = torch.tensor(val_cR).to(device)
val_yI = torch.tensor(val_yI).to(device)
val_yR = torch.tensor(val_yR).to(device)

test_x = torch.tensor(test_x).to(device)
test_I = torch.tensor(test_I).to(device)
test_R = torch.tensor(test_R).to(device)
test_cI = torch.tensor(test_cI).to(device)
test_cR = torch.tensor(test_cR).to(device)
test_yI = torch.tensor(test_yI).to(device)
test_yR = torch.tensor(test_yR).to(device)
test_active_cases = torch.tensor(test_active_cases).to(device)

dI_mean = torch.tensor(dI_mean, dtype=torch.float32).to(device).reshape((dI_mean.shape[0], 1, 1))
dI_std = torch.tensor(dI_std, dtype=torch.float32).to(device).reshape((dI_mean.shape[0], 1, 1))
dR_mean = torch.tensor(dR_mean, dtype=torch.float32).to(device).reshape((dI_mean.shape[0], 1, 1))
dR_std = torch.tensor(dR_std, dtype=torch.float32).to(device).reshape((dI_mean.shape[0], 1, 1))

N = torch.tensor(static_feat[:, 0], dtype=torch.float32).to(device).unsqueeze(-1)

# %%
#Train STAN

# Hyperparameters
in_dim = 3*history_window
hidden_dim1 = 32
hidden_dim2 = 32
gru_dim = 32
num_heads = 1


# Build STAN model for each state
for loc_name in loc_list:
    print("TRAINING NEW LOCATION:", loc_name)
    g = g.to(device)
    model = STAN(g, in_dim, hidden_dim1, hidden_dim2, gru_dim, num_heads, pred_window, device).to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-2)
    criterion = nn.MSELoss()

    all_loss = []
    file_name = './save/old_data/50_epochs_timed/' + loc_name
    min_loss = 1e10

    cur_loc = loc_list.index(loc_name)

    for epoch in range(50):
        model.train()
        optimizer.zero_grad()
        
        active_pred, recovered_pred, phy_active, phy_recover, _ = model(train_x, train_cI[cur_loc], train_cR[cur_loc], N[cur_loc], train_I[cur_loc], train_R[cur_loc])
        phy_active = (phy_active - dI_mean[cur_loc]) / dI_std[cur_loc]
        phy_recover = (phy_recover - dR_mean[cur_loc]) / dR_std[cur_loc]
        loss = criterion(active_pred.squeeze(), train_yI[cur_loc])+criterion(recovered_pred.squeeze(), train_yR[cur_loc])+0.1*criterion(phy_active.squeeze(), train_yI[cur_loc])+0.1*criterion(phy_recover.squeeze(), train_yR[cur_loc])
        
        loss.backward()
        optimizer.step()
        all_loss.append(loss.item())
        
        model.eval()
        _, _, _, _, prev_h = model(train_x, train_cI[cur_loc], train_cR[cur_loc], N[cur_loc], train_I[cur_loc], train_R[cur_loc])
        val_active_pred, val_recovered_pred, val_phy_active, val_phy_recover, _ = model(val_x, val_cI[cur_loc], val_cR[cur_loc], N[cur_loc], val_I[cur_loc], val_R[cur_loc], prev_h)
        
        val_phy_active = (val_phy_active - dI_mean[cur_loc]) / dI_std[cur_loc]
        val_loss = criterion(val_active_pred.squeeze(), val_yI[cur_loc]) + 0.1*criterion(val_phy_active.squeeze(), val_yI[cur_loc])
        if val_loss < min_loss:    
            state = {
                'state': model.state_dict(),
                'optimizer': optimizer.state_dict(),
            }
            torch.save(state, file_name)
            min_loss = val_loss
            print('Saved model')
        
        print('Epoch %d, Loss %.2f, Val loss %.2f'%(epoch, all_loss[-1], val_loss.item()))
# Out:
# TRAINING NEW LOCATION: Alabama
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/loss.py:520: UserWarning: Using a target size (torch.Size([1, 15])) that is different to the input size (torch.Size([15])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Saved model
# Epoch 0, Loss 1.39, Val loss 9.13
# Epoch 1, Loss 72.76, Val loss 74.70
# Epoch 2, Loss 125.45, Val loss 31.27
# Saved model
# Epoch 3, Loss 26.57, Val loss 1.88
# Saved model
# Epoch 4, Loss 1.92, Val loss 0.24
# Epoch 5, Loss 0.48, Val loss 0.26
# Epoch 6, Loss 0.34, Val loss 0.35
# Epoch 7, Loss 0.30, Val loss 0.40
# Epoch 8, Loss 0.31, Val loss 0.44
# Epoch 9, Loss 0.31, Val loss 0.47
# Epoch 10, Loss 0.32, Val loss 0.47
# Epoch 11, Loss 0.32, Val loss 0.48
# Epoch 12, Loss 0.32, Val loss 0.46
# Epoch 13, Loss 0.32, Val loss 0.45
# Epoch 14, Loss 0.32, Val loss 0.46
# Epoch 15, Loss 0.33, Val loss 0.47
# Epoch 16, Loss 0.32, Val loss 0.46
# Epoch 17, Loss 0.29, Val loss 0.41
# Epoch 18, Loss 0.29, Val loss 0.37
# Epoch 19, Loss 0.28, Val loss 0.38
# Epoch 20, Loss 0.28, Val loss 0.42
# Epoch 21, Loss 0.27, Val loss 0.35
# Epoch 22, Loss 0.26, Val loss 0.37
# Epoch 23, Loss 0.23, Val loss 0.35
# Epoch 24, Loss 0.25, Val loss 0.39
# Epoch 25, Loss 0.23, Val loss 0.38
# Epoch 26, Loss 0.23, Val loss 0.34
# Epoch 27, Loss 0.23, Val loss 0.33
# Epoch 28, Loss 0.22, Val loss 0.40
# Epoch 29, Loss 0.24, Val loss 0.32
# Epoch 30, Loss 0.21, Val loss 0.28
# Epoch 31, Loss 0.20, Val loss 0.30
# Epoch 32, Loss 0.19, Val loss 0.26
# Epoch 33, Loss 0.21, Val loss 0.27
# Epoch 34, Loss 0.22, Val loss 0.28
# Epoch 35, Loss 0.20, Val loss 0.27
# Saved model
# Epoch 36, Loss 0.19, Val loss 0.24
# Epoch 37, Loss 0.19, Val loss 0.27
# Epoch 38, Loss 0.21, Val loss 0.25
# Epoch 39, Loss 0.19, Val loss 0.24
# Saved model
# Epoch 40, Loss 0.20, Val loss 0.23
# Saved model
# Epoch 41, Loss 0.19, Val loss 0.22
# Epoch 42, Loss 0.19, Val loss 0.26
# Epoch 43, Loss 0.20, Val loss 0.26
# Saved model
# Epoch 44, Loss 0.19, Val loss 0.20
# Epoch 45, Loss 0.18, Val loss 0.20
# Saved model
# Epoch 46, Loss 0.19, Val loss 0.19
# Epoch 47, Loss 0.16, Val loss 0.21
# Epoch 48, Loss 0.17, Val loss 0.23
# Epoch 49, Loss 0.22, Val loss 0.20
# TRAINING NEW LOCATION: Alaska
# Saved model
# Epoch 0, Loss 10.78, Val loss 115.68
# Epoch 1, Loss 516.96, Val loss 625.03
# Epoch 2, Loss 825.54, Val loss 1017.22
# Epoch 3, Loss 490.68, Val loss 480.27
# Epoch 4, Loss 135.33, Val loss 137.30
# Saved model
# Epoch 5, Loss 33.37, Val loss 47.60
# Saved model
# Epoch 6, Loss 10.21, Val loss 18.54
# Saved model
# Epoch 7, Loss 5.07, Val loss 8.39
# Saved model
# Epoch 8, Loss 2.75, Val loss 6.62
# Saved model
# Epoch 9, Loss 2.21, Val loss 5.98
# Saved model
# Epoch 10, Loss 1.92, Val loss 5.26
# Saved model
# Epoch 11, Loss 1.84, Val loss 4.82
# Saved model
# Epoch 12, Loss 1.67, Val loss 4.26
# Saved model
# Epoch 13, Loss 1.53, Val loss 4.11
# Saved model
# Epoch 14, Loss 1.48, Val loss 4.07
# Saved model
# Epoch 15, Loss 1.46, Val loss 3.87
# Saved model
# Epoch 16, Loss 1.42, Val loss 3.85
# Saved model
# Epoch 17, Loss 1.41, Val loss 3.75
# Epoch 18, Loss 1.42, Val loss 3.76
# Epoch 19, Loss 1.37, Val loss 3.82
# Epoch 20, Loss 1.33, Val loss 3.82
# Epoch 21, Loss 1.33, Val loss 3.90
# Epoch 22, Loss 1.33, Val loss 3.96
# Epoch 23, Loss 1.27, Val loss 4.07
# Epoch 24, Loss 1.29, Val loss 4.11
# Epoch 25, Loss 1.30, Val loss 4.12
# Epoch 26, Loss 1.27, Val loss 4.18
# Epoch 27, Loss 1.24, Val loss 4.15
# Epoch 28, Loss 1.24, Val loss 4.16
# Epoch 29, Loss 1.22, Val loss 4.11
# Epoch 30, Loss 1.24, Val loss 4.13
# Epoch 31, Loss 1.25, Val loss 4.11
# Epoch 32, Loss 1.19, Val loss 4.20
# Epoch 33, Loss 1.21, Val loss 4.11
# Epoch 34, Loss 1.19, Val loss 4.08
# Epoch 35, Loss 1.19, Val loss 4.09
# Epoch 36, Loss 1.23, Val loss 3.98
# Epoch 37, Loss 1.17, Val loss 4.07
# Epoch 38, Loss 1.17, Val loss 4.04
# Epoch 39, Loss 1.14, Val loss 4.14
# Epoch 40, Loss 1.16, Val loss 4.08
# Epoch 41, Loss 1.14, Val loss 4.24
# Epoch 42, Loss 1.21, Val loss 4.09
# Epoch 43, Loss 1.12, Val loss 4.16
# Epoch 44, Loss 1.12, Val loss 4.20
# Epoch 45, Loss 1.16, Val loss 4.23
# Epoch 46, Loss 1.19, Val loss 4.17
# Epoch 47, Loss 1.11, Val loss 4.16
# Epoch 48, Loss 1.11, Val loss 4.21
# Epoch 49, Loss 1.09, Val loss 4.22
# TRAINING NEW LOCATION: Arizona
# Saved model
# Epoch 0, Loss 53871.14, Val loss 718.41
# Epoch 1, Loss 124968.30, Val loss 2998.09
# Epoch 2, Loss 79986.20, Val loss 4734.43
# Epoch 3, Loss 36532.48, Val loss 4730.26
# Epoch 4, Loss 14325.15, Val loss 3344.11
# Epoch 5, Loss 5567.64, Val loss 1713.76
# Epoch 6, Loss 1992.82, Val loss 746.24
# Saved model
# Epoch 7, Loss 724.03, Val loss 318.14
# Saved model
# Epoch 8, Loss 288.02, Val loss 144.45
# Saved model
# Epoch 9, Loss 133.40, Val loss 71.05
# Saved model
# Epoch 10, Loss 67.76, Val loss 38.41
# Saved model
# Epoch 11, Loss 37.66, Val loss 21.21
# Saved model
# Epoch 12, Loss 23.42, Val loss 13.13
# Saved model
# Epoch 13, Loss 15.48, Val loss 8.04
# Saved model
# Epoch 14, Loss 10.90, Val loss 4.91
# Saved model
# Epoch 15, Loss 8.14, Val loss 4.33
# Saved model
# Epoch 16, Loss 7.28, Val loss 2.96
# Saved model
# Epoch 17, Loss 5.64, Val loss 2.42
# Saved model
# Epoch 18, Loss 4.79, Val loss 1.70
# Saved model
# Epoch 19, Loss 4.08, Val loss 1.24
# Saved model
# Epoch 20, Loss 3.61, Val loss 1.09
# Saved model
# Epoch 21, Loss 3.29, Val loss 1.00
# Saved model
# Epoch 22, Loss 2.98, Val loss 0.77
# Saved model
# Epoch 23, Loss 2.95, Val loss 0.75
# Saved model
# Epoch 24, Loss 2.62, Val loss 0.65
# Saved model
# Epoch 25, Loss 2.42, Val loss 0.59
# Saved model
# Epoch 26, Loss 2.25, Val loss 0.53
# Saved model
# Epoch 27, Loss 2.14, Val loss 0.41
# Epoch 28, Loss 2.06, Val loss 0.45
# Saved model
# Epoch 29, Loss 1.94, Val loss 0.35
# Saved model
# Epoch 30, Loss 1.88, Val loss 0.32
# Epoch 31, Loss 1.90, Val loss 0.33
# Saved model
# TRAINING NEW LOCATION: Colorado
# Saved model
# Epoch 0, Loss 11626.57, Val loss 234.00
# Epoch 1, Loss 113423.60, Val loss 1697.44
# Epoch 2, Loss 146692.70, Val loss 3051.97
# Epoch 3, Loss 56039.52, Val loss 2337.93
# Epoch 4, Loss 13189.85, Val loss 960.73
# Epoch 5, Loss 2800.56, Val loss 304.56
# Saved model
# Epoch 6, Loss 711.16, Val loss 103.58
# Saved model
# Epoch 7, Loss 241.05, Val loss 42.60
# Saved model
# Epoch 8, Loss 103.62, Val loss 20.72
# Saved model
# Epoch 9, Loss 53.16, Val loss 11.59
# Saved model
# Epoch 10, Loss 30.82, Val loss 7.11
# Saved model
# Epoch 11, Loss 19.54, Val loss 4.91
# Saved model
# Epoch 12, Loss 13.32, Val loss 3.40
# Saved model
# Epoch 13, Loss 9.57, Val loss 2.67
# Saved model
# Epoch 14, Loss 7.15, Val loss 2.25
# Saved model
# Epoch 15, Loss 5.57, Val loss 1.97
# Saved model
# Epoch 16, Loss 4.48, Val loss 1.75
# Saved model
# Epoch 17, Loss 3.54, Val loss 1.65
# Saved model
# Epoch 18, Loss 3.12, Val loss 1.56
# Saved model
# Epoch 19, Loss 2.59, Val loss 1.45
# Saved model
# Epoch 20, Loss 2.31, Val loss 1.34
# Saved model
# Epoch 21, Loss 1.99, Val loss 1.23
# Saved model
# Epoch 22, Loss 1.80, Val loss 1.22
# Saved model
# Epoch 23, Loss 1.60, Val loss 1.16
# Saved model
# Epoch 24, Loss 1.45, Val loss 1.11
# Saved model
# Epoch 25, Loss 1.38, Val loss 1.09
# Saved model
# Epoch 26, Loss 1.33, Val loss 1.05
# Epoch 27, Loss 1.18, Val loss 1.13
# Epoch 28, Loss 1.12, Val loss 1.15
# Epoch 29, Loss 1.05, Val loss 1.31
# Epoch 30, Loss 0.99, Val loss 1.23
# Epoch 31, Loss 0.95, Val loss 1.28
# Epoch 32, Loss 0.91, Val loss 1.23
# Epoch 33, Loss 0.85, Val loss 1.22
# Epoch 34, Loss 0.86, Val loss 1.18
# Epoch 35, Loss 0.80, Val loss 1.14
# Epoch 36, Loss 0.77, Val loss 1.09
# Epoch 37, Loss 0.75, Val loss 1.05
# Epoch 38, Loss 0.80, Val loss 1.07
# Saved model
# Epoch 39, Loss 0.69, Val loss 1.05
# Epoch 40, Loss 0.81, Val loss 1.06
# Epoch 41, Loss 0.72, Val loss 1.12
# Epoch 42, Loss 0.72, Val loss 1.12
# Epoch 43, Loss 0.69, Val loss 1.12
# Epoch 44, Loss 0.72, Val loss 1.19
# Epoch 45, Loss 0.67, Val loss 1.15
# Epoch 46, Loss 0.69, Val loss 1.19
# Epoch 47, Loss 0.66, Val loss 1.18
# Epoch 48, Loss 0.67, Val loss 1.17
# Epoch 49, Loss 0.70, Val loss 1.15
# TRAINING NEW LOCATION: Connecticut
# Saved model
# Epoch 0, Loss 1078.59, Val loss 337.52
# Epoch 1, Loss 42106.57, Val loss 2263.83
# Epoch 2, Loss 55087.47, Val loss 4692.33
# Epoch 3, Loss 37283.00, Val loss 5763.91
# Epoch 4, Loss 18167.97, Val loss 4501.22
# Epoch 5, Loss 9362.46, Val loss 2533.66
# Epoch 6, Loss 3818.66, Val loss 1018.30
# Epoch 7, Loss 1549.11, Val loss 367.34
# Saved model
# Epoch 8, Loss 543.66, Val loss 138.43
# Saved model
# Epoch 9, Loss 204.41, Val loss 57.86
# Saved model
# Epoch 10, Loss 72.52, Val loss 27.70
# Saved model
# Epoch 11, Loss 33.47, Val loss 15.07
# Saved model
# Epoch 12, Loss 16.20, Val loss 9.00
# Saved model
# Epoch 13, Loss 8.79, Val loss 5.98
# Saved model
# Epoch 14, Loss 5.74, Val loss 4.34
# Saved model
# Epoch 15, Loss 4.03, Val loss 3.32
# Saved model
# Epoch 16, Loss 2.95, Val loss 2.69
# Saved model
# Epoch 17, Loss 2.36, Val loss 2.30
# Saved model
# Epoch 18, Loss 1.94, Val loss 2.06
# Saved model
# Epoch 19, Loss 1.66, Val loss 1.91
# Saved model
# Epoch 20, Loss 1.47, Val loss 1.80
# Saved model
# Epoch 21, Loss 1.30, Val loss 1.79
# Epoch 22, Loss 1.20, Val loss 1.79
# Epoch 23, Loss 1.13, Val loss 1.83
# Epoch 24, Loss 1.08, Val loss 1.85
# Epoch 25, Loss 1.03, Val loss 1.85
# Epoch 26, Loss 1.00, Val loss 1.82
# Saved model
# Epoch 27, Loss 0.97, Val loss 1.78
# Saved model
# Epoch 28, Loss 0.92, Val loss 1.73
# Saved model
# Epoch 29, Loss 0.90, Val loss 1.68
# Saved model
# Epoch 30, Loss 0.88, Val loss 1.63
# Saved model
# Epoch 31, Loss 0.87, Val loss 1.59
# Saved model
# Epoch 32, Loss 0.85, Val loss 1.57
# Saved model
# Epoch 33, Loss 0.84, Val loss 1.56
# Epoch 34, Loss 0.83, Val loss 1.56
# Epoch 35, Loss 0.82, Val loss 1.57
# Epoch 36, Loss 0.82, Val loss 1.58
# Epoch 37, Loss 0.79, Val loss 1.61
# Epoch 38, Loss 0.78, Val loss 1.64
# Epoch 39, Loss 0.76, Val loss 1.68
# Epoch 40, Loss 0.78, Val loss 1.70
# Epoch 41, Loss 0.77, Val loss 1.71
# Epoch 42, Loss 0.78, Val loss 1.71
# Epoch 43, Loss 0.76, Val loss 1.69
# Epoch 44, Loss 0.75, Val loss 1.66
# Epoch 45, Loss 0.75, Val loss 1.62
# Epoch 46, Loss 0.75, Val loss 1.59
# Epoch 47, Loss 0.75, Val loss 1.57
# Epoch 48, Loss 0.74, Val loss 1.56
# Epoch 49, Loss 0.74, Val loss 1.57
# TRAINING NEW LOCATION: Delaware
# Saved model
# Epoch 0, Loss 57.21, Val loss 157.62
# Epoch 1, Loss 1639.85, Val loss 3924.01
# Epoch 2, Loss 10732.47, Val loss 10600.08
# Epoch 3, Loss 13024.78, Val loss 12849.25
# Epoch 4, Loss 6841.40, Val loss 5779.27
# Epoch 5, Loss 1729.27, Val loss 1799.56
# Epoch 6, Loss 390.20, Val loss 161.38
# Saved model
# Epoch 7, Loss 211.34, Val loss 111.59
# Saved model
# Epoch 8, Loss 40.81, Val loss 60.67
# Saved model
# Epoch 9, Loss 23.31, Val loss 9.41
# Epoch 10, Loss 12.50, Val loss 9.53
# Saved model
# Epoch 11, Loss 8.00, Val loss 9.16
# Saved model
# Epoch 12, Loss 6.78, Val loss 3.52
# Saved model
# Epoch 13, Loss 8.41, Val loss 2.74
# Epoch 14, Loss 4.67, Val loss 4.72
# Epoch 15, Loss 4.31, Val loss 3.63
# Epoch 16, Loss 3.50, Val loss 4.42
# Epoch 17, Loss 3.46, Val loss 3.33
# Saved model
# Epoch 18, Loss 3.33, Val loss 1.13
# Saved model
# Epoch 19, Loss 3.13, Val loss 1.01
# Saved model
# Epoch 20, Loss 2.69, Val loss 0.65
# Epoch 21, Loss 2.96, Val loss 0.98
# Epoch 22, Loss 2.68, Val loss 1.50
# Epoch 23, Loss 2.23, Val loss 1.27
# Epoch 24, Loss 2.45, Val loss 1.36
# Saved model
# Epoch 25, Loss 2.40, Val loss 0.63
# Saved model
# Epoch 26, Loss 2.15, Val loss 0.38
# Epoch 27, Loss 2.32, Val loss 1.01
# Epoch 28, Loss 2.12, Val loss 0.75
# Epoch 29, Loss 2.03, Val loss 0.44
# Epoch 30, Loss 1.95, Val loss 0.55
# Epoch 31, Loss 1.92, Val loss 0.63
# Epoch 32, Loss 2.08, Val loss 1.03
# Epoch 33, Loss 1.95, Val loss 1.04
# Epoch 34, Loss 1.99, Val loss 0.53
# Epoch 35, Loss 1.86, Val loss 0.64
# Epoch 36, Loss 2.06, Val loss 0.44
# Epoch 37, Loss 1.90, Val loss 1.09
# Epoch 38, Loss 1.84, Val loss 0.70
# Epoch 39, Loss 1.70, Val loss 0.48
# Epoch 40, Loss 1.67, Val loss 0.80
# Epoch 41, Loss 2.01, Val loss 0.58
# Saved model
# Epoch 42, Loss 1.65, Val loss 0.34
# Epoch 43, Loss 1.93, Val loss 0.74
# Epoch 44, Loss 1.52, Val loss 0.41
# Saved model
# Epoch 45, Loss 1.79, Val loss 0.29
# Epoch 46, Loss 1.53, Val loss 0.91
# Epoch 47, Loss 1.97, Val loss 1.03
# Epoch 48, Loss 1.53, Val loss 1.08
# Epoch 49, Loss 1.75, Val loss 0.50
# TRAINING NEW LOCATION: District of Columbia
# Saved model
# Epoch 0, Loss 9.68, Val loss 110.42
# Saved model
# Epoch 1, Loss 225.30, Val loss 0.98
# Saved model
# Epoch 2, Loss 12.09, Val loss 0.17
# Epoch 3, Loss 4.18, Val loss 0.19
# Epoch 4, Loss 3.60, Val loss 0.18
# Epoch 5, Loss 3.43, Val loss 0.17
# Saved model
# Epoch 6, Loss 3.43, Val loss 0.15
# Saved model
# Epoch 7, Loss 3.55, Val loss 0.13
# Saved model
# Epoch 8, Loss 3.34, Val loss 0.12
# Saved model
# Epoch 9, Loss 3.34, Val loss 0.11
# Saved model
# Epoch 10, Loss 3.34, Val loss 0.09
# Saved model
# Epoch 11, Loss 3.35, Val loss 0.08
# Saved model
# Epoch 12, Loss 3.32, Val loss 0.07
# Saved model
# Epoch 13, Loss 3.31, Val loss 0.06
# Saved model
# Epoch 38, Loss 3.75, Val loss 0.59
# Saved model
# Epoch 39, Loss 4.09, Val loss 0.57
# Saved model
# Epoch 40, Loss 3.65, Val loss 0.57
# Epoch 41, Loss 3.91, Val loss 0.58
# Epoch 42, Loss 3.67, Val loss 0.61
# Epoch 43, Loss 3.63, Val loss 0.64
# Epoch 44, Loss 3.81, Val loss 0.66
# Epoch 45, Loss 3.71, Val loss 0.66
# Epoch 46, Loss 3.94, Val loss 0.65
# Epoch 47, Loss 3.79, Val loss 0.64
# Epoch 48, Loss 3.30, Val loss 0.63
# Epoch 49, Loss 3.85, Val loss 0.61
# TRAINING NEW LOCATION: Kentucky
# Saved model
# Epoch 0, Loss 332.22, Val loss 461.63
# Epoch 1, Loss 3102.26, Val loss 1876.44
# Epoch 2, Loss 3905.22, Val loss 2204.15
# Epoch 3, Loss 1697.54, Val loss 1075.62
# Saved model
# Epoch 4, Loss 445.24, Val loss 367.14
# Saved model
# Epoch 5, Loss 126.72, Val loss 125.97
# Saved model
# Epoch 6, Loss 40.80, Val loss 62.94
# Saved model
# Epoch 7, Loss 18.28, Val loss 25.83
# Saved model
# Epoch 8, Loss 8.06, Val loss 12.88
# Saved model
# Epoch 9, Loss 4.89, Val loss 7.36
# Saved model
# Epoch 10, Loss 3.18, Val loss 4.83
# Saved model
# Epoch 11, Loss 2.26, Val loss 3.59
# Saved model
# Epoch 12, Loss 1.75, Val loss 2.49
# Saved model
# Epoch 13, Loss 1.40, Val loss 1.99
# Saved model
# Epoch 14, Loss 1.17, Val loss 1.72
# Saved model
# Epoch 15, Loss 1.03, Val loss 1.70
# Saved model
# Epoch 16, Loss 0.95, Val loss 1.68
# Saved model
# Epoch 17, Loss 0.84, Val loss 1.57
# Saved model
# Epoch 18, Loss 0.79, Val loss 1.53
# Epoch 19, Loss 0.74, Val loss 1.55
# Saved model
# Epoch 20, Loss 0.68, Val loss 1.51
# Epoch 21, Loss 0.66, Val loss 1.54
# Saved model
# Epoch 22, Loss 0.63, Val loss 1.46
# Epoch 23, Loss 0.61, Val loss 1.53
# Epoch 24, Loss 0.62, Val loss 1.47
# Saved model
# Epoch 25, Loss 0.58, Val loss 1.38
# Epoch 26, Loss 0.57, Val loss 1.40
# Saved model
# Epoch 27, Loss 0.56, Val loss 1.29
# Epoch 28, Loss 0.54, Val loss 1.35
# Saved model
# Epoch 29, Loss 0.55, Val loss 1.20
# Saved model
# Epoch 30, Loss 0.55, Val loss 1.16
# Epoch 31, Loss 0.53, Val loss 1.25
# Epoch 32, Loss 0.52, Val loss 1.18
# Epoch 33, Loss 0.52, Val loss 1.17
# Epoch 34, Loss 0.54, Val loss 1.18
# Epoch 35, Loss 0.50, Val loss 1.31
# Epoch 36, Loss 0.50, Val loss 1.24
# Epoch 37, Loss 0.51, Val loss 1.20
# Epoch 38, Loss 0.55, Val loss 1.18
# Epoch 39, Loss 0.52, Val loss 1.18
# Epoch 40, Loss 0.49, Val loss 1.29
# Epoch 41, Loss 0.50, Val loss 1.32
# Epoch 9, Loss 609.75, Val loss 349.10
# Saved model
# Epoch 10, Loss 267.37, Val loss 219.17
# Saved model
# Epoch 11, Loss 145.58, Val loss 119.76
# Saved model
# Epoch 12, Loss 83.01, Val loss 74.98
# Saved model
# Epoch 13, Loss 50.01, Val loss 46.12
# Saved model
# Epoch 14, Loss 33.24, Val loss 33.87
# Saved model
# Epoch 15, Loss 24.14, Val loss 24.55
# Saved model
# Epoch 16, Loss 20.03, Val loss 19.63
# Saved model
# Epoch 17, Loss 14.90, Val loss 13.44
# Saved model
# Epoch 18, Loss 12.14, Val loss 11.71
# Saved model
# Epoch 19, Loss 11.81, Val loss 9.20
# Saved model
# Epoch 20, Loss 9.44, Val loss 7.86
# Epoch 21, Loss 7.86, Val loss 7.94
# Saved model
# Epoch 22, Loss 7.38, Val loss 6.33
# Saved model
# Epoch 23, Loss 6.56, Val loss 4.86
# Saved model
# Epoch 24, Loss 6.19, Val loss 4.85
# Saved model
# Epoch 25, Loss 5.61, Val loss 4.56
# Saved model
# Epoch 26, Loss 5.14, Val loss 3.34
# Epoch 27, Loss 4.61, Val loss 3.56
# Epoch 28, Loss 4.58, Val loss 3.67
# Saved model
# Epoch 29, Loss 4.43, Val loss 3.09
# Saved model
# Epoch 30, Loss 3.95, Val loss 2.27
# Epoch 31, Loss 3.71, Val loss 2.42
# Saved model
# Epoch 32, Loss 3.57, Val loss 2.10
# Epoch 33, Loss 3.50, Val loss 2.48
# Epoch 34, Loss 3.62, Val loss 2.17
# Saved model
# Epoch 35, Loss 3.41, Val loss 1.70
# Epoch 36, Loss 3.30, Val loss 1.70
# Epoch 37, Loss 3.25, Val loss 1.70
# Saved model
# Epoch 38, Loss 3.34, Val loss 1.38
# Epoch 39, Loss 3.06, Val loss 1.49
# Epoch 40, Loss 2.88, Val loss 1.54
# Saved model
# Epoch 41, Loss 3.02, Val loss 1.25
# Epoch 42, Loss 3.00, Val loss 1.32
# Saved model
# Epoch 43, Loss 2.82, Val loss 1.14
# Epoch 44, Loss 2.89, Val loss 1.20
# Epoch 45, Loss 2.85, Val loss 1.27
# Epoch 46, Loss 2.76, Val loss 1.23
# Saved model
# Epoch 47, Loss 2.92, Val loss 1.12
# Saved model
# Epoch 48, Loss 2.71, Val loss 1.06
# Epoch 49, Loss 2.74, Val loss 1.08
# TRAINING NEW LOCATION: Massachusetts
# Saved model
# Epoch 0, Loss 0.27, Val loss 0.13
# Epoch 1, Loss 0.42, Val loss 0.99
# Saved model
# Epoch 2, Loss 3.18, Val loss 0.11
# Epoch 3, Loss 0.23, Val loss 0.11
# Epoch 4, Loss 0.17, Val loss 0.12
# Epoch 5, Loss 0.15, Val loss 0.13
# Epoch 6, Loss 0.14, Val loss 0.14
# Epoch 7, Loss 0.13, Val loss 0.16
# Epoch 8, Loss 0.13, Val loss 0.16
# Epoch 9, Loss 0.13, Val loss 0.16
# Epoch 10, Loss 0.14, Val loss 0.16
# Epoch 11, Loss 0.13, Val loss 0.15
# Epoch 12, Loss 0.12, Val loss 0.14
# Epoch 13, Loss 0.12, Val loss 0.14
# Epoch 30, Loss 0.17, Val loss 0.73
# Saved model
# Epoch 31, Loss 0.16, Val loss 0.71
# Saved model
# Epoch 32, Loss 0.15, Val loss 0.69
# Saved model
# Epoch 33, Loss 0.14, Val loss 0.68
# Saved model
# Epoch 34, Loss 0.14, Val loss 0.67
# Epoch 35, Loss 0.13, Val loss 0.68
# Epoch 36, Loss 0.12, Val loss 0.70
# Epoch 37, Loss 0.11, Val loss 0.70
# Epoch 38, Loss 0.11, Val loss 0.68
# Saved model
# Epoch 39, Loss 0.11, Val loss 0.67
# Saved model
# Epoch 40, Loss 0.10, Val loss 0.67
# Saved model
# Epoch 41, Loss 0.10, Val loss 0.65
# Epoch 42, Loss 0.10, Val loss 0.66
# Epoch 43, Loss 0.09, Val loss 0.66
# Epoch 44, Loss 0.09, Val loss 0.66
# Epoch 45, Loss 0.08, Val loss 0.67
# Epoch 46, Loss 0.08, Val loss 0.67
# Epoch 47, Loss 0.08, Val loss 0.66
# Epoch 48, Loss 0.07, Val loss 0.66
# Epoch 49, Loss 0.07, Val loss 0.66
# TRAINING NEW LOCATION: Mississippi
# Saved model
# Epoch 0, Loss 5.04, Val loss 3.77
# Saved model
# Epoch 1, Loss 19.43, Val loss 1.87
# Saved model
# Epoch 2, Loss 4.86, Val loss 1.23
# Saved model
# Epoch 3, Loss 2.65, Val loss 1.15
# Saved model
# Epoch 4, Loss 2.34, Val loss 1.11
# Saved model
# Epoch 5, Loss 2.26, Val loss 1.09
# Epoch 6, Loss 2.23, Val loss 1.10
# Epoch 7, Loss 2.22, Val loss 1.12
# Epoch 8, Loss 2.19, Val loss 1.12
# ...
# Epoch 34, Loss 1.98, Val loss 0.50
# Epoch 35, Loss 1.99, Val loss 0.52
# Epoch 36, Loss 1.97, Val loss 0.54
# Epoch 37, Loss 1.96, Val loss 0.57
# Epoch 38, Loss 1.95, Val loss 0.56
# Epoch 39, Loss 1.94, Val loss 0.56
# Epoch 40, Loss 1.93, Val loss 0.54
# Epoch 41, Loss 1.95, Val loss 0.57
# Epoch 42, Loss 1.92, Val loss 0.59
# Epoch 43, Loss 1.91, Val loss 0.60
# Epoch 44, Loss 1.90, Val loss 0.62
# Epoch 45, Loss 1.91, Val loss 0.62
# Epoch 46, Loss 1.91, Val loss 0.60
# Epoch 47, Loss 1.88, Val loss 0.59
# Epoch 48, Loss 1.88, Val loss 0.56
# Epoch 49, Loss 1.85, Val loss 0.54
# TRAINING NEW LOCATION: Texas
# Saved model
# Epoch 0, Loss 14.09, Val loss 1169.81
# Saved model
# Epoch 1, Loss 2916.59, Val loss 69.25
# Saved model
# Epoch 2, Loss 182.28, Val loss 0.72
# Epoch 3, Loss 10.61, Val loss 0.79
# Epoch 4, Loss 4.15, Val loss 1.01
# Epoch 5, Loss 3.53, Val loss 1.12
# Epoch 6, Loss 3.42, Val loss 1.22
# Epoch 7, Loss 3.46, Val loss 1.28
# Epoch 8, Loss 3.42, Val loss 1.34
# Epoch 9, Loss 3.50, Val loss 1.38
# Epoch 10, Loss 3.51, Val loss 1.40
# Epoch 19, Loss 0.30, Val loss 0.75
# Epoch 20, Loss 0.30, Val loss 0.70
# Epoch 21, Loss 0.29, Val loss 0.67
# Epoch 22, Loss 0.29, Val loss 0.70
# Epoch 23, Loss 0.27, Val loss 0.70
# Epoch 24, Loss 0.26, Val loss 0.69
# Epoch 25, Loss 0.26, Val loss 0.65
# Epoch 26, Loss 0.25, Val loss 0.66
# Epoch 27, Loss 0.24, Val loss 0.67
# Epoch 28, Loss 0.24, Val loss 0.66
# Epoch 29, Loss 0.24, Val loss 0.65
# Epoch 30, Loss 0.25, Val loss 0.68
# Epoch 31, Loss 0.23, Val loss 0.65
# Epoch 32, Loss 0.22, Val loss 0.65
# Epoch 33, Loss 0.21, Val loss 0.65
# Epoch 34, Loss 0.22, Val loss 0.71
# Epoch 35, Loss 0.20, Val loss 0.73
# Epoch 36, Loss 0.21, Val loss 0.73
# Epoch 37, Loss 0.20, Val loss 0.75
# Epoch 38, Loss 0.19, Val loss 0.69
# Epoch 39, Loss 0.19, Val loss 0.70
# Epoch 40, Loss 0.18, Val loss 0.65
# Epoch 41, Loss 0.18, Val loss 0.67
# Epoch 42, Loss 0.17, Val loss 0.63
# Epoch 43, Loss 0.17, Val loss 0.62
# Epoch 44, Loss 0.19, Val loss 0.60
# Epoch 45, Loss 0.16, Val loss 0.63
# Epoch 46, Loss 0.16, Val loss 0.66
# Epoch 47, Loss 0.16, Val loss 0.68
# Epoch 48, Loss 0.17, Val loss 0.69
# Saved model
# Epoch 49, Loss 0.16, Val loss 0.53
# TRAINING NEW LOCATION: Vermont
# Saved model
# Epoch 0, Loss 1.43, Val loss 1.56
# Saved model
# Epoch 1, Loss 1.02, Val loss 0.07
# Saved model
# Epoch 2, Loss 0.20, Val loss 0.07
# Epoch 3, Loss 0.12, Val loss 0.08
# Epoch 4, Loss 0.07, Val loss 0.09
# Epoch 5, Loss 0.08, Val loss 0.10
# Epoch 6, Loss 0.10, Val loss 0.08
# Saved model
# Epoch 7, Loss 0.09, Val loss 0.06
# Saved model
# Epoch 8, Loss 0.08, Val loss 0.05
# Saved model
# Epoch 9, Loss 0.07, Val loss 0.04
# Saved model
# Epoch 10, Loss 0.06, Val loss 0.04
# Saved model
# Epoch 11, Loss 0.06, Val loss 0.03
# Epoch 12, Loss 0.06, Val loss 0.03
# Epoch 13, Loss 0.05, Val loss 0.04
# Epoch 14, Loss 0.06, Val loss 0.04
# Epoch 15, Loss 0.04, Val loss 0.06
# Epoch 16, Loss 0.05, Val loss 0.05
# Epoch 17, Loss 0.04, Val loss 0.07
# Epoch 18, Loss 0.05, Val loss 0.07
# Epoch 19, Loss 0.05, Val loss 0.07
# Epoch 20, Loss 0.04, Val loss 0.07
# Epoch 21, Loss 0.06, Val loss 0.06
# Epoch 22, Loss 0.05, Val loss 0.04
# Epoch 23, Loss 0.05, Val loss 0.03
# Saved model
# Epoch 24, Loss 0.04, Val loss 0.03
# Epoch 25, Loss 0.04, Val loss 0.03
# Epoch 26, Loss 0.04, Val loss 0.04
# Epoch 27, Loss 0.04, Val loss 0.05
# Epoch 28, Loss 0.04, Val loss 0.05
# Epoch 29, Loss 0.04, Val loss 0.06
# Epoch 30, Loss 0.04, Val loss 0.07
# Epoch 31, Loss 0.04, Val loss 0.06
# Epoch 32, Loss 0.06, Val loss 0.06
# Epoch 33, Loss 0.04, Val loss 0.05
# Epoch 34, Loss 0.04, Val loss 0.04
# Epoch 35, Loss 0.03, Val loss 0.04
# Epoch 36, Loss 0.04, Val loss 0.04
# Epoch 37, Loss 0.03, Val loss 0.05
# Epoch 38, Loss 0.03, Val loss 0.05
# Epoch 39, Loss 0.03, Val loss 0.05
# Epoch 40, Loss 0.03, Val loss 0.04
# Epoch 41, Loss 0.03, Val loss 0.04
# Epoch 42, Loss 0.03, Val loss 0.04
# Epoch 43, Loss 0.03, Val loss 0.04
# Epoch 44, Loss 0.03, Val loss 0.05
# Epoch 45, Loss 0.03, Val loss 0.05
# Epoch 46, Loss 0.02, Val loss 0.05
# Epoch 47, Loss 0.03, Val loss 0.05
# Epoch 48, Loss 0.03, Val loss 0.05
# Epoch 49, Loss 0.02, Val loss 0.05
# TRAINING NEW LOCATION: Virginia
# Saved model
# Epoch 0, Loss 10992.93, Val loss 1223.97
# Epoch 1, Loss 72392.54, Val loss 7363.58
# Epoch 2, Loss 82512.49, Val loss 11493.21
# Epoch 3, Loss 32386.27, Val loss 7098.75
# Epoch 4, Loss 8158.92, Val loss 2454.33
# Saved model
# Epoch 5, Loss 2223.33, Val loss 891.27
# Saved model
# Epoch 6, Loss 678.46, Val loss 408.67
# Saved model
# Epoch 7, Loss 308.09, Val loss 216.30
# Saved model
# Epoch 8, Loss 170.78, Val loss 107.07
# Saved model
# Epoch 9, Loss 91.10, Val loss 74.41
# Saved model
# Epoch 10, Loss 79.48, Val loss 38.15
# Saved model
# Epoch 11, Loss 41.61, Val loss 27.09
# Saved model
# Epoch 12, Loss 31.61, Val loss 14.94
# Saved model
# Epoch 13, Loss 24.29, Val loss 9.41
# Saved model
# Epoch 14, Loss 17.28, Val loss 7.29
# Saved model
# Epoch 15, Loss 13.66, Val loss 5.11
# Saved model
# Epoch 16, Loss 11.26, Val loss 4.31
# Saved model
# Epoch 17, Loss 10.34, Val loss 3.06
# Saved model
# Epoch 18, Loss 9.03, Val loss 2.97
# Saved model
# Epoch 19, Loss 8.32, Val loss 2.03
# Saved model
# Epoch 20, Loss 7.45, Val loss 1.80
# Saved model
# Epoch 21, Loss 7.65, Val loss 1.62
# Saved model
# Epoch 22, Loss 6.40, Val loss 1.61
# Epoch 23, Loss 6.31, Val loss 2.04
# Saved model
# Epoch 24, Loss 5.21, Val loss 1.24
# Epoch 25, Loss 5.26, Val loss 1.28
# Saved model
# Epoch 26, Loss 5.12, Val loss 0.86
# Epoch 27, Loss 4.68, Val loss 1.14
# Saved model
# Epoch 28, Loss 4.44, Val loss 0.71
# Epoch 29, Loss 4.52, Val loss 0.78
# Epoch 30, Loss 4.44, Val loss 0.72
# Epoch 31, Loss 4.03, Val loss 0.79
# Saved model
# Epoch 32, Loss 4.16, Val loss 0.65
# Epoch 9, Loss 0.23, Val loss 8.94
# Epoch 10, Loss 0.22, Val loss 8.72
# Epoch 11, Loss 0.21, Val loss 8.66
# Epoch 12, Loss 0.17, Val loss 8.52
# Epoch 13, Loss 0.17, Val loss 8.47
# Epoch 14, Loss 0.16, Val loss 8.54
# Epoch 15, Loss 0.15, Val loss 8.55
# Epoch 16, Loss 0.14, Val loss 8.56
# Epoch 17, Loss 0.13, Val loss 8.48
# Saved model
# Epoch 18, Loss 0.13, Val loss 8.40
# Saved model
# Epoch 19, Loss 0.15, Val loss 8.29
# Epoch 20, Loss 0.14, Val loss 8.32
# Epoch 21, Loss 0.13, Val loss 8.61
# Epoch 22, Loss 0.13, Val loss 8.59
# Epoch 23, Loss 0.13, Val loss 8.47
# Saved model
# Epoch 24, Loss 0.18, Val loss 8.27
# Saved model
# Epoch 25, Loss 0.12, Val loss 8.09
# Saved model
# Epoch 26, Loss 0.12, Val loss 8.02
# Epoch 27, Loss 0.11, Val loss 8.03
# Epoch 28, Loss 0.18, Val loss 8.15
# Epoch 29, Loss 0.13, Val loss 8.37
# Epoch 30, Loss 0.12, Val loss 8.45
# Epoch 31, Loss 0.12, Val loss 8.64
# Epoch 32, Loss 0.15, Val loss 8.59
# Epoch 33, Loss 0.11, Val loss 8.52
# Epoch 34, Loss 0.09, Val loss 8.38
# Epoch 35, Loss 0.10, Val loss 8.30
# Epoch 36, Loss 0.11, Val loss 8.27
# Epoch 37, Loss 0.11, Val loss 8.29
# Epoch 38, Loss 0.10, Val loss 8.36
# Epoch 39, Loss 0.09, Val loss 8.48
# Epoch 40, Loss 0.09, Val loss 8.54
# Epoch 41, Loss 0.09, Val loss 8.59
# Epoch 42, Loss 0.08, Val loss 8.57
# Epoch 43, Loss 0.08, Val loss 8.47
# Epoch 44, Loss 0.08, Val loss 8.33
# Epoch 45, Loss 0.08, Val loss 8.21
# Epoch 46, Loss 0.08, Val loss 8.13
# Epoch 47, Loss 0.07, Val loss 8.16
# Epoch 48, Loss 0.07, Val loss 8.20
# Epoch 49, Loss 0.07, Val loss 8.21
# TRAINING NEW LOCATION: Wyoming
# Saved model
# Epoch 0, Loss 0.79, Val loss 1.10
# Saved model
# Epoch 1, Loss 0.34, Val loss 1.03
# Saved model
# Epoch 2, Loss 0.15, Val loss 0.96
# Saved model
# Epoch 3, Loss 0.12, Val loss 0.80
# Saved model
# Epoch 4, Loss 0.07, Val loss 0.77
# Epoch 5, Loss 0.07, Val loss 0.81
# Epoch 6, Loss 0.07, Val loss 0.85
# Epoch 7, Loss 0.08, Val loss 0.84
# Epoch 8, Loss 0.06, Val loss 0.83
# Epoch 9, Loss 0.06, Val loss 0.86
# Epoch 10, Loss 0.05, Val loss 0.85
# Epoch 11, Loss 0.07, Val loss 0.85
# Epoch 12, Loss 0.07, Val loss 0.83
# Epoch 13, Loss 0.06, Val loss 0.88
# Epoch 14, Loss 0.05, Val loss 0.83
# Epoch 15, Loss 0.04, Val loss 0.83
# Saved model
# Epoch 16, Loss 0.06, Val loss 0.77
# Epoch 17, Loss 0.07, Val loss 0.78
# Epoch 18, Loss 0.05, Val loss 0.81
# Epoch 19, Loss 0.05, Val loss 0.83
# Epoch 20, Loss 0.04, Val loss 0.86
# Epoch 21, Loss 0.05, Val loss 0.85
# Epoch 22, Loss 0.04, Val loss 0.85
# Epoch 23, Loss 0.04, Val loss 0.84
# Epoch 24, Loss 0.04, Val loss 0.78
# Saved model
# Epoch 25, Loss 0.04, Val loss 0.76
# Saved model
# Epoch 26, Loss 0.04, Val loss 0.72
# Epoch 27, Loss 0.05, Val loss 0.72
# Epoch 28, Loss 0.04, Val loss 0.75
# Epoch 29, Loss 0.04, Val loss 0.79
# Epoch 30, Loss 0.04, Val loss 0.78
# Epoch 31, Loss 0.04, Val loss 0.76
# Epoch 32, Loss 0.06, Val loss 0.77
# Epoch 33, Loss 0.04, Val loss 0.78
# Epoch 34, Loss 0.04, Val loss 0.75
# Epoch 35, Loss 0.04, Val loss 0.73
# Epoch 36, Loss 0.05, Val loss 0.75
# Epoch 37, Loss 0.04, Val loss 0.74
# Epoch 38, Loss 0.03, Val loss 0.73
# Saved model
# Epoch 39, Loss 0.03, Val loss 0.72
# Saved model
# Epoch 40, Loss 0.03, Val loss 0.70
# Epoch 41, Loss 0.03, Val loss 0.71
# Epoch 42, Loss 0.03, Val loss 0.72
# Epoch 43, Loss 0.03, Val loss 0.72
# Saved model
# Epoch 44, Loss 0.03, Val loss 0.70
# Saved model
# Epoch 45, Loss 0.03, Val loss 0.69
# Saved model
# Epoch 46, Loss 0.03, Val loss 0.68
# Epoch 47, Loss 0.03, Val loss 0.68
# Saved model
# Epoch 48, Loss 0.03, Val loss 0.66
# Epoch 49, Loss 0.03, Val loss 0.68

# %%
#Pred with STAN

model_predictions_number_infected_dictionary = {}
model_predictions_number_infected_list = []

for loc_name in loc_list:
  file_name = './save/old_data/50_epochs_timed/' + loc_name
  checkpoint = torch.load(file_name)
  model = STAN(g, in_dim, hidden_dim1, hidden_dim2, gru_dim, num_heads, pred_window, device).to(device)
  model.load_state_dict(checkpoint['state'])
  model.eval()

  prev_x = torch.cat((train_x, val_x), dim=1)
  prev_I = torch.cat((train_I, val_I), dim=1)
  prev_R = torch.cat((train_R, val_R), dim=1)
  prev_cI = torch.cat((train_cI, val_cI), dim=1)
  prev_cR = torch.cat((train_cR, val_cR), dim=1)

  cur_loc = loc_list.index(loc_name)

  prev_active_pred, _, prev_phyactive_pred, _, h = model(prev_x, prev_cI[cur_loc], prev_cR[cur_loc], N[cur_loc], prev_I[cur_loc], prev_R[cur_loc])

  test_pred_active, test_pred_recovered, test_pred_phy_active, test_pred_phy_recover, _ = model(test_x, test_cI[cur_loc], test_cR[cur_loc], N[cur_loc], test_I[cur_loc], test_R[cur_loc], h)

  # Cumulate predicted dI
  pred_I = []

  for i in range(test_pred_active.size(1)):
      cur_pred = (test_pred_active[0, i, :].detach().cpu().numpy() * dI_std[cur_loc].reshape(1, 1).detach().cpu().numpy()) + dI_mean[cur_loc].reshape(1, 1).detach().cpu().numpy()
      #cur_pred = test_pred_phy_active[0, i, :].detach().cpu().numpy()
      cur_pred = (cur_pred + test_pred_phy_active[0, i, :].detach().cpu().numpy()) / 2
      cur_pred = np.cumsum(cur_pred)
      cur_pred = cur_pred + test_I[cur_loc, i].detach().cpu().item()
      pred_I.append(cur_pred)

  model_predictions_number_infected_list.append(pred_I)  
  # pred_I = np.array(pred_I)
  # pred_I = pred_I

  model_predictions_number_infected_dictionary[loc_name] = np.array(pred_I)[-1, :]

model_predictions_number_infected_tensor = torch.tensor(model_predictions_number_infected_list)
model_predictions_number_infected = model_predictions_number_infected_tensor.reshape((len(loc_list), pred_window)) # (52, 1, 15) --> (52, 15)

# %%
# Get the ground truth values for number of infected people 
ground_truth_number_infected_dictionary = {}
ground_truth_number_infected_tensor = test_active_cases

test_active_cases_tensor = test_active_cases.reshape((len(loc_list), pred_window)) # (52, 1, 15) --> (52, 15)

for loc_name in loc_list:
  cur_loc = loc_list.index(loc_name)
  ground_truth_number_infected_dictionary[loc_name] = test_active_cases_tensor[cur_loc]

# %%
archived_output = {
    'loc_list':loc_list, 
    'model_predictions_number_infected_dictionary':model_predictions_number_infected_dictionary, 
    'model_predictions_number_infected_tensor':model_predictions_number_infected_tensor, # (52, 15)
    'ground_truth_number_infected_dictionary':ground_truth_number_infected_dictionary, 
    'ground_truth_number_infected_tensor':test_active_cases_tensor # (52, 15)
}

import pickle

# Save archived_output as pickle for use later
with open('./save/old_data/50_epochs_timed/archived_output_50_epochs.pickle', 'wb') as handle:
    pickle.dump(archived_output, handle)


# # Load in archived_output pickle
# archived_output = None
# with open('./save/old_data/50_epochs_timed/archived_output_50_epochs.pickle', 'rb') as handle:
#     archived_output = pickle.load(handle)


# print(model_predictions_number_infected['Alabama'])
# print(ground_truth_number_infected['Alabama'])

# %%
predicted_output = model_predictions_number_infected_tensor
labeled_output = test_active_cases_tensor
mean_squared_error = criterion(predicted_output.reshape((52, 15)), labeled_output.reshape((52, 15))).item()
mae_function = torch.nn.L1Loss()
mean_absolute_error = mae_function(predicted_output.reshape((52, 15)), labeled_output.reshape((52, 15))).item()
print("mean squared error: ", mean_squared_error)
print("mean absolute error: ", mean_absolute_error)
##################################################################################
# 4/13/22 trial 1: 50 epochs, seed = 0, google colab
# mean squared error:  422452352.0
# mean absolute error:  10121.361328125

# 4/13/22 trial 2: 50 epochs, seed = 0, google colab
# mean squared error:  422452352.0
# mean absolute error:  10121.361328125
# Out:
# mean squared error:  422452352.0
# mean absolute error:  10121.361328125

# %%
time_end = time.time()
time_seconds = time_end - time_start
(t_min, t_sec) = divmod(time_seconds,60)
(t_hour,t_min) = divmod(t_min,60) 
print('Time passed: {} hours:{} minutes:{} seconds'.format(t_hour,t_min,t_sec))
###################################################################################
# 4/13/22 trial 1: 50 epochs, seed = 0, google colab
# Time passed: 0.0 hours:25.0 minutes:59.541184425354004 seconds

# 4/13/22 trial 2: 50 epochs, seed = 0, google colab
# Time passed: 0.0 hours:26.0 minutes:44.246944427490234 seconds
# Out:
# Time passed: 0.0 hours:26.0 minutes:44.246944427490234 seconds
# Time passed: 0.0 hours:26.0 minutes:44.246944427490234 seconds
