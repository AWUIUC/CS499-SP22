# %%
# Mount this colab file correctly in google drive so I can access relative/local files
from google.colab import drive
drive.mount('/content/gdrive')
% cd /content/gdrive/My Drive/Github/"CS 499 - SPRING 2022"/"1. STAN - Original"
! pwd

# Install python packages I will need in the local environment
! pip install epiweeks
! pip install haversine
! pip install dgl-cu111 -f https://data.dgl.ai/wheels/repo.html
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# /content/gdrive/My Drive/Github/CS 499 - SPRING 2022/1. STAN - Original
# /content/gdrive/My Drive/Github/CS 499 - SPRING 2022/1. STAN - Original
# Requirement already satisfied: epiweeks in /usr/local/lib/python3.7/dist-packages (2.1.4)
# Requirement already satisfied: haversine in /usr/local/lib/python3.7/dist-packages (2.5.1)
# Looking in links: https://data.dgl.ai/wheels/repo.html
# Requirement already satisfied: dgl-cu111 in /usr/local/lib/python3.7/dist-packages (0.8.0)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from dgl-cu111) (1.4.1)
# Requirement already satisfied: networkx>=2.1 in /usr/local/lib/python3.7/dist-packages (from dgl-cu111) (2.6.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from dgl-cu111) (2.23.0)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.7/dist-packages (from dgl-cu111) (1.21.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from dgl-cu111) (4.63.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->dgl-cu111) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->dgl-cu111) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->dgl-cu111) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->dgl-cu111) (3.0.4)

# %%
import csv
import os

import numpy as np
import pandas as pd
from epiweeks import Week

from data_downloader import GenerateTrainingData
from utils import date_today, gravity_law_commute_dist

os.environ['NUMEXPR_MAX_THREADS'] = '16'
os.environ['NUMEXPR_NUM_THREADS'] = '8'

import pickle
import matplotlib.pyplot as plt
import dgl
import torch
from torch import nn
import torch.nn.functional as F
from model import STAN

import sklearn
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

# %%
GenerateTrainingData().download_jhu_data('2020-05-01', '2020-12-01')
# Out:
# Finish download
#       state  latitude  longitude  fips date_today  confirmed  deaths  \
# 0   Alabama   32.3182   -86.9023     1 2020-05-04       8203       8
# 0   Alabama   32.3182   -86.9023     1 2020-05-05       8520      17
# 0   Alabama   32.3182   -86.9023     1 2020-05-06       8769      28
# 0   Alabama   32.3182   -86.9023     1 2020-05-07       9115      26
# 0   Alabama   32.3182   -86.9023     1 2020-05-08       9437      14
# ..      ...       ...        ...   ...        ...        ...     ...
# 57  Wyoming   42.7560  -107.3025    56 2020-11-27      31773       0
# 57  Wyoming   42.7560  -107.3025    56 2020-11-28      31928       0
# 57  Wyoming   42.7560  -107.3025    56 2020-11-29      32489       0
# 57  Wyoming   42.7560  -107.3025    56 2020-11-30      33305       0
# 57  Wyoming   42.7560  -107.3025    56 2020-12-01      33805      24
#
#     recovered  active  hospitalization  new_cases
# 0         0.0  7905.0              0.0        226
# 0         0.0     0.0              0.0        317
# 0         0.0     0.0              0.0        249
# 0         0.0     0.0              0.0        346
# 0         0.0     0.0              0.0        322
# ..        ...     ...              ...        ...
# 57    21700.0  9858.0              4.0       1012
# 57    22798.0  8915.0              4.0        155
# 57    23022.0  9252.0              2.0        561
# 57    24478.0  8612.0              0.0        816
# 57    26003.0  7563.0              2.0        500
#
# [12296 rows x 11 columns]

# %%
#Merge population data with downloaded data
raw_data = pickle.load(open('./data/state_covid_data.pickle','rb'))
pop_data = pd.read_csv('./uszips.csv')
pop_data = pop_data.groupby('state_name').agg({'population':'sum', 'density':'mean', 'lat':'mean', 'lng':'mean'}).reset_index()
raw_data = pd.merge(raw_data, pop_data, how='inner', left_on='state', right_on='state_name')

# %%
# Generate location similarity
loc_list = list(raw_data['state'].unique())
loc_dist_map = {}

for each_loc in loc_list:
    loc_dist_map[each_loc] = {}
    for each_loc2 in loc_list:
        lat1 = raw_data[raw_data['state']==each_loc]['latitude'].unique()[0]
        lng1 = raw_data[raw_data['state']==each_loc]['longitude'].unique()[0]
        pop1 = raw_data[raw_data['state']==each_loc]['population'].unique()[0]
        
        lat2 = raw_data[raw_data['state']==each_loc2]['latitude'].unique()[0]
        lng2 = raw_data[raw_data['state']==each_loc2]['longitude'].unique()[0]
        pop2 = raw_data[raw_data['state']==each_loc2]['population'].unique()[0]
        
        loc_dist_map[each_loc][each_loc2] = gravity_law_commute_dist(lat1, lng1, pop1, lat2, lng2, pop2, r=0.5)

# %%
#Generate Graph
dist_threshold = 18

for each_loc in loc_dist_map:
    loc_dist_map[each_loc] = {k: v for k, v in sorted(loc_dist_map[each_loc].items(), key=lambda item: item[1], reverse=True)}
    
adj_map = {}
for each_loc in loc_dist_map:
    adj_map[each_loc] = []
    for i, each_loc2 in enumerate(loc_dist_map[each_loc]):
        if loc_dist_map[each_loc][each_loc2] > dist_threshold:
            if i <= 3:
                adj_map[each_loc].append(each_loc2)
            else:
                break
        else:
            if i <= 1:
                adj_map[each_loc].append(each_loc2)
            else:
                break

rows = []
cols = []
for each_loc in adj_map:
    for each_loc2 in adj_map[each_loc]:
        rows.append(loc_list.index(each_loc))
        cols.append(loc_list.index(each_loc2))

# %%
g = dgl.graph((rows, cols))

# %%
#Preprocess features

active_cases = []
confirmed_cases = []
new_cases = []
death_cases = []
static_feat = []

for i, each_loc in enumerate(loc_list):
    active_cases.append(raw_data[raw_data['state'] == each_loc]['active'])
    confirmed_cases.append(raw_data[raw_data['state'] == each_loc]['confirmed'])
    new_cases.append(raw_data[raw_data['state'] == each_loc]['new_cases'])
    death_cases.append(raw_data[raw_data['state'] == each_loc]['deaths'])
    static_feat.append(np.array(raw_data[raw_data['state'] == each_loc][['population','density','lng','lat']]))
    
active_cases = np.array(active_cases)
confirmed_cases = np.array(confirmed_cases)
death_cases = np.array(death_cases)
new_cases = np.array(new_cases)
static_feat = np.array(static_feat)[:, 0, :]
recovered_cases = confirmed_cases - active_cases - death_cases
susceptible_cases = np.expand_dims(static_feat[:, 0], -1) - active_cases - recovered_cases

# Batch_feat: new_cases(dI), dR, dS
#dI = np.array(new_cases)
dI = np.concatenate((np.zeros((active_cases.shape[0],1), dtype=np.float32), np.diff(active_cases)), axis=-1)
dR = np.concatenate((np.zeros((recovered_cases.shape[0],1), dtype=np.float32), np.diff(recovered_cases)), axis=-1)
dS = np.concatenate((np.zeros((susceptible_cases.shape[0],1), dtype=np.float32), np.diff(susceptible_cases)), axis=-1)

# %%
#Build normalizer
normalizer = {'S':{}, 'I':{}, 'R':{}, 'dS':{}, 'dI':{}, 'dR':{}}

for i, each_loc in enumerate(loc_list):
    normalizer['S'][each_loc] = (np.mean(susceptible_cases[i]), np.std(susceptible_cases[i]))
    normalizer['I'][each_loc] = (np.mean(active_cases[i]), np.std(active_cases[i]))
    normalizer['R'][each_loc] = (np.mean(recovered_cases[i]), np.std(recovered_cases[i]))
    normalizer['dI'][each_loc] = (np.mean(dI[i]), np.std(dI[i]))
    normalizer['dR'][each_loc] = (np.mean(dR[i]), np.std(dR[i]))
    normalizer['dS'][each_loc] = (np.mean(dS[i]), np.std(dS[i]))

# %%
def prepare_data(data, sum_I, sum_R, history_window=5, pred_window=15, slide_step=5):
    # Data shape n_loc, timestep, n_feat
    # Reshape to n_loc, t, history_window*n_feat
    n_loc = data.shape[0]
    timestep = data.shape[1]
    n_feat = data.shape[2]
    
    x = []
    y_I = []
    y_R = []
    last_I = []
    last_R = []
    concat_I = []
    concat_R = []
    for i in range(0, timestep, slide_step):
        if i+history_window+pred_window-1 >= timestep or i+history_window >= timestep:
            break
        x.append(data[:, i:i+history_window, :].reshape((n_loc, history_window*n_feat)))
        
        concat_I.append(data[:, i+history_window-1, 0])
        concat_R.append(data[:, i+history_window-1, 1])
        last_I.append(sum_I[:, i+history_window-1])
        last_R.append(sum_R[:, i+history_window-1])

        y_I.append(data[:, i+history_window:i+history_window+pred_window, 0])
        y_R.append(data[:, i+history_window:i+history_window+pred_window, 1])

    x = np.array(x, dtype=np.float32).transpose((1, 0, 2))
    last_I = np.array(last_I, dtype=np.float32).transpose((1, 0))
    last_R = np.array(last_R, dtype=np.float32).transpose((1, 0))
    concat_I = np.array(concat_I, dtype=np.float32).transpose((1, 0))
    concat_R = np.array(concat_R, dtype=np.float32).transpose((1, 0))
    y_I = np.array(y_I, dtype=np.float32).transpose((1, 0, 2))
    y_R = np.array(y_R, dtype=np.float32).transpose((1, 0, 2))
    return x, last_I, last_R, concat_I, concat_R, y_I, y_R

# %%
valid_window = 25
test_window = 25

history_window=6
pred_window=15
slide_step=5

dynamic_feat = np.concatenate((np.expand_dims(dI, axis=-1), np.expand_dims(dR, axis=-1), np.expand_dims(dS, axis=-1)), axis=-1)
    
#Normalize
for i, each_loc in enumerate(loc_list):
    dynamic_feat[i, :, 0] = (dynamic_feat[i, :, 0] - normalizer['dI'][each_loc][0]) / normalizer['dI'][each_loc][1]
    dynamic_feat[i, :, 1] = (dynamic_feat[i, :, 1] - normalizer['dR'][each_loc][0]) / normalizer['dR'][each_loc][1]
    dynamic_feat[i, :, 2] = (dynamic_feat[i, :, 2] - normalizer['dS'][each_loc][0]) / normalizer['dS'][each_loc][1]

dI_mean = []
dI_std = []
dR_mean = []
dR_std = []

for i, each_loc in enumerate(loc_list):
    dI_mean.append(normalizer['dI'][each_loc][0])
    dR_mean.append(normalizer['dR'][each_loc][0])
    dI_std.append(normalizer['dI'][each_loc][1])
    dR_std.append(normalizer['dR'][each_loc][1])

dI_mean = np.array(dI_mean)
dI_std = np.array(dI_std)
dR_mean = np.array(dR_mean)
dR_std = np.array(dR_std)

#Split train-test
train_feat = dynamic_feat[:, :-valid_window-test_window, :]
val_feat = dynamic_feat[:, -valid_window-test_window:-test_window, :]
test_feat = dynamic_feat[:, -test_window:, :]

train_x, train_I, train_R, train_cI, train_cR, train_yI, train_yR = prepare_data(train_feat, active_cases[:, :-valid_window-test_window], recovered_cases[:, :-valid_window-test_window], history_window, pred_window, slide_step)
val_x, val_I, val_R, val_cI, val_cR, val_yI, val_yR = prepare_data(val_feat, active_cases[:, -valid_window-test_window:-test_window], recovered_cases[:, -valid_window-test_window:-test_window], history_window, pred_window, slide_step)
test_x, test_I, test_R, test_cI, test_cR, test_yI, test_yR = prepare_data(test_feat, active_cases[:, -test_window:], recovered_cases[:, -test_window:], history_window, pred_window, slide_step)

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

train_x = torch.tensor(train_x).to(device)
train_I = torch.tensor(train_I).to(device)
train_R = torch.tensor(train_R).to(device)
train_cI = torch.tensor(train_cI).to(device)
train_cR = torch.tensor(train_cR).to(device)
train_yI = torch.tensor(train_yI).to(device)
train_yR = torch.tensor(train_yR).to(device)

val_x = torch.tensor(val_x).to(device)
val_I = torch.tensor(val_I).to(device)
val_R = torch.tensor(val_R).to(device)
val_cI = torch.tensor(val_cI).to(device)
val_cR = torch.tensor(val_cR).to(device)
val_yI = torch.tensor(val_yI).to(device)
val_yR = torch.tensor(val_yR).to(device)

test_x = torch.tensor(test_x).to(device)
test_I = torch.tensor(test_I).to(device)
test_R = torch.tensor(test_R).to(device)
test_cI = torch.tensor(test_cI).to(device)
test_cR = torch.tensor(test_cR).to(device)
test_yI = torch.tensor(test_yI).to(device)
test_yR = torch.tensor(test_yR).to(device)

dI_mean = torch.tensor(dI_mean, dtype=torch.float32).to(device).reshape((dI_mean.shape[0], 1, 1))
dI_std = torch.tensor(dI_std, dtype=torch.float32).to(device).reshape((dI_mean.shape[0], 1, 1))
dR_mean = torch.tensor(dR_mean, dtype=torch.float32).to(device).reshape((dI_mean.shape[0], 1, 1))
dR_std = torch.tensor(dR_std, dtype=torch.float32).to(device).reshape((dI_mean.shape[0], 1, 1))

N = torch.tensor(static_feat[:, 0], dtype=torch.float32).to(device).unsqueeze(-1)

# %%
#Train STAN

# Hyperparameters
in_dim = 3*history_window
hidden_dim1 = 32
hidden_dim2 = 32
gru_dim = 32
num_heads = 1


# Build STAN model for each state
for loc_name in loc_list:
    print("TRAINING NEW LOCATION:", loc_name)
    g = g.to(device)
    model = STAN(g, in_dim, hidden_dim1, hidden_dim2, gru_dim, num_heads, pred_window, device).to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-2)
    criterion = nn.MSELoss()

    all_loss = []
    file_name = './save/stan_' + loc_name
    min_loss = 1e10

    cur_loc = loc_list.index(loc_name)

    for epoch in range(50):
        model.train()
        optimizer.zero_grad()
        
        active_pred, recovered_pred, phy_active, phy_recover, _ = model(train_x, train_cI[cur_loc], train_cR[cur_loc], N[cur_loc], train_I[cur_loc], train_R[cur_loc])
        phy_active = (phy_active - dI_mean[cur_loc]) / dI_std[cur_loc]
        phy_recover = (phy_recover - dR_mean[cur_loc]) / dR_std[cur_loc]
        loss = criterion(active_pred.squeeze(), train_yI[cur_loc])+criterion(recovered_pred.squeeze(), train_yR[cur_loc])+0.1*criterion(phy_active.squeeze(), train_yI[cur_loc])+0.1*criterion(phy_recover.squeeze(), train_yR[cur_loc])
        
        loss.backward()
        optimizer.step()
        all_loss.append(loss.item())
        
        model.eval()
        _, _, _, _, prev_h = model(train_x, train_cI[cur_loc], train_cR[cur_loc], N[cur_loc], train_I[cur_loc], train_R[cur_loc])
        val_active_pred, val_recovered_pred, val_phy_active, val_phy_recover, _ = model(val_x, val_cI[cur_loc], val_cR[cur_loc], N[cur_loc], val_I[cur_loc], val_R[cur_loc], prev_h)
        
        val_phy_active = (val_phy_active - dI_mean[cur_loc]) / dI_std[cur_loc]
        val_loss = criterion(val_active_pred.squeeze(), val_yI[cur_loc]) + 0.1*criterion(val_phy_active.squeeze(), val_yI[cur_loc])
        if val_loss < min_loss:    
            state = {
                'state': model.state_dict(),
                'optimizer': optimizer.state_dict(),
            }
            torch.save(state, file_name)
            min_loss = val_loss
            print('Saved model')
        
        print('Epoch %d, Loss %.2f, Val loss %.2f'%(epoch, all_loss[-1], val_loss.item()))
# Out:
# TRAINING NEW LOCATION: Alabama
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/loss.py:520: UserWarning: Using a target size (torch.Size([1, 15])) that is different to the input size (torch.Size([15])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Saved model
# Epoch 0, Loss 1.27, Val loss 3.28
# Saved model
# Epoch 1, Loss 9.68, Val loss 0.84
# Saved model
# Epoch 2, Loss 1.02, Val loss 0.23
# Saved model
# Epoch 3, Loss 0.37, Val loss 0.18
# Epoch 4, Loss 0.26, Val loss 0.18
# Saved model
# Epoch 5, Loss 0.23, Val loss 0.18
# Epoch 6, Loss 0.23, Val loss 0.18
# Saved model
# Epoch 7, Loss 0.23, Val loss 0.17
# Saved model
# Epoch 8, Loss 0.22, Val loss 0.17
# Saved model
# Epoch 9, Loss 0.19, Val loss 0.16
# Epoch 10, Loss 0.18, Val loss 0.17
# Saved model
# Epoch 11, Loss 0.18, Val loss 0.16
# Saved model
# Epoch 12, Loss 0.17, Val loss 0.15
# Epoch 13, Loss 0.17, Val loss 0.15
# Saved model
# Epoch 14, Loss 0.18, Val loss 0.12
# Epoch 15, Loss 0.16, Val loss 0.13
# Epoch 16, Loss 0.15, Val loss 0.14
# Epoch 17, Loss 0.18, Val loss 0.14
# Epoch 18, Loss 0.16, Val loss 0.16
# Epoch 19, Loss 0.16, Val loss 0.16
# Epoch 20, Loss 0.15, Val loss 0.17
# Epoch 21, Loss 0.15, Val loss 0.14
# Epoch 22, Loss 0.14, Val loss 0.17
# Epoch 23, Loss 0.14, Val loss 0.15
# Epoch 24, Loss 0.14, Val loss 0.16
# Epoch 25, Loss 0.14, Val loss 0.16
# Epoch 26, Loss 0.14, Val loss 0.16
# Epoch 27, Loss 0.14, Val loss 0.16
# Epoch 28, Loss 0.14, Val loss 0.15
# Epoch 29, Loss 0.14, Val loss 0.15
# Epoch 30, Loss 0.13, Val loss 0.14
# Epoch 31, Loss 0.14, Val loss 0.15
# Epoch 32, Loss 0.13, Val loss 0.18
# Epoch 33, Loss 0.13, Val loss 0.17
# Epoch 34, Loss 0.13, Val loss 0.18
# Epoch 35, Loss 0.14, Val loss 0.17
# Epoch 36, Loss 0.13, Val loss 0.15
# Epoch 37, Loss 0.14, Val loss 0.14
# Epoch 38, Loss 0.13, Val loss 0.14
# Epoch 39, Loss 0.13, Val loss 0.15
# Epoch 40, Loss 0.13, Val loss 0.15
# Epoch 41, Loss 0.13, Val loss 0.18
# Epoch 42, Loss 0.12, Val loss 0.16
# Epoch 43, Loss 0.13, Val loss 0.16
# Epoch 44, Loss 0.12, Val loss 0.16
# Epoch 45, Loss 0.12, Val loss 0.15
# Epoch 46, Loss 0.12, Val loss 0.15
# Epoch 47, Loss 0.12, Val loss 0.15
# Epoch 48, Loss 0.12, Val loss 0.14
# Epoch 49, Loss 0.12, Val loss 0.14
# TRAINING NEW LOCATION: Alaska
# Saved model
# Epoch 0, Loss 37.97, Val loss 292.32
# Epoch 1, Loss 916.30, Val loss 947.34
# Epoch 2, Loss 1052.95, Val loss 747.17
# Saved model
# Epoch 3, Loss 346.45, Val loss 130.63
# Saved model
# Epoch 4, Loss 50.73, Val loss 31.66
# Saved model
# Epoch 5, Loss 11.47, Val loss 12.16
# Saved model
# Epoch 6, Loss 4.99, Val loss 6.83
# Saved model
# Epoch 7, Loss 3.07, Val loss 5.40
# Saved model
# Epoch 8, Loss 2.40, Val loss 4.90
# Epoch 9, Loss 2.02, Val loss 4.92
# Saved model
# Epoch 10, Loss 1.79, Val loss 4.70
# Saved model
# Epoch 11, Loss 1.71, Val loss 4.57
# Saved model
# Epoch 12, Loss 1.67, Val loss 4.49
# Saved model
# Epoch 13, Loss 1.61, Val loss 4.39
# Saved model
# Epoch 14, Loss 1.56, Val loss 4.31
# Saved model
# Epoch 15, Loss 1.50, Val loss 4.19
# Saved model
# Epoch 16, Loss 1.48, Val loss 4.12
# Saved model
# Epoch 17, Loss 1.46, Val loss 4.05
# Saved model
# Epoch 18, Loss 1.44, Val loss 3.99
# Epoch 19, Loss 1.42, Val loss 4.02
# Saved model
# Epoch 20, Loss 1.41, Val loss 3.99
# Epoch 21, Loss 1.38, Val loss 4.01
# Epoch 22, Loss 1.36, Val loss 4.00
# Saved model
# Epoch 23, Loss 1.36, Val loss 3.97
# Saved model
# Epoch 24, Loss 1.35, Val loss 3.93
# Saved model
# Epoch 25, Loss 1.35, Val loss 3.92
# Saved model
# Epoch 26, Loss 1.32, Val loss 3.85
# Saved model
# Epoch 27, Loss 1.31, Val loss 3.80
# Saved model
# Epoch 28, Loss 1.31, Val loss 3.79
# Saved model
# Epoch 29, Loss 1.28, Val loss 3.79
# Epoch 30, Loss 1.30, Val loss 3.88
# Epoch 31, Loss 1.28, Val loss 3.90
# Epoch 32, Loss 1.26, Val loss 3.97
# Epoch 33, Loss 1.26, Val loss 4.03
# Epoch 34, Loss 1.24, Val loss 4.09
# Epoch 35, Loss 1.23, Val loss 4.15
# Epoch 36, Loss 1.23, Val loss 4.10
# Epoch 37, Loss 1.23, Val loss 4.14
# Epoch 38, Loss 1.23, Val loss 4.14
# Epoch 39, Loss 1.21, Val loss 4.12
# Epoch 40, Loss 1.22, Val loss 4.13
# Epoch 41, Loss 1.23, Val loss 4.07
# Epoch 42, Loss 1.20, Val loss 4.11
# Epoch 43, Loss 1.21, Val loss 4.08
# Epoch 44, Loss 1.18, Val loss 4.08
# Epoch 45, Loss 1.20, Val loss 4.04
# Epoch 46, Loss 1.19, Val loss 4.02
# Epoch 47, Loss 1.17, Val loss 4.07
# Epoch 48, Loss 1.19, Val loss 4.06
# Epoch 49, Loss 1.15, Val loss 4.09
# TRAINING NEW LOCATION: Arizona
# Saved model
# Epoch 0, Loss 12195.27, Val loss 1521.80
# Epoch 1, Loss 138682.80, Val loss 4722.42
# Epoch 2, Loss 71775.29, Val loss 6901.10
# Epoch 3, Loss 28317.95, Val loss 6676.85
# Epoch 4, Loss 12258.55, Val loss 4808.11
# Epoch 5, Loss 5146.28, Val loss 2463.78
# Saved model
# Epoch 6, Loss 2017.88, Val loss 991.43
# Saved model
# Epoch 7, Loss 702.45, Val loss 395.76
# Saved model
# Epoch 8, Loss 282.07, Val loss 175.04
# Saved model
# Epoch 9, Loss 124.51, Val loss 76.87
# Saved model
# Epoch 10, Loss 60.73, Val loss 44.75
# Saved model
# Epoch 11, Loss 32.95, Val loss 29.36
# Saved model
# Epoch 12, Loss 23.37, Val loss 16.08
# Saved model
# Epoch 13, Loss 14.65, Val loss 11.52
# Saved model
# Epoch 14, Loss 10.84, Val loss 8.50
# Saved model
# Epoch 15, Loss 7.81, Val loss 5.12
# Saved model
# Epoch 16, Loss 6.50, Val loss 4.16
# Saved model
# Epoch 17, Loss 5.59, Val loss 3.12
# Saved model
# Epoch 18, Loss 4.57, Val loss 2.92
# Saved model
# Epoch 19, Loss 4.05, Val loss 1.91
# Saved model
# Epoch 20, Loss 3.68, Val loss 1.75
# Saved model
# Epoch 21, Loss 3.36, Val loss 1.47
# Saved model
# Epoch 22, Loss 2.96, Val loss 1.23
# Saved model
# Epoch 23, Loss 2.75, Val loss 1.07
# Saved model
# Epoch 24, Loss 2.62, Val loss 0.91
# Epoch 25, Loss 2.45, Val loss 0.93
# Saved model
# Epoch 26, Loss 2.26, Val loss 0.80
# Saved model
# Epoch 27, Loss 2.13, Val loss 0.67
# Saved model
# Epoch 28, Loss 2.11, Val loss 0.60
# Saved model
# Epoch 29, Loss 2.01, Val loss 0.56
# Saved model
# Epoch 30, Loss 1.89, Val loss 0.53
# Saved model
# Epoch 31, Loss 1.92, Val loss 0.51
# Saved model
# Epoch 32, Loss 1.90, Val loss 0.42
# Epoch 33, Loss 1.77, Val loss 0.48
# Epoch 34, Loss 1.71, Val loss 0.43
# Epoch 35, Loss 1.74, Val loss 0.44
# Epoch 36, Loss 1.65, Val loss 0.43
# Saved model
# Epoch 37, Loss 1.66, Val loss 0.35
# Epoch 38, Loss 1.58, Val loss 0.36
# Epoch 39, Loss 1.57, Val loss 0.41
# Epoch 40, Loss 1.52, Val loss 0.36
# Saved model
# Epoch 41, Loss 1.56, Val loss 0.32
# Epoch 42, Loss 1.47, Val loss 0.36
# Saved model
# Epoch 43, Loss 1.45, Val loss 0.32
# Saved model
# Epoch 44, Loss 1.49, Val loss 0.31
# Saved model
# Epoch 45, Loss 1.42, Val loss 0.30
# Epoch 46, Loss 1.42, Val loss 0.33
# Saved model
# Epoch 47, Loss 1.39, Val loss 0.28
# Epoch 48, Loss 1.36, Val loss 0.28
# Saved model
# Epoch 49, Loss 1.33, Val loss 0.23
# TRAINING NEW LOCATION: Arkansas
# Saved model
# Epoch 0, Loss 5.21, Val loss 1.03
# Saved model
# Epoch 1, Loss 2.48, Val loss 0.83
# Epoch 2, Loss 1.82, Val loss 0.90
# Epoch 3, Loss 1.68, Val loss 0.99
# Epoch 4, Loss 1.61, Val loss 1.08
# Epoch 5, Loss 1.57, Val loss 1.15
# Epoch 6, Loss 1.55, Val loss 1.18
# Epoch 7, Loss 1.52, Val loss 1.20
# Epoch 8, Loss 1.50, Val loss 1.19
# Epoch 9, Loss 1.48, Val loss 1.15
# Epoch 10, Loss 1.47, Val loss 1.08
# Epoch 11, Loss 1.45, Val loss 1.10
# Epoch 12, Loss 1.42, Val loss 1.05
# Epoch 13, Loss 1.47, Val loss 1.10
# Epoch 14, Loss 1.40, Val loss 1.16
# Epoch 15, Loss 1.38, Val loss 1.16
# Epoch 16, Loss 1.36, Val loss 1.15
# Epoch 17, Loss 1.36, Val loss 1.17
# Epoch 18, Loss 1.34, Val loss 1.13
# Epoch 19, Loss 1.31, Val loss 1.10
# Epoch 20, Loss 1.34, Val loss 1.08
# Epoch 37, Loss 0.18, Val loss 0.00
# Epoch 38, Loss 0.18, Val loss 0.00
# Epoch 39, Loss 0.18, Val loss 0.00
# Epoch 40, Loss 0.18, Val loss 0.00
# Epoch 41, Loss 0.18, Val loss 0.00
# Epoch 42, Loss 0.18, Val loss 0.00
# Epoch 43, Loss 0.18, Val loss 0.00
# Saved model
# Epoch 44, Loss 0.18, Val loss 0.00
# Saved model
# Epoch 45, Loss 0.17, Val loss 0.00
# Saved model
# Epoch 46, Loss 0.17, Val loss 0.00
# Epoch 47, Loss 0.17, Val loss 0.00
# Epoch 48, Loss 0.17, Val loss 0.00
# Saved model
# Epoch 49, Loss 0.17, Val loss 0.00
# TRAINING NEW LOCATION: Colorado
# Saved model
# Epoch 0, Loss 9729.36, Val loss 137.75
# Epoch 1, Loss 84284.09, Val loss 693.83
# Epoch 2, Loss 46540.97, Val loss 776.33
# Epoch 3, Loss 10852.19, Val loss 345.41
# Epoch 4, Loss 2318.01, Val loss 177.49
# Saved model
# Epoch 5, Loss 1006.91, Val loss 61.75
# Saved model
# Epoch 6, Loss 289.73, Val loss 33.91
# Saved model
# Epoch 7, Loss 161.66, Val loss 14.73
# Saved model
# Epoch 8, Loss 94.49, Val loss 12.15
# Saved model
# Epoch 9, Loss 61.28, Val loss 5.26
# Saved model
# Epoch 10, Loss 33.92, Val loss 4.55
# Saved model
# Epoch 11, Loss 32.88, Val loss 3.55
# Saved model
# Epoch 12, Loss 23.77, Val loss 2.19
# Saved model
# Epoch 13, Loss 14.62, Val loss 2.02
# Saved model
# Epoch 14, Loss 16.84, Val loss 1.44
# Saved model
# Epoch 15, Loss 7.51, Val loss 1.28
# Epoch 16, Loss 10.91, Val loss 1.50
# Epoch 17, Loss 10.28, Val loss 1.53
# Saved model
# Epoch 18, Loss 8.05, Val loss 1.26
# Epoch 19, Loss 5.03, Val loss 1.32
# Epoch 20, Loss 4.27, Val loss 1.30
# Saved model
# Epoch 21, Loss 6.24, Val loss 1.20
# Saved model
# Epoch 22, Loss 6.74, Val loss 1.08
# Saved model
# Epoch 23, Loss 3.98, Val loss 1.03
# Epoch 24, Loss 4.14, Val loss 1.11
# Epoch 25, Loss 3.25, Val loss 1.10
# Epoch 26, Loss 3.53, Val loss 1.11
# Epoch 27, Loss 3.00, Val loss 1.12
# Epoch 28, Loss 3.39, Val loss 1.13
# Epoch 29, Loss 4.96, Val loss 1.16
# Epoch 30, Loss 2.52, Val loss 1.11
# Epoch 31, Loss 3.05, Val loss 1.11
# Epoch 32, Loss 2.81, Val loss 1.17
# Epoch 33, Loss 3.14, Val loss 1.11
# Epoch 34, Loss 3.04, Val loss 1.07
# Saved model
# Epoch 35, Loss 1.84, Val loss 1.01
# Epoch 36, Loss 3.56, Val loss 1.03
# Epoch 37, Loss 2.59, Val loss 1.03
# Epoch 38, Loss 2.26, Val loss 1.05
# Epoch 39, Loss 2.60, Val loss 1.10
# Epoch 40, Loss 2.16, Val loss 1.12
# Epoch 41, Loss 2.94, Val loss 1.08
# Epoch 42, Loss 2.24, Val loss 1.03
# Epoch 43, Loss 3.00, Val loss 1.08
# Epoch 44, Loss 2.68, Val loss 1.06
# Epoch 45, Loss 3.42, Val loss 1.02
# Epoch 46, Loss 2.24, Val loss 1.05
# Epoch 47, Loss 2.11, Val loss 1.01
# Epoch 48, Loss 1.80, Val loss 1.04
# Epoch 49, Loss 2.06, Val loss 1.04
# TRAINING NEW LOCATION: Connecticut
# Saved model
# Epoch 0, Loss 10157.59, Val loss 1546.97
# Epoch 1, Loss 39179.43, Val loss 3884.99
# Epoch 2, Loss 18828.18, Val loss 3698.52
# Epoch 3, Loss 6534.26, Val loss 1975.51
# Saved model
# Epoch 4, Loss 2334.67, Val loss 752.30
# Saved model
# Epoch 5, Loss 710.48, Val loss 266.75
# Saved model
# Epoch 6, Loss 233.33, Val loss 102.67
# Saved model
# Epoch 7, Loss 89.10, Val loss 44.94
# Saved model
# Epoch 8, Loss 39.63, Val loss 22.47
# Saved model
# Epoch 9, Loss 19.99, Val loss 12.73
# Saved model
# Epoch 10, Loss 11.51, Val loss 8.08
# Saved model
# Epoch 11, Loss 7.31, Val loss 5.66
# Saved model
# Epoch 12, Loss 5.01, Val loss 4.30
# Saved model
# Epoch 13, Loss 3.72, Val loss 3.46
# Saved model
# Epoch 14, Loss 2.86, Val loss 2.90
# Saved model
# Epoch 15, Loss 2.34, Val loss 2.49
# Saved model
# Epoch 16, Loss 1.97, Val loss 2.19
# Saved model
# Epoch 17, Loss 1.72, Val loss 1.96
# Saved model
# Epoch 18, Loss 1.54, Val loss 1.79
# Saved model
# Epoch 19, Loss 1.41, Val loss 1.68
# Saved model
# Epoch 20, Loss 1.31, Val loss 1.62
# Saved model
# Epoch 21, Loss 1.23, Val loss 1.59
# Saved model
# Epoch 22, Loss 1.16, Val loss 1.59
# Epoch 23, Loss 1.11, Val loss 1.59
# Epoch 24, Loss 1.06, Val loss 1.60
# Epoch 25, Loss 1.03, Val loss 1.61
# Epoch 26, Loss 1.00, Val loss 1.62
# Epoch 27, Loss 0.97, Val loss 1.64
# Epoch 28, Loss 0.95, Val loss 1.66
# Epoch 29, Loss 0.93, Val loss 1.68
# Epoch 30, Loss 0.91, Val loss 1.70
# Epoch 31, Loss 0.90, Val loss 1.71
# Epoch 32, Loss 0.89, Val loss 1.71
# Epoch 33, Loss 0.88, Val loss 1.70
# Epoch 34, Loss 0.86, Val loss 1.68
# Epoch 35, Loss 0.85, Val loss 1.66
# Epoch 36, Loss 0.85, Val loss 1.64
# Epoch 37, Loss 0.83, Val loss 1.62
# Epoch 38, Loss 0.83, Val loss 1.60
# Epoch 39, Loss 0.82, Val loss 1.59
# Saved model
# Epoch 40, Loss 0.82, Val loss 1.58
# Saved model
# Epoch 41, Loss 0.81, Val loss 1.57
# Saved model
# Epoch 42, Loss 0.81, Val loss 1.56
# Saved model
# Epoch 43, Loss 0.80, Val loss 1.55
# Saved model
# Epoch 44, Loss 0.80, Val loss 1.55
Val loss 0.01
# Saved model
# Epoch 7, Loss 0.45, Val loss 0.01
# Epoch 8, Loss 0.40, Val loss 0.01
# Epoch 9, Loss 0.39, Val loss 0.01
# Epoch 10, Loss 0.38, Val loss 0.02
# Epoch 11, Loss 0.37, Val loss 0.02
# Epoch 12, Loss 0.35, Val loss 0.02
# Epoch 13, Loss 0.34, Val loss 0.02
# Epoch 14, Loss 0.34, Val loss 0.01
# Epoch 15, Loss 0.33, Val loss 0.01
# Epoch 16, Loss 0.33, Val loss 0.01
# Epoch 17, Loss 0.34, Val loss 0.01
# Saved model
# Epoch 18, Loss 0.33, Val loss 0.01
# Saved model
# Epoch 19, Loss 0.32, Val loss 0.01
# Saved model
# Epoch 20, Loss 0.32, Val loss 0.01
# Saved model
# Epoch 21, Loss 0.32, Val loss 0.01
# Saved model
# Epoch 22, Loss 0.31, Val loss 0.01
# Saved model
# Epoch 23, Loss 0.31, Val loss 0.00
# Saved model
# Epoch 24, Loss 0.30, Val loss 0.00
# Saved model
# Epoch 25, Loss 0.30, Val loss 0.00
# Epoch 26, Loss 0.30, Val loss 0.01
# Epoch 27, Loss 0.30, Val loss 0.01
# Epoch 28, Loss 0.30, Val loss 0.01
# Epoch 29, Loss 0.30, Val loss 0.00
# Epoch 30, Loss 0.29, Val loss 0.01
# Epoch 31, Loss 0.29, Val loss 0.01
# Epoch 32, Loss 0.29, Val loss 0.01
# Epoch 33, Loss 0.28, Val loss 0.01
# Epoch 34, Loss 0.30, Val loss 0.01
# Epoch 35, Loss 0.28, Val loss 0.01
# Epoch 36, Loss 0.28, Val loss 0.01
# Epoch 37, Loss 0.28, Val loss 0.01
# Epoch 38, Loss 0.28, Val loss 0.01
# Epoch 39, Loss 0.28, Val loss 0.01
# Epoch 40, Loss 0.28, Val loss 0.01
# Epoch 41, Loss 0.27, Val loss 0.01
# Epoch 42, Loss 0.27, Val loss 0.01
# Epoch 43, Loss 0.27, Val loss 0.01
# Epoch 44, Loss 0.27, Val loss 0.00
# Epoch 45, Loss 0.27, Val loss 0.00
# Epoch 46, Loss 0.27, Val loss 0.00
# Epoch 47, Loss 0.26, Val loss 0.00
# Epoch 48, Loss 0.26, Val loss 0.00
# Saved model
# Epoch 49, Loss 0.26, Val loss 0.00
# TRAINING NEW LOCATION: Georgia
# Saved model
# Epoch 0, Loss 0.43, Val loss 0.01
# Epoch 1, Loss 0.27, Val loss 0.02
# Epoch 2, Loss 0.26, Val loss 0.03
# Epoch 3, Loss 0.22, Val loss 0.02
# Epoch 4, Loss 0.19, Val loss 0.01
# Saved model
# Epoch 5, Loss 0.18, Val loss 0.01
# Epoch 6, Loss 0.16, Val loss 0.02
# Epoch 7, Loss 0.15, Val loss 0.02
# Epoch 8, Loss 0.14, Val loss 0.02
# Epoch 9, Loss 0.14, Val loss 0.01
# Saved model
# Epoch 10, Loss 0.13, Val loss 0.01
# Saved model
# Epoch 11, Loss 0.12, Val loss 0.00
# Saved model
# Epoch 12, Loss 0.12, Val loss 0.00
# Epoch 13, Loss 0.11, Val loss 0.01
# Epoch 14, Loss 0.11, Val loss 0.01
# Epoch 15, Loss 0.11, Val loss 0.02
# Epoch 31, Loss 3.07, Val loss 0.15
# Epoch 32, Loss 3.04, Val loss 0.15
# Epoch 33, Loss 3.02, Val loss 0.15
# Epoch 34, Loss 3.01, Val loss 0.15
# Epoch 35, Loss 2.99, Val loss 0.15
# Epoch 36, Loss 2.98, Val loss 0.15
# Epoch 37, Loss 2.96, Val loss 0.16
# Epoch 38, Loss 2.94, Val loss 0.17
# Epoch 39, Loss 2.92, Val loss 0.18
# Epoch 40, Loss 2.92, Val loss 0.19
# Epoch 41, Loss 2.91, Val loss 0.17
# Epoch 42, Loss 2.88, Val loss 0.18
# Epoch 43, Loss 2.87, Val loss 0.17
# Epoch 44, Loss 2.85, Val loss 0.15
# Epoch 45, Loss 2.84, Val loss 0.16
# Epoch 46, Loss 2.83, Val loss 0.19
# Epoch 47, Loss 2.81, Val loss 0.17
# Epoch 48, Loss 2.80, Val loss 0.21
# Epoch 49, Loss 2.78, Val loss 0.19
# TRAINING NEW LOCATION: Idaho
# Saved model
# Epoch 0, Loss 68.57, Val loss 530.35
# Epoch 1, Loss 3662.06, Val loss 2357.08
# Epoch 2, Loss 6560.97, Val loss 3904.97
# Epoch 3, Loss 5595.00, Val loss 4137.67
# Epoch 4, Loss 3552.09, Val loss 3281.65
# Epoch 5, Loss 2112.80, Val loss 1841.63
# Epoch 6, Loss 874.33, Val loss 794.89
# Saved model
# Epoch 7, Loss 306.00, Val loss 315.44
# Saved model
# Epoch 8, Loss 116.92, Val loss 113.40
# Saved model
# Epoch 9, Loss 46.18, Val loss 46.09
# Saved model
# Epoch 10, Loss 20.37, Val loss 23.45
# Saved model
# Epoch 11, Loss 12.94, Val loss 11.66
# Saved model
# Epoch 12, Loss 7.02, Val loss 7.64
# Saved model
# Epoch 13, Loss 5.67, Val loss 5.35
# Saved model
# Epoch 14, Loss 3.62, Val loss 3.46
# Saved model
# Epoch 15, Loss 3.38, Val loss 2.19
# Saved model
# Epoch 16, Loss 2.36, Val loss 1.91
# Saved model
# Epoch 17, Loss 2.24, Val loss 1.70
# Saved model
# Epoch 18, Loss 1.95, Val loss 1.59
# Saved model
# Epoch 19, Loss 1.86, Val loss 1.35
# Saved model
# Epoch 20, Loss 1.76, Val loss 1.33
# Epoch 21, Loss 1.69, Val loss 1.33
# Saved model
# Epoch 22, Loss 1.58, Val loss 1.23
# Saved model
# Epoch 23, Loss 1.60, Val loss 1.19
# Epoch 24, Loss 1.56, Val loss 1.20
# Saved model
# Epoch 25, Loss 1.52, Val loss 1.14
# Saved model
# Epoch 26, Loss 1.49, Val loss 1.11
# Saved model
# Epoch 27, Loss 1.48, Val loss 1.06
# Saved model
# Epoch 28, Loss 1.47, Val loss 1.03
# Saved model
# Epoch 29, Loss 1.49, Val loss 0.97
# Saved model
# Epoch 30, Loss 1.41, Val loss 0.96
# Saved model
# Epoch 31, Loss 1.41, Val loss 0.91
# Epoch 32, Loss 1.38, Val loss 0.96
# Epoch 33, Loss 1.39, Val loss 0.99
# Saved model
# Epoch 34, Loss 1.39, Val loss 0.91
# Saved model
# Epoch 18, Loss 16.79, Val loss 0.94
# Saved model
# Epoch 19, Loss 15.49, Val loss 0.83
# Saved model
# Epoch 20, Loss 13.64, Val loss 0.78
# Saved model
# Epoch 21, Loss 10.33, Val loss 0.73
# Saved model
# Epoch 22, Loss 10.98, Val loss 0.71
# Saved model
# Epoch 23, Loss 9.45, Val loss 0.67
# Saved model
# Epoch 24, Loss 9.14, Val loss 0.67
# Saved model
# Epoch 25, Loss 7.63, Val loss 0.66
# Epoch 26, Loss 7.01, Val loss 0.67
# Saved model
# Epoch 27, Loss 6.99, Val loss 0.65
# Epoch 28, Loss 6.78, Val loss 0.67
# Epoch 29, Loss 6.62, Val loss 0.66
# Saved model
# Epoch 30, Loss 6.21, Val loss 0.64
# Saved model
# Epoch 31, Loss 6.28, Val loss 0.61
# Saved model
# Epoch 32, Loss 6.76, Val loss 0.59
# Saved model
# Epoch 33, Loss 5.64, Val loss 0.59
# Epoch 34, Loss 5.23, Val loss 0.59
# Saved model
# Epoch 35, Loss 5.35, Val loss 0.58
# Saved model
# Epoch 36, Loss 5.29, Val loss 0.58
# Epoch 37, Loss 5.15, Val loss 0.60
# Saved model
# Epoch 38, Loss 4.84, Val loss 0.58
# Epoch 39, Loss 5.71, Val loss 0.59
# Saved model
# Epoch 40, Loss 5.16, Val loss 0.57
# Saved model
# Epoch 41, Loss 4.83, Val loss 0.56
# Saved model
# Epoch 42, Loss 4.94, Val loss 0.55
# Epoch 43, Loss 4.18, Val loss 0.56
# Epoch 44, Loss 4.69, Val loss 0.57
# Epoch 45, Loss 4.12, Val loss 0.57
# Epoch 46, Loss 4.33, Val loss 0.58
# Saved model
# Epoch 47, Loss 4.31, Val loss 0.54
# Saved model
# Epoch 48, Loss 4.34, Val loss 0.53
# Saved model
# Epoch 49, Loss 4.01, Val loss 0.53
# TRAINING NEW LOCATION: Kentucky
# Saved model
# Epoch 0, Loss 88.29, Val loss 26.75
# Epoch 1, Loss 1437.38, Val loss 305.09
# Epoch 2, Loss 2028.76, Val loss 924.03
# Epoch 3, Loss 1000.28, Val loss 579.66
# Epoch 4, Loss 229.40, Val loss 194.21
# Epoch 5, Loss 56.99, Val loss 68.62
# Epoch 6, Loss 19.79, Val loss 28.71
# Saved model
# Epoch 7, Loss 8.76, Val loss 13.87
# Saved model
# Epoch 8, Loss 4.73, Val loss 7.74
# Saved model
# Epoch 9, Loss 2.92, Val loss 4.65
# Saved model
# Epoch 10, Loss 1.97, Val loss 3.15
# Saved model
# Epoch 11, Loss 1.48, Val loss 2.46
# Saved model
# Epoch 12, Loss 1.16, Val loss 2.00
# Saved model
# Epoch 13, Loss 0.97, Val loss 1.82
# Saved model
# Epoch 14, Loss 0.85, Val loss 1.67
# Saved model
# Epoch 15, Loss 0.74, Val loss 1.63
# Saved model
# Epoch 16, Loss 0.68, Val loss 1.61
# Saved model
# Epoch 17, Loss 0.64, Val loss 1.56
# Saved model
# Epoch 18, Loss 0.61, Val loss 1.55
# Saved model
# Epoch 33, Loss 0.79, Val loss 1.63
# Epoch 34, Loss 0.75, Val loss 1.73
# Epoch 35, Loss 0.78, Val loss 1.64
# Epoch 36, Loss 0.77, Val loss 1.63
# Epoch 37, Loss 0.77, Val loss 1.60
# Epoch 38, Loss 0.78, Val loss 1.60
# Epoch 39, Loss 0.74, Val loss 1.67
# Epoch 40, Loss 0.80, Val loss 1.66
# Epoch 41, Loss 0.98, Val loss 1.61
# Epoch 42, Loss 0.72, Val loss 1.50
# Epoch 43, Loss 0.87, Val loss 1.28
# Epoch 44, Loss 0.75, Val loss 1.63
# Epoch 45, Loss 0.72, Val loss 1.44
# Epoch 46, Loss 1.02, Val loss 1.51
# Epoch 47, Loss 1.00, Val loss 1.56
# Epoch 48, Loss 0.86, Val loss 1.45
# Epoch 49, Loss 0.88, Val loss 1.48
# TRAINING NEW LOCATION: Maryland
# Saved model
# Epoch 0, Loss 23269.96, Val loss 2711.30
# Epoch 1, Loss 359412.69, Val loss 13901.26
# Epoch 2, Loss 366738.59, Val loss 24075.61
# Epoch 3, Loss 205938.16, Val loss 22345.87
# Epoch 4, Loss 107380.83, Val loss 13442.54
# Epoch 5, Loss 46628.03, Val loss 5863.49
# Saved model
# Epoch 6, Loss 21485.54, Val loss 2257.20
# Saved model
# Epoch 7, Loss 8044.96, Val loss 898.83
# Saved model
# Epoch 8, Loss 3003.22, Val loss 392.90
# Saved model
# Epoch 9, Loss 971.48, Val loss 191.29
# Saved model
# Epoch 10, Loss 330.69, Val loss 102.71
# Saved model
# Epoch 11, Loss 132.32, Val loss 59.85
# Saved model
# Epoch 12, Loss 62.88, Val loss 37.28
# Saved model
# Epoch 13, Loss 34.51, Val loss 24.54
# Saved model
# Epoch 14, Loss 22.25, Val loss 16.90
# Saved model
# Epoch 15, Loss 14.81, Val loss 12.10
# Saved model
# Epoch 16, Loss 10.87, Val loss 8.95
# Saved model
# Epoch 17, Loss 8.33, Val loss 6.81
# Saved model
# Epoch 18, Loss 6.73, Val loss 5.32
# Saved model
# Epoch 19, Loss 5.56, Val loss 4.25
# Saved model
# Epoch 20, Loss 4.76, Val loss 3.48
# Saved model
# Epoch 21, Loss 4.12, Val loss 2.90
# Saved model
# Epoch 22, Loss 3.68, Val loss 2.47
# Saved model
# Epoch 23, Loss 3.33, Val loss 2.15
# Saved model
# Epoch 24, Loss 3.07, Val loss 1.89
# Saved model
# Epoch 25, Loss 2.87, Val loss 1.69
# Saved model
# Epoch 26, Loss 2.70, Val loss 1.52
# Saved model
# Epoch 27, Loss 2.57, Val loss 1.37
# Saved model
# Epoch 28, Loss 2.46, Val loss 1.24
# Saved model
# Epoch 29, Loss 2.36, Val loss 1.12
# Saved model
# Epoch 30, Loss 2.29, Val loss 1.02
# Saved model
# Epoch 31, Loss 2.22, Val loss 0.94
# Saved model
# Epoch 32, Loss 2.17, Val loss 0.87
# Saved model
# Epoch 33, Loss 2.12, Val loss 0.81
# Saved model
# Epoch 34, Loss 2.07, Val loss 0.77
# Saved model
# Epoch 35, Loss 2.04, Val loss 0.74
# Saved model
# Epoch 36, Loss 2.01, Val loss 0.71
# Saved model
# Epoch 37, Loss 1.99, Val loss 0.69
# Saved model
# Epoch 38, Loss 1.96, Val loss 0.68
# Saved model
# Epoch 39, Loss 1.93, Val loss 0.67
# Saved model
# Epoch 40, Loss 1.91, Val loss 0.66
# Saved model
# Epoch 41, Loss 1.90, Val loss 0.65
# Saved model
# Epoch 42, Loss 1.88, Val loss 0.63
# Saved model
# Epoch 43, Loss 1.86, Val loss 0.62
# Saved model
# Epoch 44, Loss 1.86, Val loss 0.61
# Saved model
# Epoch 45, Loss 1.85, Val loss 0.59
# Saved model
# Epoch 46, Loss 1.84, Val loss 0.58
# Saved model
# Epoch 47, Loss 1.84, Val loss 0.56
# Saved model
# Epoch 48, Loss 1.82, Val loss 0.55
# Saved model
# Epoch 49, Loss 1.81, Val loss 0.55
# TRAINING NEW LOCATION: Massachusetts
# Saved model
# Epoch 0, Loss 0.75, Val loss 0.67
# Saved model
# Epoch 1, Loss 0.77, Val loss 0.21
# Saved model
# Epoch 2, Loss 0.21, Val loss 0.16
# Saved model
# Epoch 3, Loss 0.15, Val loss 0.12
# Saved model
# Epoch 4, Loss 0.14, Val loss 0.11
# Epoch 5, Loss 0.14, Val loss 0.11
# Epoch 6, Loss 0.13, Val loss 0.12
# Epoch 7, Loss 0.13, Val loss 0.12
# Epoch 8, Loss 0.12, Val loss 0.12
# Epoch 9, Loss 0.12, Val loss 0.13
# Epoch 10, Loss 0.12, Val loss 0.13
# Epoch 11, Loss 0.12, Val loss 0.12
# Epoch 12, Loss 0.12, Val loss 0.11
# Saved model
# Epoch 13, Loss 0.11, Val loss 0.10
# Saved model
# Epoch 14, Loss 0.11, Val loss 0.10
# Epoch 15, Loss 0.11, Val loss 0.10
# Epoch 16, Loss 0.10, Val loss 0.11
# Epoch 17, Loss 0.11, Val loss 0.11
# Epoch 18, Loss 0.11, Val loss 0.12
# Epoch 19, Loss 0.10, Val loss 0.12
# Epoch 20, Loss 0.10, Val loss 0.12
# Epoch 21, Loss 0.10, Val loss 0.12
# Epoch 22, Loss 0.10, Val loss 0.12
# Epoch 23, Loss 0.10, Val loss 0.11
# Epoch 24, Loss 0.10, Val loss 0.10
# Saved model
# Epoch 25, Loss 0.09, Val loss 0.09
# Saved model
# Epoch 26, Loss 0.09, Val loss 0.09
# Epoch 27, Loss 0.09, Val loss 0.09
# Epoch 28, Loss 0.09, Val loss 0.10
# Epoch 29, Loss 0.09, Val loss 0.11
# Epoch 30, Loss 0.09, Val loss 0.11
# Epoch 31, Loss 0.09, Val loss 0.11
# Epoch 32, Loss 0.09, Val loss 0.11
# Epoch 33, Loss 0.08, Val loss 0.11
# Epoch 34, Loss 0.08, Val loss 0.10
# Saved model
# Epoch 35, Loss 0.08, Val loss 0.09
# Saved model
# Epoch 36, Loss 0.08, Val loss 0.08
# Epoch 37, Loss 0.08, Val loss 0.09
# Epoch 38, Loss 0.08, Val loss 0.10
# Saved model
# Epoch 14, Loss 57.58, Val loss 124.84
# Saved model
# Epoch 15, Loss 41.39, Val loss 94.82
# Saved model
# Epoch 16, Loss 29.22, Val loss 64.44
# Saved model
# Epoch 17, Loss 21.50, Val loss 48.14
# Saved model
# Epoch 18, Loss 17.50, Val loss 38.06
# Saved model
# Epoch 19, Loss 13.62, Val loss 25.20
# Epoch 20, Loss 11.06, Val loss 26.37
# Saved model
# Epoch 21, Loss 9.10, Val loss 21.55
# Saved model
# Epoch 22, Loss 7.34, Val loss 17.36
# Saved model
# Epoch 23, Loss 6.31, Val loss 14.74
# Saved model
# Epoch 24, Loss 6.05, Val loss 12.30
# Saved model
# Epoch 25, Loss 5.50, Val loss 11.23
# Saved model
# Epoch 26, Loss 5.20, Val loss 8.66
# Epoch 27, Loss 4.19, Val loss 9.48
# Saved model
# Epoch 28, Loss 3.66, Val loss 7.18
# Saved model
# Epoch 29, Loss 3.62, Val loss 6.96
# Saved model
# Epoch 30, Loss 3.91, Val loss 6.35
# Saved model
# Epoch 31, Loss 3.53, Val loss 6.12
# Saved model
# Epoch 32, Loss 3.32, Val loss 6.01
# Saved model
# Epoch 33, Loss 2.87, Val loss 4.90
# Epoch 34, Loss 2.75, Val loss 5.04
# Saved model
# Epoch 35, Loss 2.63, Val loss 4.63
# Epoch 36, Loss 2.81, Val loss 4.83
# Saved model
# Epoch 37, Loss 2.64, Val loss 4.42
# Epoch 38, Loss 2.30, Val loss 5.35
# Saved model
# Epoch 39, Loss 2.40, Val loss 4.20
# Epoch 40, Loss 2.49, Val loss 4.30
# Epoch 41, Loss 2.34, Val loss 4.76
# Saved model
# Epoch 42, Loss 2.54, Val loss 4.03
# Saved model
# Epoch 43, Loss 2.18, Val loss 3.61
# Epoch 44, Loss 2.16, Val loss 3.78
# Saved model
# Epoch 45, Loss 2.38, Val loss 3.47
# Saved model
# Epoch 46, Loss 2.29, Val loss 3.44
# Epoch 47, Loss 2.31, Val loss 3.79
# Saved model
# Epoch 48, Loss 2.11, Val loss 3.43
# Epoch 49, Loss 2.20, Val loss 3.65
# TRAINING NEW LOCATION: Washington
# Saved model
# Epoch 0, Loss 0.30, Val loss 0.04
# Saved model
# Epoch 1, Loss 0.14, Val loss 0.03
# Saved model
# Epoch 2, Loss 0.10, Val loss 0.01
# Saved model
# Epoch 3, Loss 0.08, Val loss 0.01
# Saved model
# Epoch 4, Loss 0.08, Val loss 0.01
# Saved model
# Epoch 5, Loss 0.07, Val loss 0.01
# Saved model
# Epoch 6, Loss 0.06, Val loss 0.01
# Saved model
# Epoch 7, Loss 0.06, Val loss 0.00
# Saved model
# Epoch 8, Loss 0.06, Val loss 0.00
# Saved model
# Epoch 9, Loss 0.06, Val loss 0.00
# Saved model
# Epoch 10, Loss 0.05, Val loss 0.00
# Saved model
# Epoch 11, Loss 0.05, Val loss 0.00
# Epoch 12, Loss 0.05, Val loss 0.00
# Epoch 13, Loss 0.05, Val loss 0.00
# Epoch 14, Loss 0.05, Val loss 0.00
# Epoch 15, Loss 0.05, Val loss 0.00
# Epoch 16, Loss 0.04, Val loss 0.00
# Epoch 17, Loss 0.04, Val loss 0.00
# Epoch 18, Loss 0.04, Val loss 0.00
# Epoch 19, Loss 0.04, Val loss 0.00
# Epoch 20, Loss 0.05, Val loss 0.00
# Epoch 21, Loss 0.04, Val loss 0.00
# Epoch 22, Loss 0.04, Val loss 0.00
# Epoch 23, Loss 0.04, Val loss 0.00
# Epoch 24, Loss 0.04, Val loss 0.00
# Saved model
# Epoch
# Epoch 33, Loss 0.36, Val loss 2.35
# Epoch 34, Loss 0.36, Val loss 2.35
# Epoch 35, Loss 0.36, Val loss 2.39
# Epoch 36, Loss 0.37, Val loss 2.34
# Epoch 37, Loss 0.35, Val loss 2.32
# Epoch 38, Loss 0.35, Val loss 2.32
# Epoch 39, Loss 0.35, Val loss 2.28
# Epoch 40, Loss 0.35, Val loss 2.28
# Epoch 41, Loss 0.35, Val loss 2.32
# Epoch 42, Loss 0.34, Val loss 2.32
# Epoch 43, Loss 0.34, Val loss 2.35
# Epoch 44, Loss 0.35, Val loss 2.37
# Epoch 45, Loss 0.34, Val loss 2.34
# Epoch 46, Loss 0.34, Val loss 2.33
# Epoch 47, Loss 0.33, Val loss 2.31
# Epoch 48, Loss 0.33, Val loss 2.30
# Epoch 49, Loss 0.33, Val loss 2.27
# TRAINING NEW LOCATION: Wisconsin
# Saved model
# Epoch 0, Loss 0.74, Val loss 61.68
# Saved model
# Epoch 1, Loss 20.20, Val loss 8.81
# Epoch 2, Loss 0.51, Val loss 10.31
# Epoch 3, Loss 0.41, Val loss 10.96
# Epoch 4, Loss 0.39, Val loss 11.25
# Epoch 5, Loss 0.38, Val loss 11.25
# Epoch 6, Loss 0.34, Val loss 11.08
# Epoch 7, Loss 0.32, Val loss 10.78
# Epoch 8, Loss 0.29, Val loss 10.40
# Epoch 9, Loss 0.28, Val loss 10.02
# Epoch 10, Loss 0.26, Val loss 9.67
# Epoch 11, Loss 0.24, Val loss 9.39
# Epoch 12, Loss 0.22, Val loss 9.18
# Epoch 13, Loss 0.19, Val loss 8.97
# Saved model
# Epoch 14, Loss 0.17, Val loss 8.78
# Saved model
# Epoch 15, Loss 0.18, Val loss 8.70
# Epoch 16, Loss 0.22, Val loss 8.84
# Epoch 17, Loss 0.25, Val loss 9.04
# Epoch 18, Loss 0.26, Val loss 9.35
# Epoch 19, Loss 0.29, Val loss 9.01
# Epoch 20, Loss 0.30, Val loss 8.73
# Saved model
# Epoch 21, Loss 0.22, Val loss 8.46
# Epoch 22, Loss 0.19, Val loss 8.52
# Epoch 23, Loss 0.14, Val loss 8.63
# Epoch 24, Loss 0.13, Val loss 8.65
# Epoch 25, Loss 0.13, Val loss 8.64
# Epoch 26, Loss 0.11, Val loss 8.58
# Epoch 27, Loss 0.11, Val loss 8.50
# Epoch 28, Loss 0.12, Val loss 8.55
# Epoch 29, Loss 0.12, Val loss 8.51
# Epoch 30, Loss 0.12, Val loss 8.58
# Epoch 31, Loss 0.10, Val loss 8.59
# Epoch 32, Loss 0.11, Val loss 8.53
# Epoch 33, Loss 0.11, Val loss 8.56
# Epoch 34, Loss 0.10, Val loss 8.48
# Epoch 35, Loss 0.10, Val loss 8.52
# Epoch 36, Loss 0.11, Val loss 8.49
# Saved model
# Epoch 37, Loss 0.09, Val loss 8.38
# Epoch 38, Loss 0.13, Val loss 8.45
# Epoch 39, Loss 0.11, Val loss 8.39
# Saved model
# Epoch 40, Loss 0.11, Val loss 8.38
# Saved model
# Epoch 41, Loss 0.08, Val loss 8.35
# Epoch 42, Loss 0.09, Val loss 8.39
# Saved model
# Epoch 43, Loss 0.11, Val loss 8.30
# Saved model
# Epoch 44, Loss 0.09, Val loss 8.15
# Saved model
# Epoch 45, Loss 0.09, Val loss 8.10
# Epoch 46, Loss 0.09, Val loss 8.12
# Epoch 47, Loss 0.08, Val loss 8.22
# Epoch 48, Loss 0.08, Val loss 8.30
# Epoch 49, Loss 0.07, Val loss 8.30
# TRAINING NEW LOCATION: Wyoming
# Saved model
# Epoch 0, Loss 0.58, Val loss 1.23
# Epoch 1, Loss 0.40, Val loss 1.56
# Saved model
# Epoch 2, Loss 0.35, Val loss 0.99
# Saved model
# Epoch 3, Loss 0.12, Val loss 0.92
# Saved model
# Epoch 4, Loss 0.10, Val loss 0.88
# Saved model
# Epoch 5, Loss 0.08, Val loss 0.85
# Saved model
# Epoch 6, Loss 0.08, Val loss 0.82
# Saved model
# Epoch 7, Loss 0.08, Val loss 0.80
# Epoch 8, Loss 0.07, Val loss 0.83
# Epoch 9, Loss 0.07, Val loss 0.85
# Epoch 10, Loss 0.06, Val loss 0.86
# Epoch 11, Loss 0.06, Val loss 0.88
# Epoch 12, Loss 0.05, Val loss 0.90
# Epoch 13, Loss 0.05, Val loss 0.90
# Epoch 14, Loss 0.05, Val loss 0.88
# Epoch 15, Loss 0.05, Val loss 0.87
# Epoch 16, Loss 0.05, Val loss 0.86
# Epoch 17, Loss 0.04, Val loss 0.86
# Epoch 18, Loss 0.04, Val loss 0.85
# Epoch 19, Loss 0.04, Val loss 0.85
# Epoch 20, Loss 0.04, Val loss 0.82
# Epoch 21, Loss 0.04, Val loss 0.81
# Epoch 22, Loss 0.04, Val loss 0.81
# Epoch 23, Loss 0.04, Val loss 0.82
# Epoch 24, Loss 0.03, Val loss 0.84
# Epoch 25, Loss 0.03, Val loss 0.86
# Epoch 26, Loss 0.04, Val loss 0.86
# Epoch 27, Loss 0.03, Val loss 0.85
# Epoch 28, Loss 0.03, Val loss 0.85
# Epoch 29, Loss 0.03, Val loss 0.85
# Epoch 30, Loss 0.03, Val loss 0.85
# Epoch 31, Loss 0.03, Val loss 0.86
# Epoch 32, Loss 0.03, Val loss 0.85
# Epoch 33, Loss 0.03, Val loss 0.85
# Epoch 34, Loss 0.03, Val loss 0.84
# Epoch 35, Loss 0.03, Val loss 0.82
# Epoch 36, Loss 0.03, Val loss 0.82
# Epoch 37, Loss 0.03, Val loss 0.82
# Epoch 38, Loss 0.03, Val loss 0.82
# Epoch 39, Loss 0.03, Val loss 0.82
# Epoch 40, Loss 0.03, Val loss 0.81
# Epoch 41, Loss 0.03, Val loss 0.81
# Epoch 42, Loss 0.03, Val loss 0.81
# Epoch 43, Loss 0.03, Val loss 0.81
# Saved model
# Epoch 44, Loss 0.03, Val loss 0.80
# Saved model
# Epoch 45, Loss 0.03, Val loss 0.80
# Epoch 46, Loss 0.02, Val loss 0.81
# Saved model
# Epoch 47, Loss 0.03, Val loss 0.80
# Saved model
# Epoch 48, Loss 0.02, Val loss 0.79
# Saved model
# Epoch 49, Loss 0.02, Val loss 0.79

# %%
#Pred with STAN

model_predictions_number_infected = {}

for loc_name in loc_list:
  file_name = './save/stan_' + loc_name
  checkpoint = torch.load(file_name)
  model = STAN(g, in_dim, hidden_dim1, hidden_dim2, gru_dim, num_heads, pred_window, device).to(device)
  model.load_state_dict(checkpoint['state'])
  model.eval()

  prev_x = torch.cat((train_x, val_x), dim=1)
  prev_I = torch.cat((train_I, val_I), dim=1)
  prev_R = torch.cat((train_R, val_R), dim=1)
  prev_cI = torch.cat((train_cI, val_cI), dim=1)
  prev_cR = torch.cat((train_cR, val_cR), dim=1)

  cur_loc = loc_list.index(loc_name)

  prev_active_pred, _, prev_phyactive_pred, _, h = model(prev_x, prev_cI[cur_loc], prev_cR[cur_loc], N[cur_loc], prev_I[cur_loc], prev_R[cur_loc])

  test_pred_active, test_pred_recovered, test_pred_phy_active, test_pred_phy_recover, _ = model(test_x, test_cI[cur_loc], test_cR[cur_loc], N[cur_loc], test_I[cur_loc], test_R[cur_loc], h)

  # Cumulate predicted dI
  pred_I = []

  for i in range(test_pred_active.size(1)):
      cur_pred = (test_pred_active[0, i, :].detach().cpu().numpy() * dI_std[cur_loc].reshape(1, 1).detach().cpu().numpy()) + dI_mean[cur_loc].reshape(1, 1).detach().cpu().numpy()
      #cur_pred = test_pred_phy_active[0, i, :].detach().cpu().numpy()
      cur_pred = (cur_pred + test_pred_phy_active[0, i, :].detach().cpu().numpy()) / 2
      cur_pred = np.cumsum(cur_pred)
      cur_pred = cur_pred + test_I[cur_loc, i].detach().cpu().item()
      pred_I.append(cur_pred)
  pred_I = np.array(pred_I)
  pred_I = pred_I

  model_predictions_number_infected[loc_name] = pred_I[-1, :]

# %%
# Get the ground truth values for number of infected people 
ground_truth_number_infected = {}

def get_real_y(data, history_window=5, pred_window=15, slide_step=5):
    # Data shape n_loc, timestep, n_feat
    # Reshape to n_loc, t, history_window*n_feat
    n_loc = data.shape[0]
    timestep = data.shape[1]
    
    y = []
    for i in range(0, timestep, slide_step):
        if i+history_window+pred_window-1 >= timestep or i+history_window >= timestep:
            break
        y.append(data[:, i+history_window:i+history_window+pred_window])
    y = np.array(y, dtype=np.float32).transpose((1, 0, 2))
    return y
I_true = get_real_y(active_cases[:], history_window, pred_window, slide_step)

for loc_name in loc_list:
  cur_loc = loc_list.index(loc_name)
  ground_truth_number_infected[loc_name] = I_true[cur_loc, -1, :]

# %%
archived_output = {
    'loc_list':loc_list, 
    'model_predictions_number_infected':model_predictions_number_infected,
    'ground_truth_number_infected':ground_truth_number_infected
}

import pickle

# Save archived_output as pickle for use later
with open('./save/archived_output.pickle', 'wb') as handle:
    pickle.dump(archived_output, handle)


# # Load in archived_output pickle
# archived_output = None
# with open('./save/archived_output.pickle', 'rb') as handle:
#     archived_output = pickle.load(handle)


# print(model_predictions_number_infected['Alabama'])
# print(ground_truth_number_infected['Alabama'])
# array([127945., 129509., 132101., 131789., 134220., 136549.,  138347., 139919., 142691.,  73840.,  76439.,  77356.,  79475.,  81706., 84000.], dtype=float32)
#       11/16/20,11/17/20,11/18/20,11/19/20,11/20/20,11/21/20,11/22/20 ,11/23/20,11/24/20,11/25/20,11/26/20,11/27/20,11/28/20,11/29/20,11/30/20
# Date range verified by looking at: https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports_us/11-16-2020.csv
