# %%
# Mount this colab file correctly in google drive so I can access relative/local files
from google.colab import drive
drive.mount('/content/gdrive')
% cd /content/gdrive/My Drive/Github/"CS 499 - SPRING 2022"/"1. STAN - Original"
! pwd

# Install python packages I will need in the local environment
! pip install epiweeks
! pip install haversine
! pip install dgl-cu111 -f https://data.dgl.ai/wheels/repo.html
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# /content/gdrive/My Drive/Github/CS 499 - SPRING 2022/1. STAN - Original
# /content/gdrive/My Drive/Github/CS 499 - SPRING 2022/1. STAN - Original
# Requirement already satisfied: epiweeks in /usr/local/lib/python3.7/dist-packages (2.1.4)
# Requirement already satisfied: haversine in /usr/local/lib/python3.7/dist-packages (2.5.1)
# Looking in links: https://data.dgl.ai/wheels/repo.html
# Requirement already satisfied: dgl-cu111 in /usr/local/lib/python3.7/dist-packages (0.8.0)
# Requirement already satisfied: networkx>=2.1 in /usr/local/lib/python3.7/dist-packages (from dgl-cu111) (2.6.3)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from dgl-cu111) (1.4.1)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from dgl-cu111) (2.23.0)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.7/dist-packages (from dgl-cu111) (1.21.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from dgl-cu111) (4.63.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->dgl-cu111) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->dgl-cu111) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->dgl-cu111) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->dgl-cu111) (3.0.4)

# %%
import csv
import os

import numpy as np
import pandas as pd
from epiweeks import Week

from data_downloader import GenerateTrainingData
from utils import date_today, gravity_law_commute_dist

os.environ['NUMEXPR_MAX_THREADS'] = '16'
os.environ['NUMEXPR_NUM_THREADS'] = '8'

import pickle
import matplotlib.pyplot as plt
import dgl
import torch
from torch import nn
import torch.nn.functional as F
from model import STAN

import sklearn
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

# %%
GenerateTrainingData().download_jhu_data('2020-05-01', '2020-12-01')
# Out:
# Finish download
#       state  latitude  longitude  fips date_today  confirmed  deaths  \
# 0   Alabama   32.3182   -86.9023     1 2020-05-04       8203       8
# 0   Alabama   32.3182   -86.9023     1 2020-05-05       8520      17
# 0   Alabama   32.3182   -86.9023     1 2020-05-06       8769      28
# 0   Alabama   32.3182   -86.9023     1 2020-05-07       9115      26
# 0   Alabama   32.3182   -86.9023     1 2020-05-08       9437      14
# ..      ...       ...        ...   ...        ...        ...     ...
# 57  Wyoming   42.7560  -107.3025    56 2020-11-27      31773       0
# 57  Wyoming   42.7560  -107.3025    56 2020-11-28      31928       0
# 57  Wyoming   42.7560  -107.3025    56 2020-11-29      32489       0
# 57  Wyoming   42.7560  -107.3025    56 2020-11-30      33305       0
# 57  Wyoming   42.7560  -107.3025    56 2020-12-01      33805      24
#
#     recovered  active  hospitalization  new_cases
# 0         0.0  7905.0              0.0        226
# 0         0.0     0.0              0.0        317
# 0         0.0     0.0              0.0        249
# 0         0.0     0.0              0.0        346
# 0         0.0     0.0              0.0        322
# ..        ...     ...              ...        ...
# 57    21700.0  9858.0              4.0       1012
# 57    22798.0  8915.0              4.0        155
# 57    23022.0  9252.0              2.0        561
# 57    24478.0  8612.0              0.0        816
# 57    26003.0  7563.0              2.0        500
#
# [12296 rows x 11 columns]

# %%
#Merge population data with downloaded data
raw_data = pickle.load(open('./data/state_covid_data.pickle','rb'))
pop_data = pd.read_csv('./uszips.csv')
pop_data = pop_data.groupby('state_name').agg({'population':'sum', 'density':'mean', 'lat':'mean', 'lng':'mean'}).reset_index()
raw_data = pd.merge(raw_data, pop_data, how='inner', left_on='state', right_on='state_name')

# %%
# Generate location similarity
loc_list = list(raw_data['state'].unique())
loc_dist_map = {}

for each_loc in loc_list:
    loc_dist_map[each_loc] = {}
    for each_loc2 in loc_list:
        lat1 = raw_data[raw_data['state']==each_loc]['latitude'].unique()[0]
        lng1 = raw_data[raw_data['state']==each_loc]['longitude'].unique()[0]
        pop1 = raw_data[raw_data['state']==each_loc]['population'].unique()[0]
        
        lat2 = raw_data[raw_data['state']==each_loc2]['latitude'].unique()[0]
        lng2 = raw_data[raw_data['state']==each_loc2]['longitude'].unique()[0]
        pop2 = raw_data[raw_data['state']==each_loc2]['population'].unique()[0]
        
        loc_dist_map[each_loc][each_loc2] = gravity_law_commute_dist(lat1, lng1, pop1, lat2, lng2, pop2, r=0.5)

# %%
#Generate Graph
dist_threshold = 18

for each_loc in loc_dist_map:
    loc_dist_map[each_loc] = {k: v for k, v in sorted(loc_dist_map[each_loc].items(), key=lambda item: item[1], reverse=True)}
    
adj_map = {}
for each_loc in loc_dist_map:
    adj_map[each_loc] = []
    for i, each_loc2 in enumerate(loc_dist_map[each_loc]):
        if loc_dist_map[each_loc][each_loc2] > dist_threshold:
            if i <= 3:
                adj_map[each_loc].append(each_loc2)
            else:
                break
        else:
            if i <= 1:
                adj_map[each_loc].append(each_loc2)
            else:
                break

rows = []
cols = []
for each_loc in adj_map:
    for each_loc2 in adj_map[each_loc]:
        rows.append(loc_list.index(each_loc))
        cols.append(loc_list.index(each_loc2))

# %%
g = dgl.graph((rows, cols))

# %%
#Preprocess features

active_cases = []
confirmed_cases = []
new_cases = []
death_cases = []
static_feat = []

for i, each_loc in enumerate(loc_list):
    active_cases.append(raw_data[raw_data['state'] == each_loc]['active'])
    confirmed_cases.append(raw_data[raw_data['state'] == each_loc]['confirmed'])
    new_cases.append(raw_data[raw_data['state'] == each_loc]['new_cases'])
    death_cases.append(raw_data[raw_data['state'] == each_loc]['deaths'])
    static_feat.append(np.array(raw_data[raw_data['state'] == each_loc][['population','density','lng','lat']]))
    
active_cases = np.array(active_cases)
confirmed_cases = np.array(confirmed_cases)
death_cases = np.array(death_cases)
new_cases = np.array(new_cases)
static_feat = np.array(static_feat)[:, 0, :]
recovered_cases = confirmed_cases - active_cases - death_cases
susceptible_cases = np.expand_dims(static_feat[:, 0], -1) - active_cases - recovered_cases

# Batch_feat: new_cases(dI), dR, dS
#dI = np.array(new_cases)
dI = np.concatenate((np.zeros((active_cases.shape[0],1), dtype=np.float32), np.diff(active_cases)), axis=-1)
dR = np.concatenate((np.zeros((recovered_cases.shape[0],1), dtype=np.float32), np.diff(recovered_cases)), axis=-1)
dS = np.concatenate((np.zeros((susceptible_cases.shape[0],1), dtype=np.float32), np.diff(susceptible_cases)), axis=-1)

# %%
#Build normalizer
normalizer = {'S':{}, 'I':{}, 'R':{}, 'dS':{}, 'dI':{}, 'dR':{}}

for i, each_loc in enumerate(loc_list):
    normalizer['S'][each_loc] = (np.mean(susceptible_cases[i]), np.std(susceptible_cases[i]))
    normalizer['I'][each_loc] = (np.mean(active_cases[i]), np.std(active_cases[i]))
    normalizer['R'][each_loc] = (np.mean(recovered_cases[i]), np.std(recovered_cases[i]))
    normalizer['dI'][each_loc] = (np.mean(dI[i]), np.std(dI[i]))
    normalizer['dR'][each_loc] = (np.mean(dR[i]), np.std(dR[i]))
    normalizer['dS'][each_loc] = (np.mean(dS[i]), np.std(dS[i]))

# %%
def prepare_data(data, sum_I, sum_R, history_window=5, pred_window=15, slide_step=5):
    # Data shape n_loc, timestep, n_feat
    # Reshape to n_loc, t, history_window*n_feat
    n_loc = data.shape[0]
    timestep = data.shape[1]
    n_feat = data.shape[2]
    
    x = []
    y_I = []
    y_R = []
    y_active_cases = []
    last_I = []
    last_R = []
    concat_I = []
    concat_R = []
    for i in range(0, timestep, slide_step):
        if i+history_window+pred_window-1 >= timestep or i+history_window >= timestep:
            break
        x.append(data[:, i:i+history_window, :].reshape((n_loc, history_window*n_feat)))
        
        concat_I.append(data[:, i+history_window-1, 0])
        concat_R.append(data[:, i+history_window-1, 1])
        last_I.append(sum_I[:, i+history_window-1])
        last_R.append(sum_R[:, i+history_window-1])

        y_I.append(data[:, i+history_window:i+history_window+pred_window, 0])
        y_R.append(data[:, i+history_window:i+history_window+pred_window, 1])
        y_active_cases.append(sum_I[:, i+history_window:i+history_window+pred_window].reshape((n_loc, pred_window)))

    x = np.array(x, dtype=np.float32).transpose((1, 0, 2))
    last_I = np.array(last_I, dtype=np.float32).transpose((1, 0))
    last_R = np.array(last_R, dtype=np.float32).transpose((1, 0))
    concat_I = np.array(concat_I, dtype=np.float32).transpose((1, 0))
    concat_R = np.array(concat_R, dtype=np.float32).transpose((1, 0))
    y_I = np.array(y_I, dtype=np.float32).transpose((1, 0, 2))
    y_R = np.array(y_R, dtype=np.float32).transpose((1, 0, 2))
    y_active_cases = np.array(y_active_cases, dtype=np.float32).transpose((1, 0, 2))

    return x, last_I, last_R, concat_I, concat_R, y_I, y_R, y_active_cases

# %%
valid_window = 25
test_window = 25

history_window=6
pred_window=15
slide_step=5

dynamic_feat = np.concatenate((np.expand_dims(dI, axis=-1), np.expand_dims(dR, axis=-1), np.expand_dims(dS, axis=-1)), axis=-1)
    
#Normalize
for i, each_loc in enumerate(loc_list):
    dynamic_feat[i, :, 0] = (dynamic_feat[i, :, 0] - normalizer['dI'][each_loc][0]) / normalizer['dI'][each_loc][1]
    dynamic_feat[i, :, 1] = (dynamic_feat[i, :, 1] - normalizer['dR'][each_loc][0]) / normalizer['dR'][each_loc][1]
    dynamic_feat[i, :, 2] = (dynamic_feat[i, :, 2] - normalizer['dS'][each_loc][0]) / normalizer['dS'][each_loc][1]

dI_mean = []
dI_std = []
dR_mean = []
dR_std = []

for i, each_loc in enumerate(loc_list):
    dI_mean.append(normalizer['dI'][each_loc][0])
    dR_mean.append(normalizer['dR'][each_loc][0])
    dI_std.append(normalizer['dI'][each_loc][1])
    dR_std.append(normalizer['dR'][each_loc][1])

dI_mean = np.array(dI_mean)
dI_std = np.array(dI_std)
dR_mean = np.array(dR_mean)
dR_std = np.array(dR_std)

#Split train-test
train_feat = dynamic_feat[:, :-valid_window-test_window, :]
val_feat = dynamic_feat[:, -valid_window-test_window:-test_window, :]
test_feat = dynamic_feat[:, -test_window:, :]

train_x, train_I, train_R, train_cI, train_cR, train_yI, train_yR, _ = prepare_data(train_feat, active_cases[:, :-valid_window-test_window], recovered_cases[:, :-valid_window-test_window], history_window, pred_window, slide_step)
val_x, val_I, val_R, val_cI, val_cR, val_yI, val_yR, _ = prepare_data(val_feat, active_cases[:, -valid_window-test_window:-test_window], recovered_cases[:, -valid_window-test_window:-test_window], history_window, pred_window, slide_step)
test_x, test_I, test_R, test_cI, test_cR, test_yI, test_yR, test_active_cases = prepare_data(test_feat, active_cases[:, -test_window:], recovered_cases[:, -test_window:], history_window, pred_window, slide_step)

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

train_x = torch.tensor(train_x).to(device)
train_I = torch.tensor(train_I).to(device)
train_R = torch.tensor(train_R).to(device)
train_cI = torch.tensor(train_cI).to(device)
train_cR = torch.tensor(train_cR).to(device)
train_yI = torch.tensor(train_yI).to(device)
train_yR = torch.tensor(train_yR).to(device)

val_x = torch.tensor(val_x).to(device)
val_I = torch.tensor(val_I).to(device)
val_R = torch.tensor(val_R).to(device)
val_cI = torch.tensor(val_cI).to(device)
val_cR = torch.tensor(val_cR).to(device)
val_yI = torch.tensor(val_yI).to(device)
val_yR = torch.tensor(val_yR).to(device)

test_x = torch.tensor(test_x).to(device)
test_I = torch.tensor(test_I).to(device)
test_R = torch.tensor(test_R).to(device)
test_cI = torch.tensor(test_cI).to(device)
test_cR = torch.tensor(test_cR).to(device)
test_yI = torch.tensor(test_yI).to(device)
test_yR = torch.tensor(test_yR).to(device)
test_active_cases = torch.tensor(test_active_cases).to(device)

dI_mean = torch.tensor(dI_mean, dtype=torch.float32).to(device).reshape((dI_mean.shape[0], 1, 1))
dI_std = torch.tensor(dI_std, dtype=torch.float32).to(device).reshape((dI_mean.shape[0], 1, 1))
dR_mean = torch.tensor(dR_mean, dtype=torch.float32).to(device).reshape((dI_mean.shape[0], 1, 1))
dR_std = torch.tensor(dR_std, dtype=torch.float32).to(device).reshape((dI_mean.shape[0], 1, 1))

N = torch.tensor(static_feat[:, 0], dtype=torch.float32).to(device).unsqueeze(-1)

# %%
#Train STAN

# Hyperparameters
in_dim = 3*history_window
hidden_dim1 = 32
hidden_dim2 = 32
gru_dim = 32
num_heads = 1


# Build STAN model for each state
for loc_name in loc_list:
    print("TRAINING NEW LOCATION:", loc_name)
    g = g.to(device)
    model = STAN(g, in_dim, hidden_dim1, hidden_dim2, gru_dim, num_heads, pred_window, device).to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-2)
    criterion = nn.MSELoss()

    all_loss = []
    file_name = './save/stan_' + loc_name
    min_loss = 1e10

    cur_loc = loc_list.index(loc_name)

    for epoch in range(50):
        model.train()
        optimizer.zero_grad()
        
        active_pred, recovered_pred, phy_active, phy_recover, _ = model(train_x, train_cI[cur_loc], train_cR[cur_loc], N[cur_loc], train_I[cur_loc], train_R[cur_loc])
        phy_active = (phy_active - dI_mean[cur_loc]) / dI_std[cur_loc]
        phy_recover = (phy_recover - dR_mean[cur_loc]) / dR_std[cur_loc]
        loss = criterion(active_pred.squeeze(), train_yI[cur_loc])+criterion(recovered_pred.squeeze(), train_yR[cur_loc])+0.1*criterion(phy_active.squeeze(), train_yI[cur_loc])+0.1*criterion(phy_recover.squeeze(), train_yR[cur_loc])
        
        loss.backward()
        optimizer.step()
        all_loss.append(loss.item())
        
        model.eval()
        _, _, _, _, prev_h = model(train_x, train_cI[cur_loc], train_cR[cur_loc], N[cur_loc], train_I[cur_loc], train_R[cur_loc])
        val_active_pred, val_recovered_pred, val_phy_active, val_phy_recover, _ = model(val_x, val_cI[cur_loc], val_cR[cur_loc], N[cur_loc], val_I[cur_loc], val_R[cur_loc], prev_h)
        
        val_phy_active = (val_phy_active - dI_mean[cur_loc]) / dI_std[cur_loc]
        val_loss = criterion(val_active_pred.squeeze(), val_yI[cur_loc]) + 0.1*criterion(val_phy_active.squeeze(), val_yI[cur_loc])
        if val_loss < min_loss:    
            state = {
                'state': model.state_dict(),
                'optimizer': optimizer.state_dict(),
            }
            torch.save(state, file_name)
            min_loss = val_loss
            print('Saved model')
        
        print('Epoch %d, Loss %.2f, Val loss %.2f'%(epoch, all_loss[-1], val_loss.item()))
# Out:
# TRAINING NEW LOCATION: Alabama
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/loss.py:520: UserWarning: Using a target size (torch.Size([1, 15])) that is different to the input size (torch.Size([15])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Saved model
# Epoch 0, Loss 1.52, Val loss 40.46
# Saved model
# Epoch 1, Loss 66.38, Val loss 3.00
# Saved model
# Epoch 2, Loss 5.78, Val loss 0.25
# Epoch 3, Loss 0.78, Val loss 0.27
# Epoch 4, Loss 0.47, Val loss 0.28
# Epoch 5, Loss 0.39, Val loss 0.29
# Epoch 6, Loss 0.35, Val loss 0.29
# Epoch 7, Loss 0.32, Val loss 0.28
# Epoch 8, Loss 0.29, Val loss 0.27
# Epoch 9, Loss 0.28, Val loss 0.25
# Saved model
# Epoch 10, Loss 0.26, Val loss 0.22
# Saved model
# Epoch 11, Loss 0.24, Val loss 0.22
# Saved model
# Epoch 12, Loss 0.24, Val loss 0.20
# Saved model
# Epoch 13, Loss 0.22, Val loss 0.18
# Saved model
# Epoch 14, Loss 0.21, Val loss 0.16
# Epoch 15, Loss 0.19, Val loss 0.16
# Epoch 16, Loss 0.19, Val loss 0.17
# Epoch 17, Loss 0.18, Val loss 0.18
# Epoch 18, Loss 0.18, Val loss 0.20
# Epoch 19, Loss 0.18, Val loss 0.21
# Epoch 20, Loss 0.17, Val loss 0.20
# Epoch 21, Loss 0.17, Val loss 0.21
# Epoch 22, Loss 0.17, Val loss 0.19
# Epoch 23, Loss 0.17, Val loss 0.19
# Epoch 24, Loss 0.18, Val loss 0.20
# Epoch 25, Loss 0.17, Val loss 0.22
# Epoch 26, Loss 0.15, Val loss 0.21
# Epoch 27, Loss 0.15, Val loss 0.22
# Epoch 28, Loss 0.16, Val loss 0.21
# Epoch 29, Loss 0.15, Val loss 0.20
# Epoch 30, Loss 0.16, Val loss 0.20
# Epoch 31, Loss 0.15, Val loss 0.20
# Epoch 32, Loss 0.15, Val loss 0.20
# Epoch 33, Loss 0.15, Val loss 0.21
# Epoch 34, Loss 0.16, Val loss 0.20
# Epoch 35, Loss 0.16, Val loss 0.21
# Epoch 36, Loss 0.15, Val loss 0.21
# Epoch 37, Loss 0.15, Val loss 0.21
# Epoch 38, Loss 0.14, Val loss 0.21
# Epoch 39, Loss 0.15, Val loss 0.21
# Epoch 40, Loss 0.16, Val loss 0.19
# Epoch 41, Loss 0.14, Val loss 0.18
# Epoch 42, Loss 0.14, Val loss 0.19
# Epoch 43, Loss 0.15, Val loss 0.19
# Epoch 44, Loss 0.14, Val loss 0.20
# Epoch 45, Loss 0.13, Val loss 0.19
# Epoch 46, Loss 0.14, Val loss 0.19
# Epoch 47, Loss 0.13, Val loss 0.19
# Epoch 48, Loss 0.13, Val loss 0.18
# Epoch 49, Loss 0.13, Val loss 0.18
# TRAINING NEW LOCATION: Alaska
# Saved model
# Epoch 0, Loss 70.78, Val loss 155.88
# Epoch 1, Loss 2088.26, Val loss 1173.30
# Epoch 2, Loss 2352.92, Val loss 1508.11
# Epoch 3, Loss 1058.47, Val loss 643.21
# Epoch 4, Loss 244.62, Val loss 192.21
# Saved model
# Epoch 5, Loss 52.92, Val loss 64.07
# Saved model
# Epoch 6, Loss 16.15, Val loss 24.93
# Saved model
# Epoch 7, Loss 6.48, Val loss 12.06
# Saved model
# Epoch 8, Loss 3.74, Val loss 6.96
# Saved model
# Epoch 9, Loss 2.50, Val loss 5.39
# Saved model
# Epoch 10, Loss 2.01, Val loss 4.65
# Saved model
# Epoch 11, Loss 1.74, Val loss 4.15
# Saved model
# Epoch 12, Loss 1.58, Val loss 3.93
# Saved model
# Epoch 13, Loss 1.49, Val loss 3.86
# Saved model
# Epoch 14, Loss 1.44, Val loss 3.81
# Epoch 15, Loss 1.41, Val loss 3.85
# Epoch 16, Loss 1.37, Val loss 3.97
# Epoch 17, Loss 1.35, Val loss 4.07
# Epoch 18, Loss 1.35, Val loss 4.13
# Epoch 19, Loss 1.31, Val loss 4.18
# Epoch 20, Loss 1.31, Val loss 4.16
# Epoch 21, Loss 1.31, Val loss 4.16
# Epoch 22, Loss 1.28, Val loss 4.15
# Epoch 23, Loss 1.29, Val loss 4.17
# Epoch 24, Loss 1.27, Val loss 4.17
# Epoch 25, Loss 1.26, Val loss 4.17
# Epoch 26, Loss 1.23, Val loss 4.14
# Epoch 27, Loss 1.23, Val loss 4.13
# Epoch 28, Loss 1.21, Val loss 4.08
# Epoch 29, Loss 1.22, Val loss 4.02
# Epoch 30, Loss 1.24, Val loss 4.04
# Epoch 31, Loss 1.23, Val loss 3.97
# Epoch 32, Loss 1.20, Val loss 4.02
# Epoch 33, Loss 1.19, Val loss 4.07
# Epoch 34, Loss 1.18, Val loss 4.10
# Epoch 35, Loss 1.18, Val loss 4.18
# Epoch 36, Loss 1.18, Val loss 4.17
# Epoch 37, Loss 1.16, Val loss 4.18
# Epoch 38, Loss 1.15, Val loss 4.22
# Epoch 39, Loss 1.16, Val loss 4.21
# Epoch 40, Loss 1.14, Val loss 4.21
# Epoch 41, Loss 1.13, Val loss 4.21
# Epoch 42, Loss 1.13, Val loss 4.19
# Epoch 43, Loss 1.20, Val loss 4.11
# Epoch 44, Loss 1.15, Val loss 4.07
# Epoch 45, Loss 1.16, Val loss 4.05
# Epoch 46, Loss 1.12, Val loss 4.08
# Epoch 47, Loss 1.13, Val loss 4.10
# Epoch 48, Loss 1.13, Val loss 4.18
# Epoch 49, Loss 1.12, Val loss 4.24
# TRAINING NEW LOCATION: Arizona
# Saved model
# Epoch 0, Loss 4097.65, Val loss 102.05
# Epoch 1, Loss 40939.30, Val loss 1205.36
# Epoch 2, Loss 40248.11, Val loss 2176.85
# Epoch 3, Loss 12674.72, Val loss 1565.20
# Epoch 4, Loss 3888.04, Val loss 747.96
# Epoch 5, Loss 1227.92, Val loss 323.05
# Epoch 6, Loss 411.50, Val loss 146.00
# Saved model
# Epoch 7, Loss 159.21, Val loss 72.75
# Saved model
# Epoch 8, Loss 73.72, Val loss 38.98
# Saved model
# Epoch 9, Loss 39.97, Val loss 22.61
# Saved model
# Epoch 10, Loss 24.00, Val loss 14.09
# Saved model
# Epoch 11, Loss 15.72, Val loss 9.20
# Saved model
# Epoch 12, Loss 11.09, Val loss 6.35
# Saved model
# Epoch 13, Loss 8.30, Val loss 4.54
# Saved model
# Epoch 14, Loss 6.47, Val loss 3.30
# Saved model
# Epoch 15, Loss 5.27, Val loss 2.50
# Saved model
# Epoch 16, Loss 4.45, Val loss 1.96
# Saved model
# Epoch 17, Loss 3.85, Val loss 1.59
# Saved model
# Epoch 18, Loss 3.31, Val loss 1.27
# Saved model
# Epoch 19, Loss 3.09, Val loss 1.05
# Saved model
# Epoch 20, Loss 2.85, Val loss 0.90
# Saved model
# Epoch 21, Loss 2.57, Val loss 0.75
# Saved model
# Epoch 22, Loss 2.34, Val loss 0.63
# Saved model
# Epoch 23, Loss 2.29, Val loss 0.57
# Saved model
# Epoch 24, Loss 2.13, Val loss 0.50
# Saved model
# Epoch 25, Loss 2.03, Val loss 0.44
# Saved model
# Epoch 26, Loss 1.93, Val loss 0.39
# Saved model
# Epoch 27, Loss 1.86, Val loss 0.37
# Saved model
# Epoch 28, Loss 1.78, Val loss 0.34
# Saved model
# Epoch 29, Loss 1.73, Val loss 0.32
# Saved model
# Epoch 30, Loss 1.69, Val loss 0.29
# Saved model
# Epoch 31, Loss 1.60, Val loss 0.29
# Saved model
# Epoch 32, Loss 1.56, Val loss 0.27
# Saved model
# Epoch 33, Loss 1.58, Val loss 0.25
# Saved model
# Epoch 34, Loss 1.50, Val loss 0.24
# Saved model
# Epoch 35, Loss 1.48, Val loss 0.23
# Saved model
# Epoch 36, Loss 1.49, Val loss 0.21
# Epoch 37, Loss 1.47, Val loss 0.21
# Epoch 38, Loss 1.43, Val loss 0.21
# Epoch 39, Loss 1.41, Val loss 0.21
# Epoch 40, Loss 1.41, Val loss 0.21
# Epoch 41, Loss 1.38, Val loss 0.23
# Saved model
# Epoch 42, Loss 1.35, Val loss 0.20
# Saved model
# Epoch 43, Loss 1.30, Val loss 0.20
# Saved model
# Epoch 44, Loss 1.28, Val loss 0.20
# Saved model
# Epoch 45, Loss 1.32, Val loss 0.19
# Epoch 46, Loss 1.29, Val loss 0.20
# Saved model
# Epoch 47, Loss 1.23, Val loss 0.18
# Epoch 48, Loss 1.24, Val loss 0.18
# Saved model
# Epoch 49, Loss 1.24, Val loss 0.17
# TRAINING NEW LOCATION: Arkansas
# Saved model
# Epoch 0, Loss 22.21, Val loss 0.64
# Epoch 1, Loss 2.31, Val loss 0.68
# Epoch 2, Loss 1.86, Val loss 0.79
# Epoch 3, Loss 1.67, Val loss 0.95
# Epoch 4, Loss 1.54, Val loss 1.10
# Epoch 5, Loss 1.52, Val loss 1.20
# Epoch 6, Loss 1.55, Val loss 1.24
# Epoch 7, Loss 1.54, Val loss 1.17
# Epoch 8, Loss 1.54, Val loss 1.13
# Epoch 9, Loss 1.50, Val loss 1.09
# Epoch 10, Loss 1.49, Val loss 1.02
# Epoch 11, Loss 1.44, Val loss 0.91
# Epoch 12, Loss 1.40, Val loss 0.91
# Epoch 13, Loss 1.40, Val loss 0.90
# Epoch 14, Loss 1.38, Val loss 0.91
# Epoch 15, Loss 1.38, Val loss 0.93
# Epoch 16, Loss 1.38, Val loss 1.02
# Epoch 17, Loss 1.38, Val loss 1.01
# Epoch 18, Loss 1.38, Val loss 0.99
# Epoch 19, Loss 1.34, Val loss 1.10
# Epoch 20, Loss 1.33, Val loss 1.04
# Epoch 21, Loss 1.37, Val loss 1.02
# Epoch 22, Loss 1.33, Val loss 1.03
# Epoch 23, Loss 1.34, Val loss 1.11
# Epoch 24, Loss 1.32, Val loss 1.08
# Epoch 25, Loss 1.31, Val loss 1.07
# Epoch 26, Loss 1.31, Val loss 1.07
# Epoch 27, Loss 1.30, Val loss 1.07
# Epoch 28, Loss 1.29, Val loss 1.04
# Epoch 29, Loss 1.29, Val loss 1.05
# Epoch 30, Loss 1.29, Val loss 1.04
# Epoch 31, Loss 1.28, Val loss 1.10
# Epoch 32, Loss 1.27, Val loss 1.15
# Epoch 33, Loss 1.26, Val loss 1.16
# Epoch 34, Loss 1.27, Val loss 1.16
# Epoch 35, Loss 1.26, Val loss 1.18
# Epoch 36, Loss 1.23, Val loss 1.18
# Epoch 37, Loss 1.23, Val loss 1.16
# Epoch 38, Loss 1.24, Val loss 1.08
# Epoch 39, Loss 1.22, Val loss 1.08
# Epoch 40, Loss 1.21, Val loss 1.09
# Epoch 41, Loss 1.20, Val loss 1.12
# Epoch 42, Loss 1.24, Val loss 1.28
# Epoch 43, Loss 1.20, Val loss 1.25
# Epoch 44, Loss 1.20, Val loss 1.21
# Epoch 45, Loss 1.22, Val loss 1.20
# Epoch 46, Loss 1.18, Val loss 1.09
# Epoch 47, Loss 1.18, Val loss 1.03
# Epoch 48, Loss 1.17, Val loss 1.04
# Epoch 49, Loss 1.18, Val loss 1.08
# TRAINING NEW LOCATION: California
# Saved model
# Epoch 0, Loss 0.73, Val loss 0.04
# Saved model
# Epoch 1, Loss 0.48, Val loss 0.02
# Saved model
# Epoch 2, Loss 0.44, Val loss 0.02
# Epoch 3, Loss 0.41, Val loss 0.02
# Epoch 4, Loss 0.38, Val loss 0.02
# Epoch 5, Loss 0.34, Val loss 0.02
# Epoch 6, Loss 0.31, Val loss 0.02
# Epoch 7, Loss 0.29, Val loss 0.02
# Epoch 8, Loss 0.27, Val loss 0.02
# Epoch 9, Loss 0.27, Val loss 0.02
# Epoch 10, Loss 0.25, Val loss 0.02
# Epoch 11, Loss 0.24, Val loss 0.02
# Epoch 12, Loss 0.23, Val loss 0.02
# Saved model
# Epoch 13, Loss 0.23, Val loss 0.01
# Saved model
# Epoch 14, Loss 0.23, Val loss 0.01
# Saved model
# Epoch 15, Loss 0.22, Val loss 0.01
# Saved model
# Epoch 16, Loss 0.22, Val loss 0.01
# Saved model
# Epoch 17, Loss 0.21, Val loss 0.01
# Saved model
# Epoch 18, Loss 0.21, Val loss 0.01
# Saved model
# Epoch 19, Loss 0.21, Val loss 0.01
# Saved model
# Epoch 20, Loss 0.21, Val loss 0.01
# Saved model
# Epoch 21, Loss 0.21, Val loss 0.00
# Saved model
# Epoch 22, Loss 0.21, Val loss 0.00
# Saved model
# Epoch 23, Loss 0.21, Val loss 0.00
# Saved model
# Epoch 24, Loss 0.21, Val loss 0.00
# Epoch 25, Loss 0.20, Val loss 0.00
# Epoch 26, Loss 0.21, Val loss 0.00
# Saved model
# Epoch 27, Loss 0.20, Val loss 0.00
# Epoch 28, Loss 0.21, Val loss 0.00
# Epoch 29, Loss 0.20, Val loss 0.00
# Epoch 30, Loss 0.20, Val loss 0.00
# Epoch 31, Loss 0.20, Val loss 0.00
# Epoch 32, Loss 0.20, Val loss 0.00
# Epoch 33, Loss 0.20, Val loss 0.00
# Epoch 34, Loss 0.20, Val loss 0.00
# Epoch 35, Loss 0.20, Val loss 0.00
# Epoch 36, Loss 0.19, Val loss 0.00
# Epoch 37, Loss 0.20, Val loss 0.00
# Epoch 38, Loss 0.19, Val loss 0.00
# Saved model
# Epoch 39, Loss 0.19, Val loss 0.00
# Epoch 40, Loss 0.19, Val loss 0.00
# Epoch 41, Loss 0.19, Val loss 0.00
# Epoch 42, Loss 0.19, Val loss 0.00
# Epoch 43, Loss 0.19, Val loss 0.00
# Epoch 44, Loss 0.19, Val loss 0.00
# Epoch 45, Loss 0.19, Val loss 0.00
# Epoch 46, Loss 0.19, Val loss 0.00
# Epoch 47, Loss 0.19, Val loss 0.00
# Epoch 48, Loss 0.19, Val loss 0.00
# Epoch 49, Loss 0.19, Val loss 0.00
# TRAINING NEW LOCATION: Colorado
# Saved model
# Epoch 0, Loss 14482.32, Val loss 81.50
# Epoch 1, Loss 96717.62, Val loss 611.12
# Epoch 2, Loss 131353.38, Val loss 1242.01
# Epoch 3, Loss 51834.74, Val loss 1040.96
# Epoch 4, Loss 12940.21, Val loss 492.65
# Epoch 5, Loss 3228.32, Val loss 144.91
# Saved model
# Epoch 6, Loss 818.74, Val loss 74.58
# Saved model
# Epoch 7, Loss 352.01, Val loss 29.78
# Saved model
# Epoch 8, Loss 143.03, Val loss 15.73
# Saved model
# Epoch 9, Loss 66.70, Val loss 6.84
# Saved model
# Epoch 10, Loss 42.18, Val loss 4.73
# Saved model
# Epoch 11, Loss 26.07, Val loss 3.60
# Saved model
# Epoch 12, Loss 18.15, Val loss 2.52
# Saved model
# Epoch 13, Loss 13.35, Val loss 2.12
# Saved model
# Epoch 14, Loss 9.93, Val loss 1.72
# Saved model
# Epoch 15, Loss 8.86, Val loss 1.65
# Saved model
# Epoch 16, Loss 7.84, Val loss 1.42
# Saved model
# Epoch 17, Loss 6.04, Val loss 1.35
# Saved model
# Epoch 18, Loss 4.60, Val loss 1.29
# Saved model
# Epoch 19, Loss 4.60, Val loss 1.19
# Saved model
# Epoch 20, Loss 3.60, Val loss 1.07
# Saved model
# Epoch 21, Loss 3.45, Val loss 1.06
# Saved model
# Epoch 22, Loss 3.37, Val loss 0.99
# Saved model
# Epoch 23, Loss 3.34, Val loss 0.91
# Saved model
# Epoch 24, Loss 2.87, Val loss 0.88
# Saved model
# Epoch 25, Loss 2.61, Val loss 0.85
# Saved model
# Epoch 26, Loss 2.16, Val loss 0.81
# Epoch 27, Loss 1.92, Val loss 0.84
# Epoch 28, Loss 1.96, Val loss 0.90
# Epoch 29, Loss 2.12, Val loss 0.96
# Epoch 30, Loss 2.26, Val loss 0.95
# Epoch 31, Loss 1.92, Val loss 1.11
# Epoch 32, Loss 1.79, Val loss 1.01
# Epoch 33, Loss 1.60, Val loss 1.12
# Epoch 34, Loss 1.57, Val loss 1.07
# Epoch 35, Loss 1.35, Val loss 1.15
# Epoch 36, Loss 1.51, Val loss 1.21
# Epoch 37, Loss 1.41, Val loss 1.25
# Epoch 38, Loss 1.43, Val loss 1.20
# Epoch 39, Loss 1.59, Val loss 1.08
# Epoch 40, Loss 1.41, Val loss 1.00
# Epoch 41, Loss 1.53, Val loss 0.92
# Epoch 42, Loss 1.67, Val loss 0.89
# Epoch 43, Loss 1.24, Val loss 0.91
# Epoch 44, Loss 1.11, Val loss 0.93
# Epoch 45, Loss 1.64, Val loss 1.00
# Epoch 46, Loss 1.32, Val loss 0.99
# Epoch 47, Loss 1.19, Val loss 1.05
# Epoch 48, Loss 1.20, Val loss 1.08
# Epoch 49, Loss 1.52, Val loss 1.05
# TRAINING NEW LOCATION: Connecticut
# Saved model
# Epoch 0, Loss 1135.28, Val loss 227.30
# Epoch 1, Loss 66931.98, Val loss 1888.88
# Epoch 2, Loss 93354.77, Val loss 5499.74
# Epoch 3, Loss 61262.20, Val loss 7978.97
# Epoch 4, Loss 31539.17, Val loss 8262.50
# Epoch 5, Loss 16649.09, Val loss 7062.47
# Epoch 6, Loss 10827.40, Val loss 5152.97
# Epoch 7, Loss 6016.29, Val loss 1693.07
# Epoch 8, Loss 1588.45, Val loss 1204.53
# Epoch 9, Loss 686.52, Val loss 250.69
# Saved model
# Epoch 10, Loss 159.40, Val loss 63.08
# Saved model
# Epoch 11, Loss 76.75, Val loss 40.52
# Saved model
# Epoch 12, Loss 42.39, Val loss 13.46
# Saved model
# Epoch 13, Loss 15.84, Val loss 8.51
# Saved model
# Epoch 14, Loss 9.32, Val loss 7.78
# Saved model
# Epoch 15, Loss 4.05, Val loss 4.49
# Epoch 16, Loss 4.39, Val loss 5.25
# Saved model
# Epoch 17, Loss 2.71, Val loss 3.62
# Saved model
# Epoch 18, Loss 1.95, Val loss 2.60
# Saved model
# Epoch 19, Loss 1.67, Val loss 2.45
# Saved model
# Epoch 20, Loss 1.37, Val loss 2.27
# Saved model
# Epoch 21, Loss 1.50, Val loss 2.01
# Saved model
# Epoch 22, Loss 1.31, Val loss 1.93
# Saved model
# Epoch 23, Loss 1.12, Val loss 1.79
# Saved model
# Epoch 24, Loss 1.16, Val loss 1.71
# Epoch 25, Loss 0.99, Val loss 1.73
# Epoch 26, Loss 1.03, Val loss 1.92
# Epoch 27, Loss 0.93, Val loss 1.76
# Epoch 28, Loss 0.92, Val loss 1.74
# Epoch 29, Loss 0.89, Val loss 1.74
# Saved model
# Epoch 30, Loss 0.91, Val loss 1.70
# Saved model
# Epoch 31, Loss 0.82, Val loss 1.67
# Saved model
# Epoch 32, Loss 0.82, Val loss 1.65
# Saved model
# Epoch 33, Loss 0.79, Val loss 1.62
# Saved model
# Epoch 34, Loss 0.79, Val loss 1.60
# Saved model
# Epoch 35, Loss 0.82, Val loss 1.59
# Epoch 36, Loss 0.80, Val loss 1.60
# Epoch 37, Loss 0.75, Val loss 1.62
# Epoch 38, Loss 0.78, Val loss 1.63
# Epoch 39, Loss 0.77, Val loss 1.64
# Epoch 40, Loss 0.76, Val loss 1.64
# Epoch 41, Loss 0.76, Val loss 1.66
# Epoch 42, Loss 0.75, Val loss 1.63
# Epoch 43, Loss 0.78, Val loss 1.63
# Epoch 44, Loss 0.73, Val loss 1.60
# Epoch 45, Loss 0.72, Val loss 1.60
# Saved model
# Epoch 46, Loss 0.74, Val loss 1.59
# Saved model
# Epoch 47, Loss 0.71, Val loss 1.58
# Epoch 48, Loss 0.73, Val loss 1.60
# Epoch 49, Loss 0.72, Val loss 1.61
# TRAINING NEW LOCATION: Delaware
# Saved model
# Epoch 0, Loss 605.76, Val loss 654.13
# Epoch 1, Loss 6526.49, Val loss 4923.79
# Epoch 2, Loss 11195.62, Val loss 5325.52
# Epoch 3, Loss 4883.12, Val loss 1097.46
# Saved model
# Epoch 4, Loss 672.44, Val loss 181.02
# Saved model
# Epoch 5, Loss 119.94, Val loss 44.01
# Saved model
# Epoch 6, Loss 34.27, Val loss 14.62
# Saved model
# Epoch 7, Loss 16.71, Val loss 6.31
# Saved model
# Epoch 8, Loss 10.61, Val loss 3.01
# Saved model
# Epoch 9, Loss 7.66, Val loss 1.75
# Saved model
# Epoch 10, Loss 6.33, Val loss 1.19
# Saved model
# Epoch 11, Loss 5.55, Val loss 0.81
# Saved model
# Epoch 12, Loss 4.93, Val loss 0.57
# Saved model
# Epoch 13, Loss 4.55, Val loss 0.52
# Saved model
# Epoch 14, Loss 4.18, Val loss 0.52
# Saved model
# Epoch 15, Loss 4.11, Val loss 0.34
# Saved model
# Epoch 16, Loss 3.86, Val loss 0.32
# Epoch 17, Loss 3.41, Val loss 0.39
# Saved model
# Epoch 18, Loss 3.43, Val loss 0.24
# Epoch 19, Loss 2.93, Val loss 0.34
# Epoch 20, Loss 2.82, Val loss 0.30
# Epoch 21, Loss 2.84, Val loss 0.33
# Epoch 22, Loss 2.81, Val loss 0.28
# Epoch 23, Loss 2.80, Val loss 0.26
# Epoch 24, Loss 2.55, Val loss 0.24
# Epoch 25, Loss 2.51, Val loss 0.24
# Epoch 26, Loss 2.59, Val loss 0.26
# Epoch 27, Loss 2.53, Val loss 0.26
# Epoch 28, Loss 2.40, Val loss 0.33
# Epoch 29, Loss 2.29, Val loss 0.27
# Epoch 30, Loss 2.29, Val loss 0.32
# Epoch 31, Loss 2.14, Val loss 0.28
# Epoch 32, Loss 2.23, Val loss 0.28
# Epoch 33, Loss 2.15, Val loss 0.28
# Epoch 34, Loss 2.11, Val loss 0.31
# Epoch 35, Loss 2.08, Val loss 0.35
# Epoch 36, Loss 2.05, Val loss 0.33
# Epoch 37, Loss 2.02, Val loss 0.28
# Epoch 38, Loss 2.26, Val loss 0.32
# Epoch 39, Loss 2.07, Val loss 0.30
# Epoch 40, Loss 1.95, Val loss 0.26
# Epoch 41, Loss 1.86, Val loss 0.24
# Epoch 42, Loss 2.11, Val loss 0.24
# Epoch 43, Loss 1.91, Val loss 0.30
# Epoch 44, Loss 2.05, Val loss 0.30
# Epoch 45, Loss 1.98, Val loss 0.30
# Epoch 46, Loss 1.86, Val loss 0.35
# Epoch 47, Loss 1.83, Val loss 0.35
# Epoch 48, Loss 1.99, Val loss 0.30
# Epoch 49, Loss 1.85, Val loss 0.32
# TRAINING NEW LOCATION: District of Columbia
# Saved model
# Epoch 0, Loss 31.59, Val loss 70.74
# Epoch 1, Loss 385.21, Val loss 207.70
# Epoch 2, Loss 544.44, Val loss 164.09
# Saved model
# Epoch 3, Loss 381.95, Val loss 23.08
# Saved model
# Epoch 4, Loss 156.16, Val loss 1.09
# Saved model
# Epoch 5, Loss 28.90, Val loss 0.10
# Saved model
# Epoch 6, Loss 6.08, Val loss 0.07
# Epoch 7, Loss 3.84, Val loss 0.08
# Epoch 8, Loss 3.48, Val loss 0.08
# Epoch 9, Loss 3.41, Val loss 0.08
# Epoch 10, Loss 3.38, Val loss 0.08
# Epoch 11, Loss 3.40, Val loss 0.09
# Epoch 12, Loss 3.43, Val loss 0.11
# Epoch 13, Loss 3.42, Val loss 0.12
# Epoch 14, Loss 3.42, Val loss 0.12
# Epoch 15, Loss 3.41, Val loss 0.13
# Epoch 16, Loss 3.42, Val loss 0.12
# Epoch 17, Loss 3.40, Val loss 0.12
# Epoch 18, Loss 3.40, Val loss 0.11
# Epoch 19, Loss 3.40, Val loss 0.10
# Epoch 20, Loss 3.39, Val loss 0.09
# Epoch 21, Loss 3.38, Val loss 0.09
# Epoch 22, Loss 3.37, Val loss 0.08
# Epoch 23, Loss 3.37, Val loss 0.08
# Epoch 24, Loss 3.37, Val loss 0.08
# Epoch 25, Loss 3.35, Val loss 0.08
# Epoch 26, Loss 3.35, Val loss 0.08
# Epoch 27, Loss 3.34, Val loss 0.09
# Epoch 28, Loss 3.33, Val loss 0.09
# Epoch 29, Loss 3.32, Val loss 0.09
# Epoch 30, Loss 3.29, Val loss 0.10
# Epoch 31, Loss 3.28, Val loss 0.10
# Epoch 32, Loss 3.27, Val loss 0.09
# Epoch 33, Loss 3.27, Val loss 0.09
# Epoch 34, Loss 3.25, Val loss 0.09
# Epoch 35, Loss 3.24, Val loss 0.09
# Epoch 36, Loss 3.26, Val loss 0.08
# Epoch 37, Loss 3.22, Val loss 0.08
# Epoch 38, Loss 3.21, Val loss 0.08
# Saved model
# Epoch 39, Loss 3.21, Val loss 0.06
# Epoch 40, Loss 3.21, Val loss 0.07
# Epoch 41, Loss 3.19, Val loss 0.06
# Saved model
# Epoch 42, Loss 3.17, Val loss 0.06
# Saved model
# Epoch 43, Loss 3.17, Val loss 0.06
# Saved model
# Epoch 44, Loss 3.19, Val loss 0.06
# Epoch 45, Loss 3.14, Val loss 0.07
# Epoch 46, Loss 3.12, Val loss 0.06
# Epoch 47, Loss 3.13, Val loss 0.06
# Epoch 48, Loss 3.13, Val loss 0.06
# Saved model
# Epoch 49, Loss 3.11, Val loss 0.06
# TRAINING NEW LOCATION: Florida
# Saved model
# Epoch 0, Loss 1.23, Val loss 0.03
# Epoch 1, Loss 1.04, Val loss 0.04
# Epoch 2, Loss 0.98, Val loss 0.03
# Saved model
# Epoch 3, Loss 0.90, Val loss 0.02
# Saved model
# Epoch 4, Loss 0.81, Val loss 0.02
# Saved model
# Epoch 5, Loss 0.73, Val loss 0.02
# Saved model
# Epoch 6, Loss 0.64, Val loss 0.01
# Epoch 7, Loss 0.55, Val loss 0.02
# Epoch 8, Loss 0.46, Val loss 0.02
# Epoch 9, Loss 0.42, Val loss 0.02
# Epoch 10, Loss 0.40, Val loss 0.03
# Epoch 11, Loss 0.38, Val loss 0.02
# Epoch 12, Loss 0.37, Val loss 0.02
# Epoch 13, Loss 0.35, Val loss 0.02
# Epoch 14, Loss 0.35, Val loss 0.02
# Epoch 15, Loss 0.36, Val loss 0.02
# Epoch 16, Loss 0.33, Val loss 0.02
# Epoch 17, Loss 0.33, Val loss 0.02
# Epoch 18, Loss 0.34, Val loss 0.02
# Epoch 19, Loss 0.34, Val loss 0.02
# Epoch 20, Loss 0.33, Val loss 0.01
# Saved model
# Epoch 21, Loss 0.34, Val loss 0.01
# Saved model
# Epoch 22, Loss 0.32, Val loss 0.01
# Epoch 23, Loss 0.31, Val loss 0.01
# Epoch 24, Loss 0.31, Val loss 0.01
# Epoch 25, Loss 0.32, Val loss 0.01
# Epoch 26, Loss 0.31, Val loss 0.01
# Epoch 27, Loss 0.30, Val loss 0.01
# Epoch 28, Loss 0.31, Val loss 0.01
# Epoch 29, Loss 0.29, Val loss 0.01
# Epoch 30, Loss 0.29, Val loss 0.01
# Saved model
# Epoch 31, Loss 0.30, Val loss 0.01
# Saved model
# Epoch 32, Loss 0.30, Val loss 0.01
# Epoch 33, Loss 0.29, Val loss 0.01
# Epoch 34, Loss 0.29, Val loss 0.01
# Epoch 35, Loss 0.29, Val loss 0.01
# Saved model
# Epoch 36, Loss 0.29, Val loss 0.01
# Saved model
# Epoch 37, Loss 0.28, Val loss 0.01
# Epoch 38, Loss 0.28, Val loss 0.01
# Epoch 39, Loss 0.28, Val loss 0.01
# Epoch 40, Loss 0.28, Val loss 0.01
# Epoch 41, Loss 0.27, Val loss 0.01
# Saved model
# Epoch 42, Loss 0.27, Val loss 0.01
# Saved model
# Epoch 43, Loss 0.27, Val loss 0.01
# Saved model
# Epoch 44, Loss 0.27, Val loss 0.01
# Saved model
# Epoch 45, Loss 0.27, Val loss 0.00
# Saved model
# Epoch 46, Loss 0.27, Val loss 0.00
# Saved model
# Epoch 47, Loss 0.26, Val loss 0.00
# Epoch 48, Loss 0.27, Val loss 0.00
# Epoch 49, Loss 0.27, Val loss 0.01
# TRAINING NEW LOCATION: Georgia
# Saved model
# Epoch 0, Loss 0.47, Val loss 0.08
# Saved model
# Epoch 1, Loss 0.30, Val loss 0.05
# Saved model
# Epoch 2, Loss 0.26, Val loss 0.02
# Saved model
# Epoch 3, Loss 0.20, Val loss 0.02
# Saved model
# Epoch 4, Loss 0.19, Val loss 0.02
# Saved model
# Epoch 5, Loss 0.17, Val loss 0.01
# Saved model
# Epoch 6, Loss 0.16, Val loss 0.01
# Saved model
# Epoch 7, Loss 0.15, Val loss 0.01
# Saved model
# Epoch 8, Loss 0.14, Val loss 0.01
# Saved model
# Epoch 9, Loss 0.13, Val loss 0.01
# Epoch 10, Loss 0.12, Val loss 0.01
# Epoch 11, Loss 0.12, Val loss 0.01
# Epoch 12, Loss 0.11, Val loss 0.01
# Epoch 13, Loss 0.11, Val loss 0.01
# Epoch 14, Loss 0.11, Val loss 0.01
# Epoch 15, Loss 0.10, Val loss 0.01
# Epoch 16, Loss 0.10, Val loss 0.01
# Epoch 17, Loss 0.10, Val loss 0.01
# Epoch 18, Loss 0.09, Val loss 0.01
# Saved model
# Epoch 19, Loss 0.10, Val loss 0.01
# Saved model
# Epoch 20, Loss 0.09, Val loss 0.00
# Saved model
# Epoch 21, Loss 0.09, Val loss 0.00
# Saved model
# Epoch 22, Loss 0.09, Val loss 0.00
# Saved model
# Epoch 23, Loss 0.09, Val loss 0.00
# Epoch 24, Loss 0.09, Val loss 0.00
# Epoch 25, Loss 0.09, Val loss 0.00
# Epoch 26, Loss 0.09, Val loss 0.00
# Epoch 27, Loss 0.09, Val loss 0.00
# Saved model
# Epoch 28, Loss 0.09, Val loss 0.00
# Saved model
# Epoch 29, Loss 0.09, Val loss 0.00
# Saved model
# Epoch 30, Loss 0.08, Val loss 0.00
# Saved model
# Epoch 31, Loss 0.09, Val loss 0.00
# Epoch 32, Loss 0.08, Val loss 0.00
# Epoch 33, Loss 0.09, Val loss 0.00
# Epoch 34, Loss 0.08, Val loss 0.00
# Epoch 35, Loss 0.08, Val loss 0.00
# Epoch 36, Loss 0.08, Val loss 0.00
# Epoch 37, Loss 0.09, Val loss 0.00
# Epoch 38, Loss 0.08, Val loss 0.00
# Epoch 39, Loss 0.09, Val loss 0.00
# Epoch 40, Loss 0.08, Val loss 0.00
# Epoch 41, Loss 0.08, Val loss 0.00
# Epoch 42, Loss 0.08, Val loss 0.00
# Epoch 43, Loss 0.08, Val loss 0.00
# Epoch 44, Loss 0.08, Val loss 0.00
# Epoch 45, Loss 0.08, Val loss 0.00
# Epoch 46, Loss 0.08, Val loss 0.00
# Epoch 47, Loss 0.08, Val loss 0.00
# Epoch 48, Loss 0.08, Val loss 0.00
# Epoch 49, Loss 0.08, Val loss 0.00
# TRAINING NEW LOCATION: Hawaii
# Saved model
# Epoch 0, Loss 16.77, Val loss 24.67
# Saved model
# Epoch 1, Loss 57.85, Val loss 0.26
# Saved model
# Epoch 2, Loss 4.58, Val loss 0.08
# Epoch 3, Loss 3.44, Val loss 0.08
# Epoch 4, Loss 3.29, Val loss 0.08
# Epoch 5, Loss 3.22, Val loss 0.09
# Epoch 6, Loss 3.19, Val loss 0.10
# Epoch 7, Loss 3.18, Val loss 0.11
# Epoch 8, Loss 3.17, Val loss 0.09
# Epoch 9, Loss 3.14, Val loss 0.08
# Saved model
# Epoch 10, Loss 3.12, Val loss 0.07
# Epoch 11, Loss 3.11, Val loss 0.08
# Epoch 12, Loss 3.09, Val loss 0.10
# Epoch 13, Loss 3.07, Val loss 0.10
# Epoch 14, Loss 3.05, Val loss 0.09
# Epoch 15, Loss 3.06, Val loss 0.10
# Epoch 16, Loss 3.02, Val loss 0.12
# Epoch 17, Loss 3.00, Val loss 0.11
# Epoch 18, Loss 2.98, Val loss 0.15
# Epoch 19, Loss 2.98, Val loss 0.13
# Epoch 20, Loss 2.96, Val loss 0.13
# Epoch 21, Loss 2.95, Val loss 0.15
# Epoch 22, Loss 2.95, Val loss 0.16
# Epoch 23, Loss 2.93, Val loss 0.12
# Epoch 24, Loss 2.90, Val loss 0.12
# Epoch 25, Loss 2.91, Val loss 0.11
# Epoch 26, Loss 2.87, Val loss 0.12
# Epoch 27, Loss 2.85, Val loss 0.15
# Epoch 28, Loss 2.84, Val loss 0.17
# Epoch 29, Loss 2.80, Val loss 0.19
# Epoch 30, Loss 2.81, Val loss 0.20
# Epoch 31, Loss 2.77, Val loss 0.22
# Epoch 32, Loss 2.76, Val loss 0.23
# Epoch 33, Loss 2.70, Val loss 0.31
# Epoch 34, Loss 2.71, Val loss 0.34
# Epoch 35, Loss 2.67, Val loss 0.38
# Epoch 36, Loss 2.64, Val loss 0.42
# Epoch 37, Loss 2.64, Val loss 0.43
# Epoch 38, Loss 2.60, Val loss 0.40
# Epoch 39, Loss 2.56, Val loss 0.41
# Epoch 40, Loss 2.55, Val loss 0.46
# Epoch 41, Loss 2.52, Val loss 0.48
# Epoch 42, Loss 2.52, Val loss 0.51
# Epoch 43, Loss 2.46, Val loss 0.57
# Epoch 44, Loss 2.47, Val loss 0.57
# Epoch 45, Loss 2.40, Val loss 0.69
# Epoch 46, Loss 2.40, Val loss 0.69
# Epoch 47, Loss 2.48, Val loss 0.67
# Epoch 48, Loss 2.43, Val loss 0.76
# Epoch 49, Loss 2.38, Val loss 0.80
# TRAINING NEW LOCATION: Idaho
# Saved model
# Epoch 0, Loss 199.02, Val loss 83.60
# Epoch 1, Loss 591.07, Val loss 675.88
# Epoch 2, Loss 1296.49, Val loss 1566.76
# Epoch 3, Loss 1280.73, Val loss 1445.97
# Epoch 4, Loss 512.47, Val loss 406.20
# Epoch 5, Loss 109.93, Val loss 94.13
# Saved model
# Epoch 6, Loss 34.08, Val loss 29.23
# Saved model
# Epoch 7, Loss 14.46, Val loss 12.87
# Saved model
# Epoch 8, Loss 7.56, Val loss 10.04
# Saved model
# Epoch 9, Loss 5.16, Val loss 6.14
# Saved model
# Epoch 10, Loss 3.95, Val loss 3.45
# Saved model
# Epoch 11, Loss 3.02, Val loss 3.44
# Epoch 12, Loss 2.55, Val loss 3.46
# Saved model
# Epoch 13, Loss 2.41, Val loss 2.20
# Epoch 14, Loss 2.08, Val loss 2.34
# Saved model
# Epoch 15, Loss 1.93, Val loss 2.02
# Saved model
# Epoch 16, Loss 1.76, Val loss 1.87
# Saved model
# Epoch 17, Loss 1.71, Val loss 1.70
# Epoch 18, Loss 1.63, Val loss 1.74
# Saved model
# Epoch 19, Loss 1.66, Val loss 1.63
# Saved model
# Epoch 20, Loss 1.55, Val loss 1.28
# Epoch 21, Loss 1.52, Val loss 1.38
# Saved model
# Epoch 22, Loss 1.46, Val loss 1.06
# Epoch 23, Loss 1.48, Val loss 1.33
# Saved model
# Epoch 24, Loss 1.46, Val loss 1.02
# Epoch 25, Loss 1.41, Val loss 1.04
# Epoch 26, Loss 1.42, Val loss 1.24
# Saved model
# Epoch 27, Loss 1.43, Val loss 0.99
# Epoch 28, Loss 1.39, Val loss 1.14
# Epoch 29, Loss 1.39, Val loss 1.20
# Epoch 30, Loss 1.39, Val loss 1.05
# Epoch 31, Loss 1.38, Val loss 1.08
# Epoch 32, Loss 1.35, Val loss 1.11
# Epoch 33, Loss 1.35, Val loss 1.12
# Epoch 34, Loss 1.32, Val loss 1.14
# Epoch 35, Loss 1.35, Val loss 1.15
# Epoch 36, Loss 1.33, Val loss 1.10
# Saved model
# Epoch 37, Loss 1.30, Val loss 0.93
# Epoch 38, Loss 1.30, Val loss 0.98
# Epoch 39, Loss 1.28, Val loss 1.02
# Epoch 40, Loss 1.29, Val loss 1.03
# Epoch 41, Loss 1.28, Val loss 1.10
# Epoch 42, Loss 1.27, Val loss 1.07
# Epoch 43, Loss 1.29, Val loss 0.99
# Epoch 44, Loss 1.25, Val loss 0.95
# Epoch 45, Loss 1.29, Val loss 1.17
# Epoch 46, Loss 1.27, Val loss 0.98
# Epoch 47, Loss 1.27, Val loss 1.00
# Saved model
# Epoch 48, Loss 1.25, Val loss 0.86
# Epoch 49, Loss 1.25, Val loss 0.93
# TRAINING NEW LOCATION: Illinois
# Saved model
# Epoch 0, Loss 0.26, Val loss 0.04
# Saved model
# Epoch 1, Loss 0.11, Val loss 0.02
# Saved model
# Epoch 2, Loss 0.06, Val loss 0.02
# Saved model
# Epoch 3, Loss 0.06, Val loss 0.02
# Saved model
# Epoch 4, Loss 0.06, Val loss 0.01
# Saved model
# Epoch 5, Loss 0.05, Val loss 0.01
# Saved model
# Epoch 6, Loss 0.04, Val loss 0.01
# Saved model
# Epoch 7, Loss 0.04, Val loss 0.01
# Saved model
# Epoch 8, Loss 0.05, Val loss 0.01
# Epoch 9, Loss 0.04, Val loss 0.01
# Epoch 10, Loss 0.03, Val loss 0.01
# Epoch 11, Loss 0.03, Val loss 0.01
# Epoch 12, Loss 0.03, Val loss 0.01
# Epoch 13, Loss 0.03, Val loss 0.01
# Epoch 14, Loss 0.03, Val loss 0.01
# Epoch 15, Loss 0.03, Val loss 0.01
# Epoch 16, Loss 0.03, Val loss 0.01
# Epoch 17, Loss 0.03, Val loss 0.01
# Saved model
# Epoch 18, Loss 0.03, Val loss 0.00
# Saved model
# Epoch 19, Loss 0.02, Val loss 0.00
# Saved model
# Epoch 20, Loss 0.02, Val loss 0.00
# Saved model
# Epoch 21, Loss 0.03, Val loss 0.00
# Saved model
# Epoch 22, Loss 0.02, Val loss 0.00
# Epoch 23, Loss 0.02, Val loss 0.00
# Epoch 24, Loss 0.02, Val loss 0.00
# Epoch 25, Loss 0.02, Val loss 0.00
# Epoch 26, Loss 0.03, Val loss 0.00
# Epoch 27, Loss 0.02, Val loss 0.00
# Epoch 28, Loss 0.02, Val loss 0.00
# Epoch 29, Loss 0.02, Val loss 0.00
# Epoch 30, Loss 0.02, Val loss 0.00
# Epoch 31, Loss 0.02, Val loss 0.00
# Epoch 32, Loss 0.02, Val loss 0.00
# Epoch 33, Loss 0.02, Val loss 0.00
# Epoch 34, Loss 0.02, Val loss 0.00
# Epoch 35, Loss 0.02, Val loss 0.00
# Epoch 36, Loss 0.02, Val loss 0.00
# Epoch 37, Loss 0.02, Val loss 0.00
# Epoch 38, Loss 0.02, Val loss 0.00
# Epoch 39, Loss 0.02, Val loss 0.00
# Epoch 40, Loss 0.02, Val loss 0.00
# Epoch 41, Loss 0.02, Val loss 0.00
# Epoch 42, Loss 0.02, Val loss 0.00
# Epoch 43, Loss 0.02, Val loss 0.00
# Epoch 44, Loss 0.02, Val loss 0.00
# Saved model
# Epoch 45, Loss 0.02, Val loss 0.00
# Saved model
# Epoch 46, Loss 0.02, Val loss 0.00
# Saved model
# Epoch 47, Loss 0.02, Val loss 0.00
# Epoch 48, Loss 0.02, Val loss 0.00
# Epoch 49, Loss 0.02, Val loss 0.00
# TRAINING NEW LOCATION: Indiana
# Saved model
# Epoch 0, Loss 1.34, Val loss 57.34
# Saved model
# Epoch 1, Loss 27.59, Val loss 0.66
# Epoch 2, Loss 1.37, Val loss 0.94
# Epoch 3, Loss 1.07, Val loss 0.96
# Epoch 4, Loss 1.00, Val loss 0.92
# Epoch 5, Loss 0.97, Val loss 0.84
# Epoch 6, Loss 0.92, Val loss 0.78
# Epoch 7, Loss 0.91, Val loss 0.72
# Epoch 8, Loss 0.91, Val loss 0.72
# Epoch 9, Loss 0.92, Val loss 0.70
# Epoch 10, Loss 0.92, Val loss 0.67
# Epoch 11, Loss 0.90, Val loss 0.69
# Saved model
# Epoch 12, Loss 0.88, Val loss 0.62
# Epoch 13, Loss 0.87, Val loss 0.67
# Epoch 14, Loss 0.85, Val loss 0.64
# Epoch 15, Loss 0.84, Val loss 0.64
# Epoch 16, Loss 0.85, Val loss 0.63
# Epoch 17, Loss 0.83, Val loss 0.66
# Saved model
# Epoch 18, Loss 0.85, Val loss 0.58
# Epoch 19, Loss 0.83, Val loss 0.63
# Epoch 20, Loss 0.81, Val loss 0.69
# Epoch 21, Loss 0.83, Val loss 0.72
# Epoch 22, Loss 0.80, Val loss 0.63
# Epoch 23, Loss 0.80, Val loss 0.72
# Saved model
# Epoch 24, Loss 0.80, Val loss 0.55
# Saved model
# Epoch 25, Loss 0.78, Val loss 0.50
# Saved model
# Epoch 26, Loss 0.78, Val loss 0.40
# Epoch 27, Loss 0.77, Val loss 0.42
# Epoch 28, Loss 0.76, Val loss 0.46
# Saved model
# Epoch 29, Loss 0.77, Val loss 0.37
# Epoch 30, Loss 0.75, Val loss 0.43
# Epoch 31, Loss 0.76, Val loss 0.48
# Epoch 32, Loss 0.74, Val loss 0.51
# Epoch 33, Loss 0.74, Val loss 0.50
# Epoch 34, Loss 0.73, Val loss 0.53
# Epoch 35, Loss 0.74, Val loss 0.52
# Epoch 36, Loss 0.74, Val loss 0.51
# Epoch 37, Loss 0.74, Val loss 0.59
# Epoch 38, Loss 0.74, Val loss 0.55
# Epoch 39, Loss 0.71, Val loss 0.48
# Epoch 40, Loss 0.71, Val loss 0.49
# Epoch 41, Loss 0.70, Val loss 0.57
# Epoch 42, Loss 0.69, Val loss 0.48
# Epoch 43, Loss 0.74, Val loss 0.48
# Epoch 44, Loss 0.68, Val loss 0.52
# Epoch 45, Loss 0.68, Val loss 0.54
# Epoch 46, Loss 0.66, Val loss 0.55
# Epoch 47, Loss 0.66, Val loss 0.60
# Epoch 48, Loss 0.67, Val loss 0.58
# Epoch 49, Loss 0.66, Val loss 0.55
# TRAINING NEW LOCATION: Iowa
# Saved model
# Epoch 0, Loss 3.39, Val loss 1.81
# Epoch 1, Loss 44.48, Val loss 7.59
# Epoch 2, Loss 39.83, Val loss 2.99
# Saved model
# Epoch 3, Loss 7.54, Val loss 1.25
# Saved model
# Epoch 4, Loss 2.11, Val loss 1.08
# Saved model
# Epoch 5, Loss 1.42, Val loss 1.01
# Saved model
# Epoch 6, Loss 1.17, Val loss 0.99
# Epoch 7, Loss 1.07, Val loss 0.99
# Epoch 8, Loss 1.06, Val loss 1.03
# Epoch 9, Loss 1.05, Val loss 1.05
# Epoch 10, Loss 1.03, Val loss 1.09
# Epoch 11, Loss 1.03, Val loss 1.09
# Epoch 12, Loss 1.03, Val loss 1.08
# Epoch 13, Loss 1.00, Val loss 1.03
# Epoch 14, Loss 0.99, Val loss 1.04
# Epoch 15, Loss 0.98, Val loss 1.05
# Epoch 16, Loss 0.96, Val loss 1.06
# Epoch 17, Loss 0.98, Val loss 1.04
# Saved model
# Epoch 18, Loss 0.95, Val loss 0.99
# Epoch 19, Loss 0.98, Val loss 1.00
# Epoch 20, Loss 0.94, Val loss 1.00
# Saved model
# Epoch 21, Loss 0.93, Val loss 0.96
# Saved model
# Epoch 22, Loss 0.95, Val loss 0.94
# Saved model
# Epoch 23, Loss 0.96, Val loss 0.94
# Saved model
# Epoch 24, Loss 0.95, Val loss 0.93
# Epoch 25, Loss 0.93, Val loss 0.95
# Epoch 26, Loss 0.93, Val loss 0.98
# Epoch 27, Loss 0.92, Val loss 1.01
# Epoch 28, Loss 0.93, Val loss 1.05
# Epoch 29, Loss 0.92, Val loss 1.09
# Epoch 30, Loss 0.92, Val loss 1.05
# Epoch 31, Loss 0.96, Val loss 1.07
# Epoch 32, Loss 0.91, Val loss 1.06
# Epoch 33, Loss 0.92, Val loss 1.12
# Epoch 34, Loss 0.92, Val loss 1.01
# Epoch 35, Loss 0.94, Val loss 1.04
# Epoch 36, Loss 0.91, Val loss 1.05
# Epoch 37, Loss 0.92, Val loss 1.01
# Epoch 38, Loss 0.91, Val loss 1.01
# Epoch 39, Loss 0.90, Val loss 1.00
# Epoch 40, Loss 0.90, Val loss 0.96
# Epoch 41, Loss 0.91, Val loss 0.99
# Epoch 42, Loss 0.90, Val loss 1.01
# Epoch 43, Loss 0.91, Val loss 1.02
# Epoch 44, Loss 0.90, Val loss 1.04
# Epoch 45, Loss 0.90, Val loss 1.03
# Epoch 46, Loss 0.90, Val loss 1.06
# Epoch 47, Loss 0.90, Val loss 1.06
# Epoch 48, Loss 0.91, Val loss 1.06
# Epoch 49, Loss 0.91, Val loss 1.06
# TRAINING NEW LOCATION: Kansas
# Saved model
# Epoch 0, Loss 14124.46, Val loss 38.24
# Epoch 1, Loss 249003.11, Val loss 256.67
# Epoch 2, Loss 264580.41, Val loss 495.80
# Epoch 3, Loss 78788.80, Val loss 420.98
# Epoch 4, Loss 16528.01, Val loss 217.37
# Epoch 5, Loss 4232.70, Val loss 91.34
# Saved model
# Epoch 6, Loss 1303.55, Val loss 37.52
# Saved model
# Epoch 7, Loss 546.94, Val loss 16.74
# Saved model
# Epoch 8, Loss 256.43, Val loss 9.68
# Saved model
# Epoch 9, Loss 127.44, Val loss 5.56
# Saved model
# Epoch 10, Loss 80.77, Val loss 3.50
# Saved model
# Epoch 11, Loss 55.38, Val loss 2.52
# Saved model
# Epoch 12, Loss 36.05, Val loss 2.01
# Saved model
# Epoch 13, Loss 28.72, Val loss 1.48
# Saved model
# Epoch 14, Loss 27.73, Val loss 1.21
# Saved model
# Epoch 15, Loss 15.65, Val loss 1.15
# Saved model
# Epoch 16, Loss 15.75, Val loss 1.07
# Epoch 17, Loss 12.36, Val loss 1.12
# Saved model
# Epoch 18, Loss 9.49, Val loss 0.93
# Saved model
# Epoch 19, Loss 9.38, Val loss 0.88
# Epoch 20, Loss 8.02, Val loss 0.96
# Saved model
# Epoch 21, Loss 6.92, Val loss 0.80
# Saved model
# Epoch 22, Loss 7.51, Val loss 0.69
# Epoch 23, Loss 6.68, Val loss 0.71
# Saved model
# Epoch 24, Loss 6.35, Val loss 0.68
# Epoch 25, Loss 4.05, Val loss 0.70
# Epoch 26, Loss 5.07, Val loss 0.68
# Saved model
# Epoch 27, Loss 5.52, Val loss 0.65
# Epoch 28, Loss 5.06, Val loss 0.71
# Saved model
# Epoch 29, Loss 4.22, Val loss 0.64
# Epoch 30, Loss 3.84, Val loss 0.64
# Saved model
# Epoch 31, Loss 4.79, Val loss 0.63
# Epoch 32, Loss 3.38, Val loss 0.66
# Epoch 33, Loss 3.21, Val loss 0.67
# Epoch 34, Loss 3.74, Val loss 0.65
# Epoch 35, Loss 3.73, Val loss 0.64
# Epoch 36, Loss 3.09, Val loss 0.68
# Epoch 37, Loss 3.08, Val loss 0.65
# Saved model
# Epoch 38, Loss 2.96, Val loss 0.63
# Saved model
# Epoch 39, Loss 3.30, Val loss 0.62
# Epoch 40, Loss 3.08, Val loss 0.63
# Saved model
# Epoch 41, Loss 3.20, Val loss 0.59
# Saved model
# Epoch 42, Loss 3.46, Val loss 0.59
# Epoch 43, Loss 2.66, Val loss 0.61
# Epoch 44, Loss 3.43, Val loss 0.61
# Saved model
# Epoch 45, Loss 3.31, Val loss 0.56
# Epoch 46, Loss 3.17, Val loss 0.56
# Saved model
# Epoch 47, Loss 3.49, Val loss 0.54
# Epoch 48, Loss 3.44, Val loss 0.59
# Epoch 49, Loss 3.28, Val loss 0.58
# TRAINING NEW LOCATION: Kentucky
# Saved model
# Epoch 0, Loss 414.81, Val loss 267.93
# Epoch 1, Loss 6043.61, Val loss 2240.41
# Epoch 2, Loss 7328.89, Val loss 5261.61
# Epoch 3, Loss 5558.97, Val loss 5037.91
# Epoch 4, Loss 2737.00, Val loss 2749.75
# Epoch 5, Loss 920.28, Val loss 986.56
# Epoch 6, Loss 265.79, Val loss 277.81
# Saved model
# Epoch 7, Loss 72.81, Val loss 138.54
# Saved model
# Epoch 8, Loss 26.17, Val loss 45.36
# Saved model
# Epoch 9, Loss 12.24, Val loss 22.83
# Saved model
# Epoch 10, Loss 4.71, Val loss 13.45
# Saved model
# Epoch 11, Loss 3.60, Val loss 11.12
# Saved model
# Epoch 12, Loss 2.18, Val loss 6.41
# Saved model
# Epoch 13, Loss 1.83, Val loss 5.35
# Saved model
# Epoch 14, Loss 1.68, Val loss 3.91
# Saved model
# Epoch 15, Loss 1.17, Val loss 3.35
# Saved model
# Epoch 16, Loss 1.00, Val loss 2.90
# Saved model
# Epoch 17, Loss 0.87, Val loss 2.45
# Saved model
# Epoch 18, Loss 0.80, Val loss 2.31
# Saved model
# Epoch 19, Loss 0.73, Val loss 2.11
# Saved model
# Epoch 20, Loss 0.73, Val loss 1.99
# Saved model
# Epoch 21, Loss 0.67, Val loss 1.86
# Epoch 22, Loss 0.64, Val loss 1.89
# Saved model
# Epoch 23, Loss 0.60, Val loss 1.69
# Epoch 24, Loss 0.60, Val loss 1.76
# Saved model
# Epoch 25, Loss 0.57, Val loss 1.60
# Epoch 26, Loss 0.56, Val loss 1.63
# Saved model
# Epoch 27, Loss 0.54, Val loss 1.58
# Saved model
# Epoch 28, Loss 0.54, Val loss 1.48
# Saved model
# Epoch 29, Loss 0.53, Val loss 1.41
# Epoch 30, Loss 0.53, Val loss 1.45
# Saved model
# Epoch 31, Loss 0.51, Val loss 1.31
# Saved model
# Epoch 32, Loss 0.51, Val loss 1.27
# Epoch 33, Loss 0.50, Val loss 1.29
# Saved model
# Epoch 34, Loss 0.51, Val loss 1.24
# Saved model
# Epoch 35, Loss 0.50, Val loss 1.09
# Epoch 36, Loss 0.49, Val loss 1.14
# Epoch 37, Loss 0.50, Val loss 1.15
# Epoch 38, Loss 0.50, Val loss 1.25
# Epoch 39, Loss 0.50, Val loss 1.50
# Epoch 40, Loss 0.49, Val loss 1.41
# Epoch 41, Loss 0.51, Val loss 1.24
# Epoch 42, Loss 0.49, Val loss 1.37
# Epoch 43, Loss 0.47, Val loss 1.12
# Epoch 44, Loss 0.47, Val loss 1.39
# Epoch 45, Loss 0.48, Val loss 1.56
# Epoch 46, Loss 0.46, Val loss 1.31
# Epoch 47, Loss 0.48, Val loss 1.40
# Epoch 48, Loss 0.46, Val loss 1.42
# Epoch 49, Loss 0.46, Val loss 1.23
# TRAINING NEW LOCATION: Louisiana
# Saved model
# Epoch 0, Loss 6.62, Val loss 1.72
# Saved model
# Epoch 1, Loss 33.96, Val loss 0.18
# Epoch 2, Loss 4.46, Val loss 0.20
# Epoch 3, Loss 3.22, Val loss 0.24
# Epoch 4, Loss 2.93, Val loss 0.29
# Epoch 5, Loss 2.85, Val loss 0.31
# Epoch 6, Loss 2.79, Val loss 0.33
# Epoch 7, Loss 2.82, Val loss 0.33
# Epoch 8, Loss 2.80, Val loss 0.32
# Epoch 9, Loss 2.82, Val loss 0.28
# Epoch 10, Loss 2.76, Val loss 0.26
# Epoch 11, Loss 2.72, Val loss 0.25
# Epoch 12, Loss 2.77, Val loss 0.20
# Epoch 13, Loss 2.63, Val loss 0.20
# Epoch 14, Loss 2.55, Val loss 0.19
# Epoch 15, Loss 2.54, Val loss 0.22
# Epoch 16, Loss 2.49, Val loss 0.21
# Epoch 17, Loss 2.45, Val loss 0.20
# Epoch 18, Loss 2.40, Val loss 0.24
# Epoch 19, Loss 2.38, Val loss 0.25
# Epoch 20, Loss 2.38, Val loss 0.28
# Epoch 21, Loss 2.36, Val loss 0.29
# Epoch 22, Loss 2.34, Val loss 0.31
# Epoch 23, Loss 2.32, Val loss 0.28
# Epoch 24, Loss 2.30, Val loss 0.26
# Epoch 25, Loss 2.29, Val loss 0.23
# Epoch 26, Loss 2.27, Val loss 0.24
# Epoch 27, Loss 2.27, Val loss 0.21
# Epoch 28, Loss 2.25, Val loss 0.19
# Epoch 29, Loss 2.23, Val loss 0.20
# Epoch 30, Loss 2.23, Val loss 0.20
# Epoch 31, Loss 2.21, Val loss 0.21
# Epoch 32, Loss 2.19, Val loss 0.24
# Epoch 33, Loss 2.18, Val loss 0.28
# Epoch 34, Loss 2.17, Val loss 0.24
# Epoch 35, Loss 2.15, Val loss 0.27
# Epoch 36, Loss 2.15, Val loss 0.28
# Epoch 37, Loss 2.12, Val loss 0.26
# Epoch 38, Loss 2.12, Val loss 0.26
# Epoch 39, Loss 2.12, Val loss 0.24
# Epoch 40, Loss 2.10, Val loss 0.24
# Epoch 41, Loss 2.08, Val loss 0.23
# Epoch 42, Loss 2.07, Val loss 0.22
# Epoch 43, Loss 2.06, Val loss 0.20
# Epoch 44, Loss 2.05, Val loss 0.19
# Epoch 45, Loss 2.04, Val loss 0.19
# Epoch 46, Loss 2.02, Val loss 0.22
# Epoch 47, Loss 2.01, Val loss 0.22
# Epoch 48, Loss 2.00, Val loss 0.23
# Epoch 49, Loss 1.99, Val loss 0.25
# TRAINING NEW LOCATION: Maine
# Saved model
# Epoch 0, Loss 1.83, Val loss 69.46
# Saved model
# Epoch 1, Loss 259.48, Val loss 1.11
# Epoch 2, Loss 2.26, Val loss 1.38
# Epoch 3, Loss 1.07, Val loss 1.47
# Epoch 4, Loss 1.04, Val loss 1.54
# Epoch 5, Loss 1.04, Val loss 1.60
# Epoch 6, Loss 1.03, Val loss 1.65
# Epoch 7, Loss 1.04, Val loss 1.70
# Epoch 8, Loss 1.03, Val loss 1.73
# Epoch 9, Loss 1.02, Val loss 1.75
# Epoch 10, Loss 0.95, Val loss 1.73
# Epoch 11, Loss 0.95, Val loss 1.73
# Epoch 12, Loss 0.96, Val loss 1.71
# Epoch 13, Loss 0.93, Val loss 1.68
# Epoch 14, Loss 0.90, Val loss 1.64
# Epoch 15, Loss 0.90, Val loss 1.61
# Epoch 16, Loss 0.85, Val loss 1.60
# Epoch 17, Loss 0.86, Val loss 1.58
# Epoch 18, Loss 0.79, Val loss 1.58
# Epoch 19, Loss 0.78, Val loss 1.53
# Epoch 20, Loss 0.77, Val loss 1.52
# Epoch 21, Loss 0.72, Val loss 1.52
# Epoch 22, Loss 0.70, Val loss 1.48
# Epoch 23, Loss 0.69, Val loss 1.45
# Epoch 24, Loss 0.69, Val loss 1.46
# Epoch 25, Loss 0.65, Val loss 1.43
# Epoch 26, Loss 0.62, Val loss 1.36
# Epoch 27, Loss 0.63, Val loss 1.35
# Epoch 28, Loss 0.61, Val loss 1.33
# Epoch 29, Loss 0.60, Val loss 1.30
# Epoch 30, Loss 0.58, Val loss 1.31
# Epoch 31, Loss 0.57, Val loss 1.30
# Epoch 32, Loss 0.56, Val loss 1.28
# Epoch 33, Loss 0.57, Val loss 1.24
# Epoch 34, Loss 0.55, Val loss 1.25
# Epoch 35, Loss 0.53, Val loss 1.24
# Epoch 36, Loss 0.53, Val loss 1.22
# Epoch 37, Loss 0.54, Val loss 1.20
# Epoch 38, Loss 0.54, Val loss 1.26
# Epoch 39, Loss 0.56, Val loss 1.25
# Epoch 40, Loss 0.54, Val loss 1.21
# Epoch 41, Loss 0.54, Val loss 1.13
# Saved model
# Epoch 42, Loss 0.55, Val loss 1.09
# Epoch 43, Loss 0.52, Val loss 1.11
# Epoch 44, Loss 0.53, Val loss 1.10
# Epoch 45, Loss 0.55, Val loss 1.14
# Epoch 46, Loss 0.54, Val loss 1.18
# Epoch 47, Loss 0.54, Val loss 1.20
# Epoch 48, Loss 0.55, Val loss 1.24
# Epoch 49, Loss 0.53, Val loss 1.25
# TRAINING NEW LOCATION: Maryland
# Saved model
# Epoch 0, Loss 10577.20, Val loss 257.62
# Epoch 1, Loss 83632.70, Val loss 2564.48
# Epoch 2, Loss 99524.88, Val loss 7264.66
# Epoch 3, Loss 45914.21, Val loss 7616.51
# Epoch 4, Loss 18627.68, Val loss 4206.77
# Epoch 5, Loss 6825.40, Val loss 1614.06
# Epoch 6, Loss 2280.50, Val loss 553.36
# Saved model
# Epoch 7, Loss 729.34, Val loss 254.16
# Saved model
# Epoch 8, Loss 264.25, Val loss 108.93
# Saved model
# Epoch 9, Loss 113.26, Val loss 61.86
# Saved model
# Epoch 10, Loss 57.41, Val loss 34.45
# Saved model
# Epoch 11, Loss 38.27, Val loss 19.98
# Saved model
# Epoch 12, Loss 23.93, Val loss 13.26
# Saved model
# Epoch 13, Loss 17.14, Val loss 9.92
# Saved model
# Epoch 14, Loss 12.79, Val loss 5.64
# Saved model
# Epoch 15, Loss 10.12, Val loss 5.07
# Saved model
# Epoch 16, Loss 8.26, Val loss 3.45
# Saved model
# Epoch 17, Loss 7.07, Val loss 2.49
# Saved model
# Epoch 18, Loss 6.47, Val loss 1.90
# Saved model
# Epoch 19, Loss 5.65, Val loss 1.53
# Saved model
# Epoch 20, Loss 5.09, Val loss 1.39
# Saved model
# Epoch 21, Loss 4.29, Val loss 1.25
# Saved model
# Epoch 22, Loss 4.25, Val loss 1.07
# Saved model
# Epoch 23, Loss 4.06, Val loss 0.85
# Saved model
# Epoch 24, Loss 3.72, Val loss 0.73
# Saved model
# Epoch 25, Loss 3.61, Val loss 0.72
# Saved model
# Epoch 26, Loss 3.49, Val loss 0.64
# Epoch 27, Loss 3.31, Val loss 0.64
# Saved model
# Epoch 28, Loss 3.14, Val loss 0.49
# Epoch 29, Loss 3.23, Val loss 0.52
# Epoch 30, Loss 3.04, Val loss 0.54
# Saved model
# Epoch 31, Loss 2.86, Val loss 0.46
# Saved model
# Epoch 32, Loss 2.87, Val loss 0.43
# Saved model
# Epoch 33, Loss 2.81, Val loss 0.37
# Saved model
# Epoch 34, Loss 2.71, Val loss 0.36
# Epoch 35, Loss 2.67, Val loss 0.48
# Saved model
# Epoch 36, Loss 2.82, Val loss 0.33
# Saved model
# Epoch 37, Loss 2.64, Val loss 0.28
# Epoch 38, Loss 2.54, Val loss 0.33
# Epoch 39, Loss 2.68, Val loss 0.34
# Epoch 40, Loss 2.66, Val loss 0.33
# Epoch 41, Loss 2.67, Val loss 0.35
# Epoch 42, Loss 2.43, Val loss 0.34
# Epoch 43, Loss 2.46, Val loss 0.28
# Epoch 44, Loss 2.41, Val loss 0.28
# Epoch 45, Loss 2.59, Val loss 0.31
# Epoch 46, Loss 2.58, Val loss 0.34
# Epoch 47, Loss 2.48, Val loss 0.30
# Epoch 48, Loss 2.36, Val loss 0.33
# Epoch 49, Loss 2.51, Val loss 0.31
# TRAINING NEW LOCATION: Massachusetts
# Saved model
# Epoch 0, Loss 0.48, Val loss 0.89
# Saved model
# Epoch 1, Loss 0.58, Val loss 0.22
# Saved model
# Epoch 2, Loss 0.23, Val loss 0.13
# Saved model
# Epoch 3, Loss 0.17, Val loss 0.10
# Epoch 4, Loss 0.14, Val loss 0.12
# Epoch 5, Loss 0.13, Val loss 0.15
# Epoch 6, Loss 0.14, Val loss 0.17
# Epoch 7, Loss 0.14, Val loss 0.17
# Epoch 8, Loss 0.13, Val loss 0.16
# Epoch 9, Loss 0.12, Val loss 0.14
# Epoch 10, Loss 0.12, Val loss 0.13
# Epoch 11, Loss 0.11, Val loss 0.12
# Epoch 12, Loss 0.11, Val loss 0.12
# Epoch 13, Loss 0.11, Val loss 0.12
# Epoch 14, Loss 0.11, Val loss 0.12
# Epoch 15, Loss 0.10, Val loss 0.12
# Epoch 16, Loss 0.11, Val loss 0.11
# Epoch 17, Loss 0.10, Val loss 0.11
# Epoch 18, Loss 0.10, Val loss 0.11
# Epoch 19, Loss 0.09, Val loss 0.11
# Epoch 20, Loss 0.09, Val loss 0.12
# Epoch 21, Loss 0.09, Val loss 0.12
# Epoch 22, Loss 0.09, Val loss 0.13
# Epoch 23, Loss 0.09, Val loss 0.12
# Epoch 24, Loss 0.09, Val loss 0.12
# Epoch 25, Loss 0.08, Val loss 0.11
# Epoch 26, Loss 0.08, Val loss 0.11
# Epoch 27, Loss 0.08, Val loss 0.10
# Epoch 28, Loss 0.08, Val loss 0.10
# Epoch 29, Loss 0.07, Val loss 0.10
# Saved model
# Epoch 30, Loss 0.08, Val loss 0.10
# Saved model
# Epoch 31, Loss 0.07, Val loss 0.10
# Saved model
# Epoch 32, Loss 0.07, Val loss 0.10
# Epoch 33, Loss 0.07, Val loss 0.10
# Epoch 34, Loss 0.07, Val loss 0.10
# Epoch 35, Loss 0.07, Val loss 0.10
# Epoch 36, Loss 0.07, Val loss 0.10
# Epoch 37, Loss 0.07, Val loss 0.10
# Epoch 38, Loss 0.06, Val loss 0.10
# Epoch 39, Loss 0.06, Val loss 0.10
# Saved model
# Epoch 40, Loss 0.06, Val loss 0.10
# Saved model
# Epoch 41, Loss 0.06, Val loss 0.09
# Saved model
# Epoch 42, Loss 0.06, Val loss 0.09
# Saved model
# Epoch 43, Loss 0.06, Val loss 0.08
# Saved model
# Epoch 44, Loss 0.05, Val loss 0.08
# Saved model
# Epoch 45, Loss 0.05, Val loss 0.08
# Saved model
# Epoch 46, Loss 0.05, Val loss 0.08
# Saved model
# Epoch 47, Loss 0.05, Val loss 0.08
# Epoch 48, Loss 0.05, Val loss 0.08
# Epoch 49, Loss 0.05, Val loss 0.08
# TRAINING NEW LOCATION: Michigan
# Saved model
# Epoch 0, Loss 19.21, Val loss 129.73
# Saved model
# Epoch 1, Loss 368.61, Val loss 68.05
# Saved model
# Epoch 2, Loss 78.38, Val loss 5.05
# Saved model
# Epoch 3, Loss 5.58, Val loss 1.18
# Saved model
# Epoch 4, Loss 1.70, Val loss 1.10
# Epoch 5, Loss 1.26, Val loss 1.18
# Epoch 6, Loss 1.04, Val loss 1.24
# Epoch 7, Loss 0.93, Val loss 1.28
# Epoch 8, Loss 0.89, Val loss 1.32
# Epoch 9, Loss 0.87, Val loss 1.34
# Epoch 10, Loss 0.87, Val loss 1.35
# Epoch 11, Loss 0.86, Val loss 1.34
# Epoch 12, Loss 0.86, Val loss 1.32
# Epoch 13, Loss 0.82, Val loss 1.29
# Epoch 14, Loss 0.83, Val loss 1.25
# Epoch 15, Loss 0.79, Val loss 1.18
# Epoch 16, Loss 0.79, Val loss 1.17
# Epoch 17, Loss 0.78, Val loss 1.14
# Epoch 18, Loss 0.77, Val loss 1.18
# Epoch 19, Loss 0.75, Val loss 1.20
# Epoch 20, Loss 0.74, Val loss 1.16
# Epoch 21, Loss 0.73, Val loss 1.18
# Epoch 22, Loss 0.74, Val loss 1.20
# Epoch 23, Loss 0.71, Val loss 1.20
# Epoch 24, Loss 0.72, Val loss 1.22
# Epoch 25, Loss 0.70, Val loss 1.18
# Epoch 26, Loss 0.69, Val loss 1.24
# Epoch 27, Loss 0.70, Val loss 1.24
# Epoch 28, Loss 0.70, Val loss 1.17
# Epoch 29, Loss 0.68, Val loss 1.19
# Epoch 30, Loss 0.68, Val loss 1.19
# Epoch 31, Loss 0.69, Val loss 1.17
# Epoch 32, Loss 0.70, Val loss 1.18
# Epoch 33, Loss 0.69, Val loss 1.14
# Epoch 34, Loss 0.68, Val loss 1.13
# Epoch 35, Loss 0.66, Val loss 1.13
# Epoch 36, Loss 0.65, Val loss 1.12
# Epoch 37, Loss 0.68, Val loss 1.10
# Epoch 38, Loss 0.70, Val loss 1.12
# Epoch 39, Loss 0.66, Val loss 1.17
# Epoch 40, Loss 0.65, Val loss 1.20
# Epoch 41, Loss 0.68, Val loss 1.25
# Epoch 42, Loss 0.64, Val loss 1.27
# Epoch 43, Loss 0.66, Val loss 1.26
# Epoch 44, Loss 0.68, Val loss 1.24
# Epoch 45, Loss 0.64, Val loss 1.21
# Epoch 46, Loss 0.63, Val loss 1.12
# Epoch 47, Loss 0.63, Val loss 1.13
# Epoch 48, Loss 0.62, Val loss 1.14
# Epoch 49, Loss 0.62, Val loss 1.12
# TRAINING NEW LOCATION: Minnesota
# Saved model
# Epoch 0, Loss 0.73, Val loss 1.19
# Saved model
# Epoch 1, Loss 1.05, Val loss 0.98
# Saved model
# Epoch 2, Loss 0.47, Val loss 0.95
# Epoch 3, Loss 0.45, Val loss 0.96
# Epoch 4, Loss 0.43, Val loss 1.01
# Epoch 5, Loss 0.41, Val loss 1.07
# Epoch 6, Loss 0.41, Val loss 1.09
# Epoch 7, Loss 0.40, Val loss 1.07
# Epoch 8, Loss 0.40, Val loss 0.99
# Saved model
# Epoch 9, Loss 0.39, Val loss 0.90
# Saved model
# Epoch 10, Loss 0.36, Val loss 0.82
# Saved model
# Epoch 11, Loss 0.35, Val loss 0.78
# Saved model
# Epoch 12, Loss 0.35, Val loss 0.77
# Epoch 13, Loss 0.35, Val loss 0.79
# Epoch 14, Loss 0.33, Val loss 0.81
# Epoch 15, Loss 0.33, Val loss 0.83
# Epoch 16, Loss 0.32, Val loss 0.83
# Epoch 17, Loss 0.30, Val loss 0.83
# Epoch 18, Loss 0.28, Val loss 0.85
# Epoch 19, Loss 0.27, Val loss 0.85
# Epoch 20, Loss 0.27, Val loss 0.84
# Epoch 21, Loss 0.27, Val loss 0.84
# Epoch 22, Loss 0.25, Val loss 0.83
# Epoch 23, Loss 0.24, Val loss 0.82
# Epoch 24, Loss 0.24, Val loss 0.81
# Epoch 25, Loss 0.23, Val loss 0.81
# Epoch 26, Loss 0.22, Val loss 0.79
# Epoch 27, Loss 0.21, Val loss 0.79
# Epoch 28, Loss 0.21, Val loss 0.80
# Epoch 29, Loss 0.20, Val loss 0.81
# Epoch 30, Loss 0.19, Val loss 0.80
# Epoch 31, Loss 0.19, Val loss 0.78
# Saved model
# Epoch 32, Loss 0.19, Val loss 0.76
# Saved model
# Epoch 33, Loss 0.17, Val loss 0.75
# Epoch 34, Loss 0.16, Val loss 0.76
# Epoch 35, Loss 0.16, Val loss 0.78
# Epoch 36, Loss 0.15, Val loss 0.81
# Epoch 37, Loss 0.15, Val loss 0.81
# Epoch 38, Loss 0.14, Val loss 0.76
# Saved model
# Epoch 39, Loss 0.13, Val loss 0.71
# Saved model
# Epoch 40, Loss 0.13, Val loss 0.70
# Epoch 41, Loss 0.12, Val loss 0.71
# Epoch 42, Loss 0.12, Val loss 0.73
# Epoch 43, Loss 0.12, Val loss 0.73
# Epoch 44, Loss 0.11, Val loss 0.74
# Epoch 45, Loss 0.10, Val loss 0.74
# Epoch 46, Loss 0.10, Val loss 0.71
# Epoch 47, Loss 0.10, Val loss 0.71
# Epoch 48, Loss 0.09, Val loss 0.72
# Saved model
# Epoch 49, Loss 0.09, Val loss 0.70
# TRAINING NEW LOCATION: Mississippi
# Saved model
# Epoch 0, Loss 7.78, Val loss 9.17
# Saved model
# Epoch 1, Loss 24.02, Val loss 2.58
# Saved model
# Epoch 2, Loss 4.73, Val loss 1.27
# Saved model
# Epoch 3, Loss 2.57, Val loss 1.15
# Saved model
# Epoch 4, Loss 2.33, Val loss 1.10
# Saved model
# Epoch 5, Loss 2.23, Val loss 1.07
# Saved model
# Epoch 6, Loss 2.20, Val loss 1.02
# Saved model
# Epoch 7, Loss 2.17, Val loss 1.00
# ...
# Epoch 32, Loss 2.11, Val loss 0.54
# Epoch 33, Loss 2.10, Val loss 0.59
# Epoch 34, Loss 2.18, Val loss 0.53
# Epoch 35, Loss 2.12, Val loss 0.55
# Epoch 36, Loss 2.21, Val loss 0.59
# Epoch 37, Loss 2.20, Val loss 0.58
# Epoch 38, Loss 2.18, Val loss 0.53
# Epoch 39, Loss 2.06, Val loss 0.54
# Epoch 40, Loss 2.10, Val loss 0.51
# Epoch 41, Loss 2.15, Val loss 0.52
# Epoch 42, Loss 2.22, Val loss 0.48
# Epoch 43, Loss 2.11, Val loss 0.49
# Epoch 44, Loss 2.07, Val loss 0.48
# Epoch 45, Loss 2.26, Val loss 0.49
# Epoch 46, Loss 2.04, Val loss 0.52
# Epoch 47, Loss 1.99, Val loss 0.55
# Epoch 48, Loss 2.18, Val loss 0.53
# Epoch 49, Loss 2.10, Val loss 0.60
# TRAINING NEW LOCATION: Texas
# Saved model
# Epoch 0, Loss 56.13, Val loss 4.36
# Epoch 1, Loss 3.80, Val loss 4.45
# Epoch 2, Loss 2.94, Val loss 4.41
# Saved model
# Epoch 3, Loss 2.57, Val loss 4.36
# Epoch 4, Loss 2.35, Val loss 4.36
# Epoch 5, Loss 2.26, Val loss 4.51
# Epoch 6, Loss 2.39, Val loss 4.73
# Epoch 7, Loss 2.39, Val loss 4.89
# Epoch 8, Loss 2.19, Val loss 5.02
# Epoch 9, Loss 2.08, Val loss 5.08
# Epoch 10, Loss 1.74, Val loss 5.09
# Epoch 11, Loss 1.65, Val loss 5.08
# Epoch 12, Loss 1.56, Val loss 5.06
# Epoch 13, Loss 1.52, Val loss 4.98
# Epoch 14, Loss 1.47, Val loss 4.96
# Epoch 15, Loss 1.46, Val loss 4.87
# Epoch 16, Loss 1.43, Val loss 4.76
# Epoch 17, Loss 1.44, Val loss 4.65
# Epoch 18, Loss 1.40, Val loss 4.55
# Epoch 19, Loss 1.37, Val loss 4.46
# Epoch 20, Loss 1.37, Val loss 4.47
# Epoch 21, Loss 1.35, Val loss 4.52
# Epoch 22, Loss 1.32, Val loss 4.60
# Epoch 23, Loss 1.38, Val loss 4.66
# Epoch 24, Loss 1.29, Val loss 4.69
# Epoch 25, Loss 1.26, Val loss 4.81
# Epoch 26, Loss 1.25, Val loss 4.85
# Epoch 27, Loss 1.24, Val loss 4.90
# Epoch 28, Loss 1.21, Val loss 4.96
# Epoch 29, Loss 1.20, Val loss 4.96
# Epoch 30, Loss 1.18, Val loss 4.93
# Epoch 31, Loss 1.16, Val loss 4.92
# Epoch 32, Loss 1.15, Val loss 4.80
# Epoch 33, Loss 1.12, Val loss 4.68
# Epoch 34, Loss 1.10, Val loss 4.61
# Epoch 35, Loss 1.11, Val loss 4.59
# Epoch 36, Loss 1.10, Val loss 4.54
# Epoch 37, Loss 1.08, Val loss 4.52
# Epoch 38, Loss 1.05, Val loss 4.62
# Epoch 39, Loss 1.05, Val loss 4.56
# Epoch 40, Loss 1.03, Val loss 4.54
# Epoch 41, Loss 1.03, Val loss 4.60
# Epoch 42, Loss 1.01, Val loss 4.57
# Epoch 43, Loss 1.01, Val loss 4.62
# Epoch 44, Loss 1.03, Val loss 4.74
# Epoch 45, Loss 1.07, Val loss 4.71
# Epoch 46, Loss 1.00, Val loss 4.62
# Epoch 47, Loss 0.98, Val loss 4.67
# Epoch 48, Loss 1.04, Val loss 4.62
# Epoch 49, Loss 0.95, Val loss 4.60
# TRAINING NEW LOCATION: Utah
# Saved model
# Epoch 0, Loss 35.73, Val loss 130.59
# Saved model
# Epoch 1, Loss 83.02, Val loss 0.47
# Epoch 2, Loss 2.08, Val loss 1.54
# Epoch 3, Loss 1.07, Val loss 2.09
# Epoch 4, Loss 0.94, Val loss 2.37
# Epoch 5, Loss 0.85, Val loss 2.47
# Epoch 6, Loss 0.83, Val loss 2.51
# Epoch 7, Loss 0.80, Val loss 2.29
# Epoch 8, Loss 0.77, Val loss 2.37
# Epoch 9, Loss 0.72, Val loss 2.05
# Epoch 10, Loss 0.68, Val loss 1.90
# Epoch 11, Loss 0.64, Val loss 1.69
# Epoch 12, Loss 0.58, Val loss 1.48
# Epoch 13, Loss 0.52, Val loss 1.50
# Epoch 14, Loss 0.48, Val loss 1.11
# Epoch 15, Loss 0.46, Val loss 1.17
# Epoch 16, Loss 0.41, Val loss 0.74
# Epoch 17, Loss 0.38, Val loss 0.66
# Epoch 18, Loss 0.38, Val loss 0.84
# Epoch 19, Loss 0.39, Val loss 0.87
# Epoch 20, Loss 0.55, Val loss 0.71
# Epoch 21, Loss 0.58, Val loss 0.92
# Epoch 22, Loss 0.36, Val loss 1.29
# Epoch 23, Loss 0.37, Val loss 1.59
# Epoch 24, Loss 0.34, Val loss 1.16
# Epoch 25, Loss 0.34, Val loss 2.29
# Epoch 26, Loss 0.37, Val loss 1.49
# Epoch 27, Loss 0.40, Val loss 1.61
# Epoch 28, Loss 0.37, Val loss 1.12
# Epoch 29, Loss 0.39, Val loss 0.99
# Epoch 30, Loss 0.29, Val loss 0.92
# Epoch 31, Loss 0.33, Val loss 0.83
# Epoch 32, Loss 0.25, Val loss 0.80
# Epoch 33, Loss 0.34, Val loss 0.64
# Epoch 34, Loss 0.24, Val loss 0.68
# Epoch 35, Loss 0.24, Val loss 0.86
# Epoch 36, Loss 0.22, Val loss 0.87
# Epoch 37, Loss 0.22, Val loss 1.08
# Epoch 38, Loss 0.23, Val loss 0.98
# Epoch 39, Loss 0.23, Val loss 0.84
# Epoch 40, Loss 0.20, Val loss 1.09
# Epoch 41, Loss 0.21, Val loss 0.96
# Epoch 42, Loss 0.20, Val loss 1.02
# Epoch 43, Loss 0.23, Val loss 0.98
# Epoch 44, Loss 0.19, Val loss 1.03
# Epoch 45, Loss 0.20, Val loss 0.84
# Epoch 46, Loss 0.19, Val loss 0.98
# Epoch 47, Loss 0.18, Val loss 1.09
# Epoch 48, Loss 0.21, Val loss 0.82
# Epoch 49, Loss 0.18, Val loss 1.01
# TRAINING NEW LOCATION: Vermont
# Saved model
# Epoch 0, Loss 0.19, Val loss 0.08
# Epoch 1, Loss 0.16, Val loss 0.34
# Epoch 2, Loss 0.47, Val loss 3.56
# Epoch 3, Loss 2.27, Val loss 0.30
# Saved model
# Epoch 4, Loss 0.24, Val loss 0.07
# Saved model
# Epoch 5, Loss 0.13, Val loss 0.04
# Epoch 6, Loss 0.08, Val loss 0.04
# Epoch 7, Loss 0.05, Val loss 0.06
# Epoch 8, Loss 0.05, Val loss 0.06
# Epoch 9, Loss 0.07, Val loss 0.06
# Epoch 10, Loss 0.06, Val loss 0.05
# Epoch 11, Loss 0.05, Val loss 0.05
# Saved model
# Epoch 12, Loss 0.05, Val loss 0.04
# Epoch 13, Loss 0.04, Val loss 0.05
# Epoch 14, Loss 0.04, Val loss 0.05
# Epoch 15, Loss 0.04, Val loss 0.05
# Epoch 16, Loss 0.04, Val loss 0.05
# Epoch 17, Loss 0.04, Val loss 0.05
# Epoch 18, Loss 0.05, Val loss 0.05
# Epoch 19, Loss 0.03, Val loss 0.04
# Epoch 20, Loss 0.04, Val loss 0.04
# Saved model
# Epoch 21, Loss 0.04, Val loss 0.04
# Epoch 22, Loss 0.03, Val loss 0.04
# Epoch 23, Loss 0.03, Val loss 0.04
# Epoch 24, Loss 0.04, Val loss 0.05
# Epoch 25, Loss 0.04, Val loss 0.05
# Epoch 26, Loss 0.03, Val loss 0.04
# Epoch 27, Loss 0.03, Val loss 0.04
# Epoch 28, Loss 0.03, Val loss 0.04
# Epoch 29, Loss 0.03, Val loss 0.04
# Epoch 30, Loss 0.03, Val loss 0.04
# Epoch 31, Loss 0.03, Val loss 0.04
# Epoch 32, Loss 0.03, Val loss 0.04
# Epoch 33, Loss 0.02, Val loss 0.04
# Epoch 34, Loss 0.02, Val loss 0.04
# Epoch 35, Loss 0.02, Val loss 0.05
# Epoch 36, Loss 0.03, Val loss 0.04
# Epoch 37, Loss 0.03, Val loss 0.04
# Epoch 38, Loss 0.02, Val loss 0.04
# Epoch 39, Loss 0.02, Val loss 0.04
# Epoch 40, Loss 0.03, Val loss 0.04
# Epoch 41, Loss 0.02, Val loss 0.04
# Epoch 42, Loss 0.02, Val loss 0.04
# Epoch 43, Loss 0.02, Val loss 0.05
# Epoch 44, Loss 0.02, Val loss 0.05
# Epoch 45, Loss 0.02, Val loss 0.05
# Epoch 46, Loss 0.02, Val loss 0.05
# Epoch 47, Loss 0.02, Val loss 0.04
# Epoch 48, Loss 0.03, Val loss 0.04
# Epoch 49, Loss 0.02, Val loss 0.04
# TRAINING NEW LOCATION: Virginia
# Saved model
# Epoch 0, Loss 10520.39, Val loss 3824.52
# Epoch 1, Loss 102544.55, Val loss 14520.84
# Epoch 2, Loss 65698.60, Val loss 10712.08
# Epoch 3, Loss 20925.01, Val loss 4441.05
# Saved model
# Epoch 4, Loss 5188.28, Val loss 1659.89
# Saved model
# Epoch 5, Loss 1735.20, Val loss 690.22
# Saved model
# Epoch 6, Loss 654.60, Val loss 333.41
# Saved model
# Epoch 7, Loss 303.81, Val loss 168.77
# Saved model
# Epoch 8, Loss 178.35, Val loss 120.68
# Saved model
# Epoch 9, Loss 103.83, Val loss 65.63
# Saved model
# Epoch 10, Loss 76.15, Val loss 40.93
# Saved model
# Epoch 11, Loss 53.67, Val loss 37.35
# Saved model
# Epoch 12, Loss 39.59, Val loss 23.68
# Saved model
# Epoch 13, Loss 32.30, Val loss 18.37
# Saved model
# Epoch 14, Loss 24.31, Val loss 12.74
# Saved model
# Epoch 15, Loss 21.30, Val loss 9.90
# Saved model
# Epoch 16, Loss 17.17, Val loss 8.48
# Saved model
# Epoch 17, Loss 14.72, Val loss 5.93
# Saved model
# Epoch 18, Loss 12.47, Val loss 5.57
# Saved model
# Epoch 19, Loss 10.81, Val loss 4.47
# Saved model
# Epoch 20, Loss 10.01, Val loss 3.43
# Saved model
# Epoch 21, Loss 8.78, Val loss 3.43
# Saved model
# Epoch 22, Loss 8.12, Val loss 2.85
# Epoch 23, Loss 7.78, Val loss 2.94
# Saved model
# Epoch 24, Loss 7.12, Val loss 2.29
# Saved model
# Epoch 25, Loss 6.73, Val loss 2.15
# Epoch 26, Loss 6.33, Val loss 2.20
# Saved model
# Epoch 27, Loss 6.01, Val loss 1.89
# Epoch 28, Loss 5.74, Val loss 2.19
# Saved model
# Epoch 29, Loss 5.45, Val loss 1.75
# Saved model
# Epoch 30, Loss 5.23, Val loss 1.33
# Epoch 31, Loss 5.15, Val loss 1.64
# Epoch 32, Loss 5.00, Val loss 1.42
# Epoch 33, Loss 4.78, Val loss 1.63
# Saved model
# Epoch 34, Loss 4.74, Val loss 1.27
# Epoch 35, Loss 4.57, Val loss 1.45
# Epoch 36, Loss 4.51, Val loss 1.51
# Saved model
# Epoch 37, Loss 4.48, Val loss 1.22
# Epoch 38, Loss 4.38, Val loss 1.33
# Saved model
# Epoch 39, Loss 4.30, Val loss 1.20
# Saved model
# Epoch 40, Loss 4.25, Val loss 0.87
# Epoch 41, Loss 4.14, Val loss 1.08
# Epoch 42, Loss 4.11, Val loss 1.03
# Epoch 43, Loss 4.10, Val loss 0.93
# Epoch 44, Loss 4.04, Val loss 0.99
# Epoch 45, Loss 4.05, Val loss 1.24
# Epoch 46, Loss 4.00, Val loss 1.27
# Epoch 47, Loss 3.94, Val loss 1.12
# Epoch 48, Loss 3.88, Val loss 1.14
# Saved model
# Epoch 49, Loss 3.84, Val loss 0.77
# TRAINING NEW LOCATION: Washington
# Saved model
# Epoch 0, Loss 0.32, Val loss 0.05
# Saved model
# Epoch 1, Loss 0.16, Val loss 0.04
# Saved model
# Epoch 2, Loss 0.12, Val loss 0.03
# Saved model
# Epoch 3, Loss 0.09, Val loss 0.02
# Saved model
# Epoch 4, Loss 0.08, Val loss 0.01
# Saved model
# Epoch 5, Loss 0.07, Val loss 0.01
# Saved model
# Epoch 6, Loss 0.07, Val loss 0.01
# Saved model
# Epoch 7, Loss 0.07, Val loss 0.01
# Epoch 8, Loss 0.07, Val loss 0.01
# Epoch 9, Loss 0.06, Val loss 0.01
# Saved model
# Epoch 10, Loss 0.06, Val loss 0.01
# Saved model
# Epoch 11, Loss 0.06, Val loss 0.01
# Saved model
# Epoch 12, Loss 0.06, Val loss 0.01
# Saved model
# Epoch 13, Loss 0.05, Val loss 0.00
# Saved model
# Epoch 14, Loss 0.06, Val loss 0.00
# Saved model
# Epoch 15, Loss 0.05, Val loss 0.00
# Epoch 16, Loss 0.05, Val loss 0.00
# Epoch 17, Loss 0.05, Val loss 0.00
# Epoch 18, Loss 0.05, Val loss 0.00
# Epoch 19, Loss 0.05, Val loss 0.00
# Epoch 20, Loss 0.05, Val loss 0.00
# Epoch 21, Loss 0.05, Val loss 0.00
# Saved model
# Epoch 22, Loss 0.05, Val loss 0.00
# Saved model
# Epoch 23, Loss 0.05, Val loss 0.00
# Saved model
# Epoch 24, Loss 0.04, Val loss 0.00
# Epoch 25, Loss 0.04, Val loss 0.00
# Epoch 26, Loss 0.04, Val loss 0.00
# Epoch 27, Loss 0.04, Val loss 0.00
# Epoch 28, Loss 0.04, Val loss 0.00
# Epoch 29, Loss 0.04, Val loss 0.00
# Epoch 30, Loss 0.04, Val loss 0.00
# Epoch 31, Loss 0.04, Val loss 0.00
# Epoch 32, Loss 0.04, Val loss 0.00
# Epoch 33, Loss 0.04, Val loss 0.00
# Saved model
# Epoch 34, Loss 0.04, Val loss 0.00
# Saved model
# Epoch 35, Loss 0.04, Val loss 0.00
# Epoch 36, Loss 0.04, Val loss 0.00
# Epoch 37, Loss 0.04, Val loss 0.00
# Epoch 38, Loss 0.04, Val loss 0.00
# Epoch 39, Loss 0.04, Val loss 0.00
# Epoch 40, Loss 0.04, Val loss 0.00
# Epoch 41, Loss 0.04, Val loss 0.00
# Epoch 42, Loss 0.04, Val loss 0.00
# Epoch 43, Loss 0.04, Val loss 0.00
# Epoch 44, Loss 0.04, Val loss 0.00
# Epoch 45, Loss 0.04, Val loss 0.00
# Saved model
# Epoch 46, Loss 0.04, Val loss 0.00
# Saved model
# Epoch 47, Loss 0.04, Val loss 0.00
# Saved model
# Epoch 48, Loss 0.04, Val loss 0.00
# Saved model
# Epoch 49, Loss 0.04, Val loss 0.00
# TRAINING NEW LOCATION: West Virginia
# Saved model
# Epoch 0, Loss 29.40, Val loss 345.47
# Saved model
# Epoch 1, Loss 993.21, Val loss 2.71
# Epoch 2, Loss 5.52, Val loss 3.23
# Epoch 3, Loss 1.09, Val loss 3.51
# Epoch 4, Loss 0.93, Val loss 3.62
# Epoch 5, Loss 0.89, Val loss 3.63
# Epoch 6, Loss 0.86, Val loss 3.59
# Epoch 7, Loss 0.84, Val loss 3.52
# Epoch 8, Loss 0.83, Val loss 3.44
# Epoch 9, Loss 0.83, Val loss 3.36
# Epoch 10, Loss 0.83, Val loss 3.29
# Epoch 11, Loss 0.82, Val loss 3.22
# Epoch 12, Loss 0.85, Val loss 3.24
# Epoch 13, Loss 0.82, Val loss 3.20
# Epoch 14, Loss 0.79, Val loss 3.21
# Epoch 15, Loss 0.80, Val loss 3.22
# Epoch 16, Loss 0.79, Val loss 3.20
# Epoch 17, Loss 0.77, Val loss 3.17
# Epoch 18, Loss 0.74, Val loss 3.17
# Epoch 19, Loss 0.73, Val loss 3.15
# Epoch 20, Loss 0.74, Val loss 3.13
# Epoch 21, Loss 0.72, Val loss 3.10
# Epoch 22, Loss 0.69, Val loss 3.09
# Epoch 23, Loss 0.68, Val loss 3.05
# Epoch 24, Loss 0.68, Val loss 3.06
# Epoch 25, Loss 0.66, Val loss 3.04
# Epoch 26, Loss 0.65, Val loss 3.02
# Epoch 27, Loss 0.63, Val loss 2.99
# Epoch 28, Loss 0.65, Val loss 2.92
# Epoch 29, Loss 0.63, Val loss 2.86
# Epoch 30, Loss 0.60, Val loss 2.81
# Epoch 31, Loss 0.60, Val loss 2.76
# Saved model
# Epoch 32, Loss 0.58, Val loss 2.71
# Saved model
# Epoch 33, Loss 0.58, Val loss 2.66
# Saved model
# Epoch 34, Loss 0.57, Val loss 2.64
# Saved model
# Epoch 35, Loss 0.55, Val loss 2.60
# Saved model
# Epoch 36, Loss 0.55, Val loss 2.58
# Epoch 37, Loss 0.54, Val loss 2.60
# Epoch 38, Loss 0.53, Val loss 2.61
# Epoch 39, Loss 0.54, Val loss 2.60
# Epoch 40, Loss 0.52, Val loss 2.60
# Saved model
# Epoch 41, Loss 0.52, Val loss 2.58
# Saved model
# Epoch 42, Loss 0.51, Val loss 2.56
# Saved model
# Epoch 43, Loss 0.50, Val loss 2.54
# Saved model
# Epoch 44, Loss 0.50, Val loss 2.52
# Saved model
# Epoch 45, Loss 0.49, Val loss 2.49
# Saved model
# Epoch 46, Loss 0.49, Val loss 2.46
# Saved model
# Epoch 47, Loss 0.49, Val loss 2.42
# Saved model
# Epoch 48, Loss 0.48, Val loss 2.40
# Saved model
# Epoch 49, Loss 0.48, Val loss 2.37
# TRAINING NEW LOCATION: Wisconsin
# Saved model
# Epoch 0, Loss 16.49, Val loss 8.05
# Epoch 1, Loss 0.73, Val loss 8.71
# Epoch 2, Loss 0.52, Val loss 8.90
# Epoch 3, Loss 0.40, Val loss 8.91
# Epoch 4, Loss 0.32, Val loss 8.88
# Epoch 5, Loss 0.25, Val loss 8.85
# Epoch 6, Loss 0.21, Val loss 8.79
# Epoch 7, Loss 0.20, Val loss 8.73
# Epoch 8, Loss 0.20, Val loss 8.63
# Epoch 9, Loss 0.20, Val loss 8.54
# Epoch 10, Loss 0.20, Val loss 8.46
# Epoch 11, Loss 0.19, Val loss 8.40
# Epoch 12, Loss 0.17, Val loss 8.37
# Epoch 13, Loss 0.17, Val loss 8.39
# Epoch 14, Loss 0.15, Val loss 8.43
# Epoch 15, Loss 0.16, Val loss 8.46
# Epoch 16, Loss 0.15, Val loss 8.44
# Epoch 17, Loss 0.14, Val loss 8.42
# Epoch 18, Loss 0.13, Val loss 8.39
# Epoch 19, Loss 0.14, Val loss 8.48
# Epoch 20, Loss 0.14, Val loss 8.52
# Epoch 21, Loss 0.13, Val loss 8.68
# Epoch 22, Loss 0.13, Val loss 8.75
# Epoch 23, Loss 0.14, Val loss 8.67
# Epoch 24, Loss 0.11, Val loss 8.70
# Epoch 25, Loss 0.11, Val loss 8.51
# Epoch 26, Loss 0.12, Val loss 8.43
# Epoch 27, Loss 0.11, Val loss 8.47
# Epoch 28, Loss 0.10, Val loss 8.49
# Epoch 29, Loss 0.09, Val loss 8.55
# Epoch 30, Loss 0.09, Val loss 8.55
# Epoch 31, Loss 0.09, Val loss 8.60
# Epoch 32, Loss 0.09, Val loss 8.63
# Epoch 33, Loss 0.09, Val loss 8.54
# Epoch 34, Loss 0.08, Val loss 8.45
# Epoch 35, Loss 0.09, Val loss 8.35
# Epoch 36, Loss 0.08, Val loss 8.32
# Epoch 37, Loss 0.08, Val loss 8.30
# Epoch 38, Loss 0.07, Val loss 8.35
# Epoch 39, Loss 0.07, Val loss 8.41
# Epoch 40, Loss 0.07, Val loss 8.40
# Epoch 41, Loss 0.08, Val loss 8.46
# Epoch 42, Loss 0.07, Val loss 8.42
# Epoch 43, Loss 0.08, Val loss 8.28
# Epoch 44, Loss 0.07, Val loss 8.11
# Saved model
# Epoch 45, Loss 0.06, Val loss 8.02
# Epoch 46, Loss 0.07, Val loss 8.06
# Epoch 47, Loss 0.07, Val loss 8.17
# Epoch 48, Loss 0.07, Val loss 8.24
# Epoch 49, Loss 0.07, Val loss 8.28
# TRAINING NEW LOCATION: Wyoming
# Saved model
# Epoch 0, Loss 0.88, Val loss 2.41
# Saved model
# Epoch 1, Loss 0.47, Val loss 0.96
# Saved model
# Epoch 2, Loss 0.20, Val loss 0.90
# Epoch 3, Loss 0.11, Val loss 0.97
# Epoch 4, Loss 0.09, Val loss 0.98
# Epoch 5, Loss 0.08, Val loss 0.97
# Epoch 6, Loss 0.08, Val loss 0.98
# Epoch 7, Loss 0.07, Val loss 0.97
# Saved model
# Epoch 8, Loss 0.07, Val loss 0.90
# Saved model
# Epoch 9, Loss 0.07, Val loss 0.84
# Saved model
# Epoch 10, Loss 0.05, Val loss 0.79
# Saved model
# Epoch 11, Loss 0.06, Val loss 0.77
# Saved model
# Epoch 12, Loss 0.05, Val loss 0.76
# Epoch 13, Loss 0.05, Val loss 0.76
# Epoch 14, Loss 0.04, Val loss 0.81
# Epoch 15, Loss 0.05, Val loss 0.82
# Epoch 16, Loss 0.05, Val loss 0.83
# Epoch 17, Loss 0.05, Val loss 0.84
# Epoch 18, Loss 0.05, Val loss 0.83
# Epoch 19, Loss 0.05, Val loss 0.82
# Epoch 20, Loss 0.04, Val loss 0.82
# Epoch 21, Loss 0.04, Val loss 0.81
# Epoch 22, Loss 0.03, Val loss 0.79
# Epoch 23, Loss 0.04, Val loss 0.77
# Saved model
# Epoch 24, Loss 0.03, Val loss 0.75
# Saved model
# Epoch 25, Loss 0.04, Val loss 0.73
# Epoch 26, Loss 0.04, Val loss 0.74
# Epoch 27, Loss 0.03, Val loss 0.76
# Epoch 28, Loss 0.04, Val loss 0.79
# Epoch 29, Loss 0.03, Val loss 0.81
# Epoch 30, Loss 0.03, Val loss 0.82
# Epoch 31, Loss 0.03, Val loss 0.82
# Epoch 32, Loss 0.03, Val loss 0.81
# Epoch 33, Loss 0.03, Val loss 0.80
# Epoch 34, Loss 0.03, Val loss 0.78
# Epoch 35, Loss 0.03, Val loss 0.77
# Epoch 36, Loss 0.03, Val loss 0.77
# Epoch 37, Loss 0.03, Val loss 0.76
# Epoch 38, Loss 0.03, Val loss 0.76
# Epoch 39, Loss 0.03, Val loss 0.76
# Epoch 40, Loss 0.03, Val loss 0.77
# Epoch 41, Loss 0.03, Val loss 0.77
# Epoch 42, Loss 0.03, Val loss 0.77
# Epoch 43, Loss 0.03, Val loss 0.77
# Epoch 44, Loss 0.02, Val loss 0.76
# Epoch 45, Loss 0.02, Val loss 0.75
# Epoch 46, Loss 0.02, Val loss 0.74
# Epoch 47, Loss 0.03, Val loss 0.74
# Epoch 48, Loss 0.02, Val loss 0.74
# Epoch 49, Loss 0.02, Val loss 0.74

# %%
#Pred with STAN

model_predictions_number_infected_dictionary = {}
model_predictions_number_infected_list = []

for loc_name in loc_list:
  file_name = './save/stan_' + loc_name
  checkpoint = torch.load(file_name)
  model = STAN(g, in_dim, hidden_dim1, hidden_dim2, gru_dim, num_heads, pred_window, device).to(device)
  model.load_state_dict(checkpoint['state'])
  model.eval()

  prev_x = torch.cat((train_x, val_x), dim=1)
  prev_I = torch.cat((train_I, val_I), dim=1)
  prev_R = torch.cat((train_R, val_R), dim=1)
  prev_cI = torch.cat((train_cI, val_cI), dim=1)
  prev_cR = torch.cat((train_cR, val_cR), dim=1)

  cur_loc = loc_list.index(loc_name)

  prev_active_pred, _, prev_phyactive_pred, _, h = model(prev_x, prev_cI[cur_loc], prev_cR[cur_loc], N[cur_loc], prev_I[cur_loc], prev_R[cur_loc])

  test_pred_active, test_pred_recovered, test_pred_phy_active, test_pred_phy_recover, _ = model(test_x, test_cI[cur_loc], test_cR[cur_loc], N[cur_loc], test_I[cur_loc], test_R[cur_loc], h)

  # Cumulate predicted dI
  pred_I = []

  for i in range(test_pred_active.size(1)):
      cur_pred = (test_pred_active[0, i, :].detach().cpu().numpy() * dI_std[cur_loc].reshape(1, 1).detach().cpu().numpy()) + dI_mean[cur_loc].reshape(1, 1).detach().cpu().numpy()
      #cur_pred = test_pred_phy_active[0, i, :].detach().cpu().numpy()
      cur_pred = (cur_pred + test_pred_phy_active[0, i, :].detach().cpu().numpy()) / 2
      cur_pred = np.cumsum(cur_pred)
      cur_pred = cur_pred + test_I[cur_loc, i].detach().cpu().item()
      pred_I.append(cur_pred)

  model_predictions_number_infected_list.append(pred_I)  
  # pred_I = np.array(pred_I)
  # pred_I = pred_I

  model_predictions_number_infected_dictionary[loc_name] = np.array(pred_I)[-1, :]

model_predictions_number_infected_tensor = torch.tensor(model_predictions_number_infected_list)
model_predictions_number_infected = model_predictions_number_infected_tensor.reshape((len(loc_list), pred_window)) # (52, 1, 15) --> (52, 15)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:42: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)

# %%
# Get the ground truth values for number of infected people 
ground_truth_number_infected_dictionary = {}
ground_truth_number_infected_tensor = test_active_cases

test_active_cases_tensor = test_active_cases.reshape((len(loc_list), pred_window)) # (52, 1, 15) --> (52, 15)

for loc_name in loc_list:
  cur_loc = loc_list.index(loc_name)
  ground_truth_number_infected_dictionary[loc_name] = test_active_cases_tensor[cur_loc]

# %%
archived_output = {
    'loc_list':loc_list, 
    'model_predictions_number_infected_dictionary':model_predictions_number_infected_dictionary, 
    'model_predictions_number_infected_tensor':model_predictions_number_infected_tensor, # (52, 15)
    'ground_truth_number_infected_dictionary':ground_truth_number_infected_dictionary, 
    'ground_truth_number_infected_tensor':test_active_cases_tensor # (52, 15)
}

import pickle

# Save archived_output as pickle for use later
with open('./save/archived_output.pickle', 'wb') as handle:
    pickle.dump(archived_output, handle)


# # Load in archived_output pickle
# archived_output = None
# with open('./save/archived_output.pickle', 'rb') as handle:
#     archived_output = pickle.load(handle)


# print(model_predictions_number_infected['Alabama'])
# print(ground_truth_number_infected['Alabama'])
